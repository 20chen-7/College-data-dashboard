# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
import io
import pandas as pd
import requests
import zipfile
import os

# %%
url = "https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09262023.zip"

# %%
response = requests.get(url)
response.raise_for_status()

# %%
zip_file_bytes = io.BytesIO(response.content)

# %%
#Save dataset into mage 
dataset_directory = '../mage/de-bootcamp-final-project/dataset'
os.makedirs(dataset_directory, exist_ok=True)

# List of desired CSV files 
desired_files = [
    'data/FieldOfStudyData1819_1920_PP.csv',
    'data/FieldOfStudyData1415_1516_PP.csv',
    'data/FieldOfStudyData1516_1617_PP.csv',
    'data/FieldOfStudyData1617_1718_PP.csv',
    'data/FieldOfStudyData1718_1819_PP.csv',
]

# %%
college_dtypes = {
                        'UNITID': pd.Int64Dtype(),
                        'OPEID6': pd.Int64Dtype(),
                        "INSTNM": str,
                        "CONTROL": str,
                        "MAIN": pd.Int64Dtype(),
                        "CIPCODE": pd.Int64Dtype(),
                        "CIPDESC": str,
                        "CREDLEV:": pd.Int64Dtype(),
                        "CREDDESC": str,
                        "IPEDSCOUNT1": float,
                        "IPEDSCOUNT2": float,
                        "DEBT_ALL_STGP_ANY_N": str,
                        "DEBT_ALL_STGP_ANY_MEAN": str,
                        "DEBT_ALL_STGP_ANY_MDN": str,
                        "DEBT_ALL_STGP_EVAL_N": str,
                        "DEBT_ALL_STGP_EVAL_MEAN": str,
                        "DEBT_ALL_STGP_EVAL_MDN": str,
                        "DEBT_ALL_PP_ANY_N": str,
                        "DEBT_ALL_PP_ANY_MEAN": str,
                        "DEBT_ALL_PP_ANY_MDN": str,
                        "DEBT_ALL_PP_EVAL_N": str,
                        "DEBT_ALL_PP_EVAL_MEAN": str,
                        "DEBT_ALL_PP_EVAL_MDN": str,
                        "DEBT_MALE_STGP_ANY_N": str,
                        "DEBT_MALE_STGP_ANY_MEAN": str,
                        "DEBT_MALE_STGP_ANY_MDN": str,
                        "DEBT_MALE_STGP_EVAL_N": str,
                        "DEBT_MALE_STGP_EVAL_MEAN": str,
                        "DEBT_MALE_STGP_EVAL_MDN": str,
                        "DEBT_MALE_PP_ANY_N": str,
                        "DEBT_MALE_PP_ANY_MEAN": str,
                        "DEBT_MALE_PP_ANY_MDN": str,
                        "DEBT_MALE_PP_EVAL_N": str,
                        "DEBT_MALE_PP_EVAL_MEAN": str,
                        "DEBT_MALE_PP_EVAL_MDN": str,
                        "DEBT_NOTMALE_STGP_ANY_N": str,
                        "DEBT_NOTMALE_STGP_ANY_MEAN": str,
                        "DEBT_NOTMALE_STGP_ANY_MDN": str,
                        "DEBT_NOTMALE_STGP_EVAL_N": str,
                        "DEBT_NOTMALE_STGP_EVAL_MEAN": str,
                        "DEBT_NOTMALE_STGP_EVAL_MDN": str,
                        "DEBT_NOTMALE_PP_ANY_N": str,
                        "DEBT_PELL_STGP_ANY_N": str,
                        "DEBT_PELL_STGP_ANY_MEAN": str,
                        "DEBT_PELL_STGP_ANY_MDN": str,
                        "DEBT_PELL_STGP_EVAL_N": str,
                        "DEBT_PELL_STGP_EVAL_MEAN": str,
                        "DEBT_PELL_STGP_EVAL_MDN": str,
                        "DEBT_PELL_PP_ANY_N": str,
                        "DEBT_PELL_PP_ANY_MEAN": str,
                        "DEBT_PELL_PP_ANY_MDN": str,
                        "DEBT_PELL_PP_EVAL_N": str,
                        "DEBT_PELL_PP_EVAL_MEAN": str,
                        "DEBT_PELL_PP_EVAL_MDN": str,
                        "DEBT_NOPELL_STGP_ANY_N": str,
                        "DEBT_NOPELL_STGP_ANY_MEAN": str,
                        "DEBT_NOPELL_STGP_ANY_MDN": str,
                        "DEBT_NOPELL_STGP_EVAL_N": str,
                        "DEBT_NOPELL_STGP_EVAL_MEAN": str,
                        "DEBT_NOPELL_STGP_EVAL_MDN": str,
                        "DEBT_NOPELL_PP_ANY_N": str,
                        "DEBT_NOPELL_PP_ANY_MEAN": str,
                        "DEBT_NOPELL_PP_ANY_MDN": str,
                        "DEBT_NOPELL_PP_EVAL_N": str,
                        "DEBT_NOPELL_PP_EVAL_MEAN": str,
                        "DEBT_NOPELL_PP_EVAL_MDN": str,
                        "DEBT_ALL_PP_ANY_MDN10YRPAY": str,
                        "DEBT_ALL_PP_EVAL_MDN10YRPAY": str,
                        "DEBT_ALL_STGP_ANY_MDN10YRPAY": str,
                        "DEBT_ALL_STGP_EVAL_MDN10YRPAY": str,
                        "EARN_COUNT_NWNE_HI_1YR": str,
                        "EARN_CNTOVER150_HI_1YR": str,
                        "EARN_COUNT_WNE_HI_1YR": str,
                        "EARN_MDN_HI_1YR": str,
                        "EARN_COUNT_NWNE_HI_2YR":str,
                        "EARN_CNTOVER150_HI_2YR": str,
                        "EARN_COUNT_WNE_HI_2YR": str,
                        "EARN_MDN_HI_2YR": str,
                        "BBRR2_FED_COMP_N": str,
                        "BBRR2_FED_COMP_DFLT": str,
                        "BBRR2_FED_COMP_DLNQ": str,
                        "BBRR2_FED_COMP_FBR": str,
                        "BBRR2_FED_COMP_DFR": str,
                        "BBRR2_FED_COMP_NOPROG": str,
                        "BBRR2_FED_COMP_MAKEPROG": str,
                        "BBRR2_FED_COMP_PAIDINFULL": str,
                        "BBRR2_FED_COMP_DISCHARGE": str,
                        "BBRR3_FED_COMP_N": str,
                        "BBRR3_FED_COMP_DFLT": str,
                        "BBRR3_FED_COMP_DLNQ": str,
                        "BBRR3_FED_COMP_FBR": str,
                        "BBRR3_FED_COMP_DFR": str,
                        "BBRR3_FED_COMP_NOPROG": str,
                        "BBRR3_FED_COMP_MAKEPROG": str,
                        "BBRR3_FED_COMP_PAIDINFULL": str,
                        "BBRR3_FED_COMP_DISCHARGE": str,
                        "EARN_COUNT_PELL_WNE_1YR": str,
                        "EARN_PELL_WNE_MDN_1YR": str,
                        "EARN_COUNT_NOPELL_WNE_1YR": str,
                        "EARN_NOPELL_WNE_MDN_1YR": str,
                        "EARN_COUNT_MALE_WNE_1YR": str,
                        "EARN_MALE_WNE_MDN_1YR": str,
                        "EARN_COUNT_NOMALE_WNE_1YR": str,
                        "EARN_NOMALE_WNE_MDN_1YR": str,
                        "EARN_COUNT_NE_3YR": str,
                        "EARN_NE_MDN_3YR": str,
                        "EARN_COUNT_WNE_3YR": str,
                        "EARN_CNTOVER150_3YR": str,
                        "EARN_COUNT_PELL_NE_3YR": str,
                        "EARN_PELL_NE_MDN_3YR": str,
                        "EARN_COUNT_NOPELL_NE_3YR": str,
                        "EARN_NOPELL_NE_MDN_3YR": str,
                        "EARN_COUNT_MALE_NE_3YR": str,
                        "EARN_MALE_NE_MDN_3YR": str,
                        "EARN_COUNT_NOMALE_NE_3YR": str,
                        "EARN_NOMALE_NE_MDN_3YR": str,
                        "DISTANCE": pd.Int64Dtype(),
                    }

# %%
with zipfile.ZipFile(zip_file_bytes) as zip_file:
    for file_name in zip_file.namelist():
        if file_name in desired_files:
            with zip_file.open(file_name) as file:
                df = pd.read_csv(file, dtype=college_dtypes)
                # Remove the 'data/' prefix from the filename
                simplified_name = file_name.split('/', 1)[1] if '/' in file_name else file_name
                full_path = os.path.join(dataset_directory, simplified_name.replace('.csv', '.parquet'))
                # Save to Parquet file
                df.to_parquet(full_path)
                print(f"Converted {simplified_name} to {full_path}")
# Out:
# Converted FieldOfStudyData1415_1516_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1415_1516_PP.parquet
# Converted FieldOfStudyData1516_1617_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1516_1617_PP.parquet
# Converted FieldOfStudyData1617_1718_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1617_1718_PP.parquet
# Converted FieldOfStudyData1718_1819_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1718_1819_PP.parquet
# Converted FieldOfStudyData1819_1920_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1819_1920_PP.parquet

# %% [markdown]
# Load merge data

# %%
desired_file = 'data/MERGED2019_20_PP.csv'

# %%
merged_dtypes = {
          "UNITID": float,
          "OPEID6": pd.Int64Dtype(),
          "INSTNM": str,
          "CONTROL": str,
          "MAIN": pd.Int64Dtype(),
          "CIPCODE": pd.Int64Dtype(),
          "CIPDESC": str,
          "CREDLEV": pd.Int64Dtype(),
          "CREDDESC": str,
          "IPEDSCOUNT1": float,
          "IPEDSCOUNT2": float,
          "DEBT_ALL_STGP_ANY_N": str,
          "DEBT_ALL_STGP_ANY_MEAN": str,
          "DEBT_ALL_STGP_ANY_MDN": str,
          "DEBT_ALL_STGP_EVAL_N": str,
          "DEBT_ALL_STGP_EVAL_MEAN": str,
          "DEBT_ALL_STGP_EVAL_MDN": str,
          "DEBT_ALL_PP_ANY_N": str,
          "DEBT_ALL_PP_ANY_MEAN": str,
          "DEBT_ALL_PP_ANY_MDN": str,
          "DEBT_ALL_PP_EVAL_N": str,
          "DEBT_ALL_PP_EVAL_MEAN": str,
          "DEBT_ALL_PP_EVAL_MDN": str,
          "DEBT_MALE_STGP_ANY_N": str,
          "DEBT_MALE_STGP_ANY_MEAN": str,
          "DEBT_MALE_STGP_ANY_MDN": str,
          "DEBT_MALE_STGP_EVAL_N": str,
          "DEBT_MALE_STGP_EVAL_MEAN": str,
          "DEBT_MALE_STGP_EVAL_MDN": str,
          "DEBT_MALE_PP_ANY_N": str,
          "DEBT_MALE_PP_ANY_MEAN": str,
          "DEBT_MALE_PP_ANY_MDN": str,
          "DEBT_MALE_PP_EVAL_N": str,
          "DEBT_MALE_PP_EVAL_MEAN": str,
          "DEBT_MALE_PP_EVAL_MDN": str,
          "DEBT_NOTMALE_STGP_ANY_N": str,
          "DEBT_NOTMALE_STGP_ANY_MEAN": str,
          "DEBT_NOTMALE_STGP_ANY_MDN": str,
          "DEBT_NOTMALE_STGP_EVAL_N": str,
          "DEBT_NOTMALE_STGP_EVAL_MEAN": str,
          "DEBT_NOTMALE_STGP_EVAL_MDN": str,
          "DEBT_NOTMALE_PP_ANY_N": str,
          "DEBT_NOTMALE_PP_ANY_MEAN": str,
          "DEBT_NOTMALE_PP_ANY_MDN": str,
          "DEBT_NOTMALE_PP_EVAL_N": str,
          "DEBT_NOTMALE_PP_EVAL_MEAN": str,
          "DEBT_NOTMALE_PP_EVAL_MDN": str,
          "DEBT_PELL_STGP_ANY_N": str,
          "DEBT_PELL_STGP_ANY_MEAN": str,
          "DEBT_PELL_STGP_ANY_MDN": str,
          "DEBT_PELL_STGP_EVAL_N": str,
          "DEBT_PELL_STGP_EVAL_MEAN": str,
          "DEBT_PELL_STGP_EVAL_MDN": str,
          "DEBT_PELL_PP_ANY_N": str,
          "DEBT_PELL_PP_ANY_MEAN": str,
          "DEBT_PELL_PP_ANY_MDN": str,
          "DEBT_PELL_PP_EVAL_N": str,
          "DEBT_PELL_PP_EVAL_MEAN": str,
          "DEBT_PELL_PP_EVAL_MDN": str,
          "DEBT_NOPELL_STGP_ANY_N": str,
          "DEBT_NOPELL_STGP_ANY_MEAN": str,
          "DEBT_NOPELL_STGP_ANY_MDN": str,
          "DEBT_NOPELL_STGP_EVAL_N": str,
          "DEBT_NOPELL_STGP_EVAL_MEAN": str,
          "DEBT_NOPELL_STGP_EVAL_MDN": str,
          "DEBT_NOPELL_PP_ANY_N": str,
          "DEBT_NOPELL_PP_ANY_MEAN": str,
          "DEBT_NOPELL_PP_ANY_MDN": str,
          "DEBT_NOPELL_PP_EVAL_N": str,
          "DEBT_NOPELL_PP_EVAL_MEAN": str,
          "DEBT_NOPELL_PP_EVAL_MDN": str,
          "DEBT_ALL_PP_ANY_MDN10YRPAY": str,
          "DEBT_ALL_PP_EVAL_MDN10YRPAY": str,
          "DEBT_ALL_STGP_ANY_MDN10YRPAY": str,
          "DEBT_ALL_STGP_EVAL_MDN10YRPAY": str,
          "EARN_COUNT_NWNE_HI_1YR": float,
          "EARN_CNTOVER150_HI_1YR": float,
          "EARN_COUNT_WNE_HI_1YR": float,
          "EARN_MDN_HI_1YR": float,
          "EARN_COUNT_NWNE_HI_2YR": float,
          "EARN_CNTOVER150_HI_2YR": float,
          "EARN_COUNT_WNE_HI_2YR": float,
          "EARN_MDN_HI_2YR": float,
          "BBRR2_FED_COMP_N": str,
          "BBRR2_FED_COMP_DFLT": str,
          "BBRR2_FED_COMP_DLNQ": str,
          "BBRR2_FED_COMP_FBR": str,
          "BBRR2_FED_COMP_DFR": str,
          "BBRR2_FED_COMP_NOPROG": str,
          "BBRR2_FED_COMP_MAKEPROG": str,
          "BBRR2_FED_COMP_PAIDINFULL": str,
          "BBRR2_FED_COMP_DISCHARGE": str,
          "BBRR3_FED_COMP_N": str,
          "BBRR3_FED_COMP_DFLT": str,
          "BBRR3_FED_COMP_DLNQ": str,
          "BBRR3_FED_COMP_FBR": str,
          "BBRR3_FED_COMP_DFR": str,
          "BBRR3_FED_COMP_NOPROG": str,
          "BBRR3_FED_COMP_MAKEPROG": str,
          "BBRR3_FED_COMP_PAIDINFULL": str,
          "BBRR3_FED_COMP_DISCHARGE": str,
          "EARN_COUNT_PELL_WNE_1YR": str,
          "EARN_PELL_WNE_MDN_1YR": str,
          "EARN_COUNT_NOPELL_WNE_1YR": str,
          "EARN_NOPELL_WNE_MDN_1YR": str,
          "EARN_COUNT_MALE_WNE_1YR": str,
          "EARN_MALE_WNE_MDN_1YR": str,
          "EARN_COUNT_NOMALE_WNE_1YR": str,
          "EARN_NOMALE_WNE_MDN_1YR": str,
          "EARN_COUNT_NE_3YR": float,
          "EARN_NE_MDN_3YR": float,
          "EARN_COUNT_WNE_3YR": float,
          "EARN_CNTOVER150_3YR": float,
          "EARN_COUNT_PELL_NE_3YR": float,
          "EARN_PELL_NE_MDN_3YR": float,
          "EARN_COUNT_NOPELL_NE_3YR": float,
          "EARN_NOPELL_NE_MDN_3YR": float,
          "EARN_COUNT_MALE_NE_3YR": float,
          "EARN_MALE_NE_MDN_3YR": float,
          "EARN_COUNT_NOMALE_NE_3YR": float,
          "EARN_NOMALE_NE_MDN_3YR": float,
          "EARN_COUNT_NWNE_1YR": str,
          "EARN_COUNT_WNE_1YR": str,
          "EARN_MDN_1YR": str,
          "EARN_GT_THRESHOLD_1YR": str,
          "EARN_COUNT_HIGH_CRED_1YR": str,
          "EARN_IN_STATE_1YR": str,
          "EARN_COUNT_NWNE_4YR": str,
          "EARN_COUNT_WNE_4YR": str,
          "EARN_MDN_4YR": str,
          "EARN_GT_THRESHOLD_4YR": str,
          "EARN_COUNT_PELL_WNE_4YR": str,
          "EARN_PELL_WNE_MDN_4YR": str,
          "EARN_COUNT_NOPELL_WNE_4YR": str,
          "EARN_NOPELL_WNE_MDN_4YR": str,
          "EARN_COUNT_MALE_WNE_4YR": str,
          "EARN_MALE_WNE_MDN_4YR": str,
          "EARN_COUNT_NOMALE_WNE_4YR": str,
          "EARN_NOMALE_WNE_MDN_4YR": str,
          "EARN_COUNT_HIGH_CRED_4YR": str,
          "EARN_IN_STATE_4YR": str,
          "BBRR1_FED_COMP_N": str,
          "BBRR1_FED_COMP_DFLT": str,
          "BBRR1_FED_COMP_DLNQ": str,
          "BBRR1_FED_COMP_FBR": str,
          "BBRR1_FED_COMP_DFR": str,
          "BBRR1_FED_COMP_NOPROG": str,
          "BBRR1_FED_COMP_MAKEPROG": str,
          "BBRR1_FED_COMP_PAIDINFULL": str,
          "BBRR1_FED_COMP_DISCHARGE": str,
          "BBRR4_FED_COMP_N": str,
          "BBRR4_FED_COMP_DFLT": str,
          "BBRR4_FED_COMP_DLNQ": str,
          "BBRR4_FED_COMP_FBR": str,
          "BBRR4_FED_COMP_DFR": str,
          "BBRR4_FED_COMP_NOPROG": str,
          "BBRR4_FED_COMP_MAKEPROG": str,
          "BBRR4_FED_COMP_PAIDINFULL": str,
          "BBRR4_FED_COMP_DISCHARGE": str,
          "DISTANCE": pd.Int64Dtype()
}

# %%
with zipfile.ZipFile(zip_file_bytes) as zip_file:
    with zip_file.open(desired_file) as file:
        df_merged = pd.read_csv(file)
        #         # Remove the 'data/' prefix from the filename
        # simplified_name = desired_file.split('/', 1)[1] if '/' in desired_file else desired_file
        # full_path = os.path.join(dataset_directory, simplified_name.replace('.csv', '.parquet'))
        #         # Save to Parquet file
        # df_merged.to_parquet(full_path)
        # print(f"Converted {simplified_name} to {full_path}")

# %%
print(pd.io.sql.get_schema(df_merged, name='school_data' ))
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                    0.3288                    0.2329
# 1                    0.5834                    0.1483
# 2                    0.5000                    0.5000
# 3                    0.5764                    0.1116
# 4                    0.4237                    0.1144
#
#    OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                       0.0132                       0.2632
# 1                       0.0139                       0.1823
# 2                       0.0000                       0.4211
# 3                       0.0079                       0.2619
# 4                       0.0000                       0.4211
#
#    OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                       0.5263                       0.1974
# 1                       0.5966                       0.2072
# 2                       0.5263                       0.0526
# 3                       0.5476                       0.1825
# 4                       0.5526                       0.0263
#
#    OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  OMACHT8_NOPELL_NOTFIRSTTIME  \
# 0               295.0                     219.0                         76.0
# 1              2029.0                    1025.0                       1004.0
# 2                21.0                       2.0                         19.0
# 3              1114.0                     484.0                        630.0
# 4               274.0                     236.0                         38.0
#
#    ADDR
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 3232 columns]

# %%
with open('output.txt', 'w') as f:
   print(df.dtypes, file=f)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/collage_data')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 engine = create_engine('postgresql://root:root@localhost:5432/collage_data')
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/.pyenv/versions/3.9.19/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:375, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     368     if m in kwargs:
#     369         _warn_with_version(
#     370             messages[m],
#     371             versions[m],
#     372             version_warnings[m],
#     373             stacklevel=3,
#     374         )
# --> 375 return fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.19/lib/python3.9/site-packages/sqlalchemy/engine/create.py:544, in create_engine(url, **kwargs)
#     542         if k in kwargs:
#     543             dbapi_args[k] = pop_kwarg(k)
# --> 544     dbapi = dialect_cls.dbapi(**dbapi_args)
#     546 dialect_args["dbapi"] = dbapi
#     548 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File ~/.pyenv/versions/3.9.19/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py:811, in PGDialect_psycopg2.dbapi(cls)
#     809 @classmethod
#     810 def dbapi(cls):
# --> 811     import psycopg2
#     813     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name='school_data' ))
# Out:
# CREATE TABLE "school_data" (
# "UNITID" REAL,
#   "OPEID6" INTEGER,
#   "INSTNM" TEXT,
#   "CONTROL" TEXT,
#   "MAIN" INTEGER,
#   "CIPCODE" INTEGER,
#   "CIPDESC" TEXT,
#   "CREDLEV" INTEGER,
#   "CREDDESC" TEXT,
#   "IPEDSCOUNT1" REAL,
#   "IPEDSCOUNT2" REAL,
#   "DEBT_ALL_STGP_ANY_N" TEXT,
#   "DEBT_ALL_STGP_ANY_MEAN" TEXT,
#   "DEBT_ALL_STGP_ANY_MDN" TEXT,
#   "DEBT_ALL_STGP_EVAL_N" TEXT,
#   "DEBT_ALL_STGP_EVAL_MEAN" TEXT,
#   "DEBT_ALL_STGP_EVAL_MDN" TEXT,
#   "DEBT_ALL_PP_ANY_N" TEXT,
#   "DEBT_ALL_PP_ANY_MEAN" TEXT,
#   "DEBT_ALL_PP_ANY_MDN" TEXT,
#   "DEBT_ALL_PP_EVAL_N" TEXT,
#   "DEBT_ALL_PP_EVAL_MEAN" TEXT,
#   "DEBT_ALL_PP_EVAL_MDN" TEXT,
#   "DEBT_MALE_STGP_ANY_N" TEXT,
#   "DEBT_MALE_STGP_ANY_MEAN" TEXT,
#   "DEBT_MALE_STGP_ANY_MDN" TEXT,
#   "DEBT_MALE_STGP_EVAL_N" TEXT,
#   "DEBT_MALE_STGP_EVAL_MEAN" TEXT,
#   "DEBT_MALE_STGP_EVAL_MDN" TEXT,
#   "DEBT_MALE_PP_ANY_N" TEXT,
#   "DEBT_MALE_PP_ANY_MEAN" TEXT,
#   "DEBT_MALE_PP_ANY_MDN" TEXT,
#   "DEBT_MALE_PP_EVAL_N" TEXT,
#   "DEBT_MALE_PP_EVAL_MEAN" TEXT,
#   "DEBT_MALE_PP_EVAL_MDN" TEXT,
#   "DEBT_NOTMALE_STGP_ANY_N" TEXT,
#   "DEBT_NOTMALE_STGP_ANY_MEAN" TEXT,
#   "DEBT_NOTMALE_STGP_ANY_MDN" TEXT,
#   "DEBT_NOTMALE_STGP_EVAL_N" TEXT,
#   "DEBT_NOTMALE_STGP_EVAL_MEAN" TEXT,
#   "DEBT_NOTMALE_STGP_EVAL_MDN" TEXT,
#   "DEBT_NOTMALE_PP_ANY_N" TEXT,
#   "DEBT_NOTMALE_PP_ANY_MEAN" TEXT,
#   "DEBT_NOTMALE_PP_ANY_MDN" TEXT,
#   "DEBT_NOTMALE_PP_EVAL_N" TEXT,
#   "DEBT_NOTMALE_PP_EVAL_MEAN" TEXT,
#   "DEBT_NOTMALE_PP_EVAL_MDN" TEXT,
#   "DEBT_PELL_STGP_ANY_N" TEXT,
#   "DEBT_PELL_STGP_ANY_MEAN" TEXT,
#   "DEBT_PELL_STGP_ANY_MDN" TEXT,
#   "DEBT_PELL_STGP_EVAL_N" TEXT,
#   "DEBT_PELL_STGP_EVAL_MEAN" TEXT,
#   "DEBT_PELL_STGP_EVAL_MDN" TEXT,
#   "DEBT_PELL_PP_ANY_N" TEXT,
#   "DEBT_PELL_PP_ANY_MEAN" TEXT,
#   "DEBT_PELL_PP_ANY_MDN" TEXT,
#   "DEBT_PELL_PP_EVAL_N" TEXT,
#   "DEBT_PELL_PP_EVAL_MEAN" TEXT,
#   "DEBT_PELL_PP_EVAL_MDN" TEXT,
#   "DEBT_NOPELL_STGP_ANY_N" TEXT,
#   "DEBT_NOPELL_STGP_ANY_MEAN" TEXT,
#   "DEBT_NOPELL_STGP_ANY_MDN" TEXT,
#   "DEBT_NOPELL_STGP_EVAL_N" TEXT,
#   "DEBT_NOPELL_STGP_EVAL_MEAN" TEXT,
#   "DEBT_NOPELL_STGP_EVAL_MDN" TEXT,
#   "DEBT_NOPELL_PP_ANY_N" TEXT,
#   "DEBT_NOPELL_PP_ANY_MEAN" TEXT,
#   "DEBT_NOPELL_PP_ANY_MDN" TEXT,
#   "DEBT_NOPELL_PP_EVAL_N" TEXT,
#   "DEBT_NOPELL_PP_EVAL_MEAN" TEXT,
#   "DEBT_NOPELL_PP_EVAL_MDN" TEXT,
#   "DEBT_ALL_PP_ANY_MDN10YRPAY" TEXT,
#   "DEBT_ALL_PP_EVAL_MDN10YRPAY" TEXT,
#   "DEBT_ALL_STGP_ANY_MDN10YRPAY" TEXT,
#   "DEBT_ALL_STGP_EVAL_MDN10YRPAY" TEXT,
#   "EARN_COUNT_NWNE_HI_1YR" REAL,
#   "EARN_CNTOVER150_HI_1YR" REAL,
#   "EARN_COUNT_WNE_HI_1YR" REAL,
#   "EARN_MDN_HI_1YR" REAL,
#   "EARN_COUNT_NWNE_HI_2YR" REAL,
#   "EARN_CNTOVER150_HI_2YR" REAL,
#   "EARN_COUNT_WNE_HI_2YR" REAL,
#   "EARN_MDN_HI_2YR" REAL,
#   "BBRR2_FED_COMP_N" TEXT,
#   "BBRR2_FED_COMP_DFLT" TEXT,
#   "BBRR2_FED_COMP_DLNQ" TEXT,
#   "BBRR2_FED_COMP_FBR" TEXT,
#   "BBRR2_FED_COMP_DFR" TEXT,
#   "BBRR2_FED_COMP_NOPROG" TEXT,
#   "BBRR2_FED_COMP_MAKEPROG" TEXT,
#   "BBRR2_FED_COMP_PAIDINFULL" TEXT,
#   "BBRR2_FED_COMP_DISCHARGE" TEXT,
#   "BBRR3_FED_COMP_N" TEXT,
#   "BBRR3_FED_COMP_DFLT" TEXT,
#   "BBRR3_FED_COMP_DLNQ" TEXT,
#   "BBRR3_FED_COMP_FBR" TEXT,
#   "BBRR3_FED_COMP_DFR" TEXT,
#   "BBRR3_FED_COMP_NOPROG" TEXT,
#   "BBRR3_FED_COMP_MAKEPROG" TEXT,
#   "BBRR3_FED_COMP_PAIDINFULL" TEXT,
#   "BBRR3_FED_COMP_DISCHARGE" TEXT,
#   "EARN_COUNT_PELL_WNE_1YR" TEXT,
#   "EARN_PELL_WNE_MDN_1YR" TEXT,
#   "EARN_COUNT_NOPELL_WNE_1YR" TEXT,
#   "EARN_NOPELL_WNE_MDN_1YR" TEXT,
#   "EARN_COUNT_MALE_WNE_1YR" TEXT,
#   "EARN_MALE_WNE_MDN_1YR" TEXT,
#   "EARN_COUNT_NOMALE_WNE_1YR" TEXT,
#   "EARN_NOMALE_WNE_MDN_1YR" TEXT,
#   "EARN_COUNT_NE_3YR" REAL,
#   "EARN_NE_MDN_3YR" REAL,
#   "EARN_COUNT_WNE_3YR" REAL,
#   "EARN_CNTOVER150_3YR" REAL,
#   "EARN_COUNT_PELL_NE_3YR" REAL,
#   "EARN_PELL_NE_MDN_3YR" REAL,
#   "EARN_COUNT_NOPELL_NE_3YR" REAL,
#   "EARN_NOPELL_NE_MDN_3YR" REAL,
#   "EARN_COUNT_MALE_NE_3YR" REAL,
#   "EARN_MALE_NE_MDN_3YR" REAL,
#   "EARN_COUNT_NOMALE_NE_3YR" REAL,
#   "EARN_NOMALE_NE_MDN_3YR" REAL,
#   "EARN_COUNT_NWNE_1YR" TEXT,
#   "EARN_COUNT_WNE_1YR" TEXT,
#   "EARN_MDN_1YR" TEXT,
#   "EARN_GT_THRESHOLD_1YR" TEXT,
#   "EARN_COUNT_HIGH_CRED_1YR" TEXT,
#   "EARN_IN_STATE_1YR" TEXT,
#   "EARN_COUNT_NWNE_4YR" TEXT,
#   "EARN_COUNT_WNE_4YR" TEXT,
#   "EARN_MDN_4YR" TEXT,
#   "EARN_GT_THRESHOLD_4YR" TEXT,
#   "EARN_COUNT_PELL_WNE_4YR" TEXT,
#   "EARN_PELL_WNE_MDN_4YR" TEXT,
#   "EARN_COUNT_NOPELL_WNE_4YR" TEXT,
#   "EARN_NOPELL_WNE_MDN_4YR" TEXT,
#   "EARN_COUNT_MALE_WNE_4YR" TEXT,
#   "EARN_MALE_WNE_MDN_4YR" TEXT,
#   "EARN_COUNT_NOMALE_WNE_4YR" TEXT,
#   "EARN_NOMALE_WNE_MDN_4YR" TEXT,
#   "EARN_COUNT_HIGH_CRED_4YR" TEXT,
#   "EARN_IN_STATE_4YR" TEXT,
#   "BBRR1_FED_COMP_N" TEXT,
#   "BBRR1_FED_COMP_DFLT" TEXT,
#   "BBRR1_FED_COMP_DLNQ" TEXT,
#   "BBRR1_FED_COMP_FBR" TEXT,
#   "BBRR1_FED_COMP_DFR" TEXT,
#   "BBRR1_FED_COMP_NOPROG" TEXT,
#   "BBRR1_FED_COMP_MAKEPROG" TEXT,
#   "BBRR1_FED_COMP_PAIDINFULL" TEXT,
#   "BBRR1_FED_COMP_DISCHARGE" TEXT,
#   "BBRR4_FED_COMP_N" TEXT,
#   "BBRR4_FED_COMP_DFLT" TEXT,
#   "BBRR4_FED_COMP_DLNQ" TEXT,
#   "BBRR4_FED_COMP_FBR" TEXT,
#   "BBRR4_FED_COMP_DFR" TEXT,
#   "BBRR4_FED_COMP_NOPROG" TEXT,
#   "BBRR4_FED_COMP_MAKEPROG" TEXT,
#   "BBRR4_FED_COMP_PAIDINFULL" TEXT,
#   "BBRR4_FED_COMP_DISCHARGE" TEXT,
#   "DISTANCE" INTEGER
# )

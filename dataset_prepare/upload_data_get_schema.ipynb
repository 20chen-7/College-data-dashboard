# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
import io
import pandas as pd
import requests
import zipfile
import os

# %%
url = "https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data_09262023.zip"

# %%
response = requests.get(url)
response.raise_for_status()

# %%
zip_file_bytes = io.BytesIO(response.content)

# %%
#Save dataset into mage 
dataset_directory = '../mage/de-bootcamp-final-project/dataset'
os.makedirs(dataset_directory, exist_ok=True)

# List of desired CSV files 
desired_files = [
    'data/FieldOfStudyData1819_1920_PP.csv',
    'data/FieldOfStudyData1415_1516_PP.csv',
    'data/FieldOfStudyData1516_1617_PP.csv',
    'data/FieldOfStudyData1617_1718_PP.csv',
    'data/FieldOfStudyData1718_1819_PP.csv',
]

# %%
college_dtypes = {
                        'UNITID': pd.Int64Dtype(),
                        'OPEID6': pd.Int64Dtype(),
                        "INSTNM": str,
                        "CONTROL": str,
                        "MAIN": pd.Int64Dtype(),
                        "CIPCODE": pd.Int64Dtype(),
                        "CIPDESC": str,
                        "CREDLEV:": pd.Int64Dtype(),
                        "CREDDESC": str,
                        "IPEDSCOUNT1": float,
                        "IPEDSCOUNT2": float,
                        "DEBT_ALL_STGP_ANY_N": str,
                        "DEBT_ALL_STGP_ANY_MEAN": str,
                        "DEBT_ALL_STGP_ANY_MDN": str,
                        "DEBT_ALL_STGP_EVAL_N": str,
                        "DEBT_ALL_STGP_EVAL_MEAN": str,
                        "DEBT_ALL_STGP_EVAL_MDN": str,
                        "DEBT_ALL_PP_ANY_N": str,
                        "DEBT_ALL_PP_ANY_MEAN": str,
                        "DEBT_ALL_PP_ANY_MDN": str,
                        "DEBT_ALL_PP_EVAL_N": str,
                        "DEBT_ALL_PP_EVAL_MEAN": str,
                        "DEBT_ALL_PP_EVAL_MDN": str,
                        "DEBT_MALE_STGP_ANY_N": str,
                        "DEBT_MALE_STGP_ANY_MEAN": str,
                        "DEBT_MALE_STGP_ANY_MDN": str,
                        "DEBT_MALE_STGP_EVAL_N": str,
                        "DEBT_MALE_STGP_EVAL_MEAN": str,
                        "DEBT_MALE_STGP_EVAL_MDN": str,
                        "DEBT_MALE_PP_ANY_N": str,
                        "DEBT_MALE_PP_ANY_MEAN": str,
                        "DEBT_MALE_PP_ANY_MDN": str,
                        "DEBT_MALE_PP_EVAL_N": str,
                        "DEBT_MALE_PP_EVAL_MEAN": str,
                        "DEBT_MALE_PP_EVAL_MDN": str,
                        "DEBT_NOTMALE_STGP_ANY_N": str,
                        "DEBT_NOTMALE_STGP_ANY_MEAN": str,
                        "DEBT_NOTMALE_STGP_ANY_MDN": str,
                        "DEBT_NOTMALE_STGP_EVAL_N": str,
                        "DEBT_NOTMALE_STGP_EVAL_MEAN": str,
                        "DEBT_NOTMALE_STGP_EVAL_MDN": str,
                        "DEBT_NOTMALE_PP_ANY_N": str,
                        "DEBT_PELL_STGP_ANY_N": str,
                        "DEBT_PELL_STGP_ANY_MEAN": str,
                        "DEBT_PELL_STGP_ANY_MDN": str,
                        "DEBT_PELL_STGP_EVAL_N": str,
                        "DEBT_PELL_STGP_EVAL_MEAN": str,
                        "DEBT_PELL_STGP_EVAL_MDN": str,
                        "DEBT_PELL_PP_ANY_N": str,
                        "DEBT_PELL_PP_ANY_MEAN": str,
                        "DEBT_PELL_PP_ANY_MDN": str,
                        "DEBT_PELL_PP_EVAL_N": str,
                        "DEBT_PELL_PP_EVAL_MEAN": str,
                        "DEBT_PELL_PP_EVAL_MDN": str,
                        "DEBT_NOPELL_STGP_ANY_N": str,
                        "DEBT_NOPELL_STGP_ANY_MEAN": str,
                        "DEBT_NOPELL_STGP_ANY_MDN": str,
                        "DEBT_NOPELL_STGP_EVAL_N": str,
                        "DEBT_NOPELL_STGP_EVAL_MEAN": str,
                        "DEBT_NOPELL_STGP_EVAL_MDN": str,
                        "DEBT_NOPELL_PP_ANY_N": str,
                        "DEBT_NOPELL_PP_ANY_MEAN": str,
                        "DEBT_NOPELL_PP_ANY_MDN": str,
                        "DEBT_NOPELL_PP_EVAL_N": str,
                        "DEBT_NOPELL_PP_EVAL_MEAN": str,
                        "DEBT_NOPELL_PP_EVAL_MDN": str,
                        "DEBT_ALL_PP_ANY_MDN10YRPAY": str,
                        "DEBT_ALL_PP_EVAL_MDN10YRPAY": str,
                        "DEBT_ALL_STGP_ANY_MDN10YRPAY": str,
                        "DEBT_ALL_STGP_EVAL_MDN10YRPAY": str,
                        "EARN_COUNT_NWNE_HI_1YR": str,
                        "EARN_CNTOVER150_HI_1YR": str,
                        "EARN_COUNT_WNE_HI_1YR": str,
                        "EARN_MDN_HI_1YR": str,
                        "EARN_COUNT_NWNE_HI_2YR":str,
                        "EARN_CNTOVER150_HI_2YR": str,
                        "EARN_COUNT_WNE_HI_2YR": str,
                        "EARN_MDN_HI_2YR": str,
                        "BBRR2_FED_COMP_N": str,
                        "BBRR2_FED_COMP_DFLT": str,
                        "BBRR2_FED_COMP_DLNQ": str,
                        "BBRR2_FED_COMP_FBR": str,
                        "BBRR2_FED_COMP_DFR": str,
                        "BBRR2_FED_COMP_NOPROG": str,
                        "BBRR2_FED_COMP_MAKEPROG": str,
                        "BBRR2_FED_COMP_PAIDINFULL": str,
                        "BBRR2_FED_COMP_DISCHARGE": str,
                        "BBRR3_FED_COMP_N": str,
                        "BBRR3_FED_COMP_DFLT": str,
                        "BBRR3_FED_COMP_DLNQ": str,
                        "BBRR3_FED_COMP_FBR": str,
                        "BBRR3_FED_COMP_DFR": str,
                        "BBRR3_FED_COMP_NOPROG": str,
                        "BBRR3_FED_COMP_MAKEPROG": str,
                        "BBRR3_FED_COMP_PAIDINFULL": str,
                        "BBRR3_FED_COMP_DISCHARGE": str,
                        "EARN_COUNT_PELL_WNE_1YR": str,
                        "EARN_PELL_WNE_MDN_1YR": str,
                        "EARN_COUNT_NOPELL_WNE_1YR": str,
                        "EARN_NOPELL_WNE_MDN_1YR": str,
                        "EARN_COUNT_MALE_WNE_1YR": str,
                        "EARN_MALE_WNE_MDN_1YR": str,
                        "EARN_COUNT_NOMALE_WNE_1YR": str,
                        "EARN_NOMALE_WNE_MDN_1YR": str,
                        "EARN_COUNT_NE_3YR": str,
                        "EARN_NE_MDN_3YR": str,
                        "EARN_COUNT_WNE_3YR": str,
                        "EARN_CNTOVER150_3YR": str,
                        "EARN_COUNT_PELL_NE_3YR": str,
                        "EARN_PELL_NE_MDN_3YR": str,
                        "EARN_COUNT_NOPELL_NE_3YR": str,
                        "EARN_NOPELL_NE_MDN_3YR": str,
                        "EARN_COUNT_MALE_NE_3YR": str,
                        "EARN_MALE_NE_MDN_3YR": str,
                        "EARN_COUNT_NOMALE_NE_3YR": str,
                        "EARN_NOMALE_NE_MDN_3YR": str,
                        "DISTANCE": pd.Int64Dtype(),
                    }

# %%
with zipfile.ZipFile(zip_file_bytes) as zip_file:
    for file_name in zip_file.namelist():
        if file_name in desired_files:
            with zip_file.open(file_name) as file:
                df = pd.read_csv(file, dtype=college_dtypes)
                # Remove the 'data/' prefix from the filename
                simplified_name = file_name.split('/', 1)[1] if '/' in file_name else file_name
                full_path = os.path.join(dataset_directory, simplified_name.replace('.csv', '.parquet'))
                # Save to Parquet file
                df.to_parquet(full_path)
                print(f"Converted {simplified_name} to {full_path}")
# Out:
# Converted FieldOfStudyData1415_1516_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1415_1516_PP.parquet
# Converted FieldOfStudyData1516_1617_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1516_1617_PP.parquet
# Converted FieldOfStudyData1617_1718_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1617_1718_PP.parquet
# Converted FieldOfStudyData1718_1819_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1718_1819_PP.parquet
# Converted FieldOfStudyData1819_1920_PP.csv to ../mage/de-bootcamp-final-project/dataset/FieldOfStudyData1819_1920_PP.parquet

# %% [markdown]
# Load merge data

# %%
desired_file = 'data/MERGED2019_20_PP.csv'

# %%
merged_dtypes = {
                        "UNITID": pd.Int64Dtype(),
                        "OPEID": pd.Int64Dtype(),
                        "OPEID6": pd.Int64Dtype(),
                        "INSTNM": str,
                        "CITY": str,
                        "STABBR": str,
                        "ZIP": str,
                        "ACCREDAGENCY": float,
                        "INSTURL": float,
                        "NPCURL": float,
                        "SCH_DEG": float,
                        "HCM2": float,
                        "MAIN": pd.Int64Dtype(),
                        "NUMBRANCH": pd.Int64Dtype(),
                        "PREDDEG": pd.Int64Dtype(),
                        "HIGHDEG": pd.Int64Dtype(),
                        "CONTROL": pd.Int64Dtype(),
                        "ST_FIPS": pd.Int64Dtype(),
                        "REGION": pd.Int64Dtype(),
                        "LOCALE": float,
                        "LOCALE2": float,
                        "LATITUDE": float,
                        "LONGITUDE": float,
                        "CCBASIC": float,
                        "CCUGPROF": float,
                        "CCSIZSET": float,
                        "HBCU": float,
                        "PBI": float,
                        "ANNHI": float,
                        "TRIBAL": float,
                        "AANAPII": float,
                        "HSI": float,
                        "NANTI": float,
                        "MENONLY": float,
                        "WOMENONLY": float,
                        "RELAFFIL": float,
                        "ADM_RATE": float,
                        "ADM_RATE_ALL": float,
                        "SATVR25": float,
                        "SATVR75": float,
                        "SATMT25": float,
                        "SATMT75": float,
                        "SATWR25": float,
                        "SATWR75": float,
                        "SATVRMID": float,
                        "SATMTMID": float,
                        "SATWRMID": float,
                        "ACTCM25": float,
                        "ACTCM75": float,
                        "ACTEN25": float,
                        "ACTEN75": float,
                        "ACTMT25": float,
                        "ACTMT75": float,
                        "ACTWR25": float,
                        "ACTWR75": float,
                        "ACTCMMID": float,
                        "ACTENMID": float,
                        "ACTMTMID": float,
                        "ACTWRMID": float,
                        "SAT_AVG": float,
                        "SAT_AVG_ALL": float,
                        "PCIP01": float,
                        "PCIP03": float,
                        "PCIP04": float,
                        "PCIP05": float,
                        "PCIP09": float,
                        "PCIP10": float,
                        "PCIP11": float,
                        "PCIP12": float,
                        "PCIP13": float,
                        "PCIP14": float,
                        "PCIP15": float,
                        "PCIP16": float,
                        "PCIP19": float,
                        "PCIP22": float,
                        "PCIP23": float,
                        "PCIP24": float,
                        "PCIP25": float,
                        "PCIP26": float,
                        "PCIP27": float,
                        "PCIP29": float,
                        "PCIP30": float,
                        "PCIP31": float,
                        "PCIP38": float,
                        "PCIP39": float,
                        "PCIP40": float,
                        "PCIP41": float,
                        "PCIP42": float,
                        "PCIP43": float,
                        "PCIP44": float,
                        "PCIP45": float,
                        "PCIP46": float,
                        "PCIP47": float,
                        "PCIP48": float,
                        "PCIP49": float,
                        "PCIP50": float,
                        "PCIP51": float,
                        "PCIP52": float,
                        "PCIP54": float,
                        "CIP01CERT1": float,
                        "CIP01CERT2": float,
                        "CIP01ASSOC": float,
                        "CIP01CERT4": float,
                        "CIP01BACHL": float,
                        "CIP03CERT1": float,
                        "CIP03CERT2": float,
                        "CIP03ASSOC": float,
                        "CIP03CERT4": float,
                        "CIP03BACHL": float,
                        "CIP04CERT1": float,
                        "CIP04CERT2": float,
                        "CIP04ASSOC": float,
                        "CIP04CERT4": float,
                        "CIP04BACHL": float,
                        "CIP05CERT1": float,
                        "CIP05CERT2": float,
                        "CIP05ASSOC": float,
                        "CIP05CERT4": float,
                        "CIP05BACHL": float,
                        "CIP09CERT1": float,
                        "CIP09CERT2": float,
                        "CIP09ASSOC": float,
                        "CIP09CERT4": float,
                        "CIP09BACHL": float,
                        "CIP10CERT1": float,
                        "CIP10CERT2": float,
                        "CIP10ASSOC": float,
                        "CIP10CERT4": float,
                        "CIP10BACHL": float,
                        "CIP11CERT1": float,
                        "CIP11CERT2": float,
                        "CIP11ASSOC": float,
                        "CIP11CERT4": float,
                        "CIP11BACHL": float,
                        "CIP12CERT1": float,
                        "CIP12CERT2": float,
                        "CIP12ASSOC": float,
                        "CIP12CERT4": float,
                        "CIP12BACHL": float,
                        "CIP13CERT1": float,
                        "CIP13CERT2": float,
                        "CIP13ASSOC": float,
                        "CIP13CERT4": float,
                        "CIP13BACHL": float,
                        "CIP14CERT1": float,
                        "CIP14CERT2": float,
                        "CIP14ASSOC": float,
                        "CIP14CERT4": float,
                        "CIP14BACHL": float,
                        "CIP15CERT1": float,
                        "CIP15CERT2": float,
                        "CIP15ASSOC": float,
                        "CIP15CERT4": float,
                        "CIP15BACHL": float,
                        "CIP16CERT1": float,
                        "CIP16CERT2": float,
                        "CIP16ASSOC": float,
                        "CIP16CERT4": float,
                        "CIP16BACHL": float,
                        "CIP19CERT1": float,
                        "CIP19CERT2": float,
                        "CIP19ASSOC": float,
                        "CIP19CERT4": float,
                        "CIP19BACHL": float,
                        "CIP22CERT1": float,
                        "CIP22CERT2": float,
                        "CIP22ASSOC": float,
                        "CIP22CERT4": float,
                        "CIP22BACHL": float,
                        "CIP23CERT1": float,
                        "CIP23CERT2": float,
                        "CIP23ASSOC": float,
                        "CIP23CERT4": float,
                        "CIP23BACHL": float,
                        "CIP24CERT1": float,
                        "CIP24CERT2": float,
                        "CIP24ASSOC": float,
                        "CIP24CERT4": float,
                        "CIP24BACHL": float,
                        "CIP25CERT1": float,
                        "CIP25CERT2": float,
                        "CIP25ASSOC": float,
                        "CIP25CERT4": float,
                        "CIP25BACHL": float,
                        "CIP26CERT1": float,
                        "CIP26CERT2": float,
                        "CIP26ASSOC": float,
                        "CIP26CERT4": float,
                        "CIP26BACHL": float,
                        "CIP27CERT1": float,
                        "CIP27CERT2": float,
                        "CIP27ASSOC": float,
                        "CIP27CERT4": float,
                        "CIP27BACHL": float,
                        "CIP29CERT1": float,
                        "CIP29CERT2": float,
                        "CIP29ASSOC": float,
                        "CIP29CERT4": float,
                        "CIP29BACHL": float,
                        "CIP30CERT1": float,
                        "CIP30CERT2": float,
                        "CIP30ASSOC": float,
                        "CIP30CERT4": float,
                        "CIP30BACHL": float,
                        "CIP31CERT1": float,
                        "CIP31CERT2": float,
                        "CIP31ASSOC": float,
                        "CIP31CERT4": float,
                        "CIP31BACHL": float,
                        "CIP38CERT1": float,
                        "CIP38CERT2": float,
                        "CIP38ASSOC": float,
                        "CIP38CERT4": float,
                        "CIP38BACHL": float,
                        "CIP39CERT1": float,
                        "CIP39CERT2": float,
                        "CIP39ASSOC": float,
                        "CIP39CERT4": float,
                        "CIP39BACHL": float,
                        "CIP40CERT1": float,
                        "CIP40CERT2": float,
                        "CIP40ASSOC": float,
                        "CIP40CERT4": float,
                        "CIP40BACHL": float,
                        "CIP41CERT1": float,
                        "CIP41CERT2": float,
                        "CIP41ASSOC": float,
                        "CIP41CERT4": float,
                        "CIP41BACHL": float,
                        "CIP42CERT1": float,
                        "CIP42CERT2": float,
                        "CIP42ASSOC": float,
                        "CIP42CERT4": float,
                        "CIP42BACHL": float,
                        "CIP43CERT1": float,
                        "CIP43CERT2": float,
                        "CIP43ASSOC": float,
                        "CIP43CERT4": float,
                        "CIP43BACHL": float,
                        "CIP44CERT1": float,
                        "CIP44CERT2": float,
                        "CIP44ASSOC": float,
                        "CIP44CERT4": float,
                        "CIP44BACHL": float,
                        "CIP45CERT1": float,
                        "CIP45CERT2": float,
                        "CIP45ASSOC": float,
                        "CIP45CERT4": float,
                        "CIP45BACHL": float,
                        "CIP46CERT1": float,
                        "CIP46CERT2": float,
                        "CIP46ASSOC": float,
                        "CIP46CERT4": float,
                        "CIP46BACHL": float,
                        "CIP47CERT1": float,
                        "CIP47CERT2": float,
                        "CIP47ASSOC": float,
                        "CIP47CERT4": float,
                        "CIP47BACHL": float,
                        "CIP48CERT1": float,
                        "CIP48CERT2": float,
                        "CIP48ASSOC": float,
                        "CIP48CERT4": float,
                        "CIP48BACHL": float,
                        "CIP49CERT1": float,
                        "CIP49CERT2": float,
                        "CIP49ASSOC": float,
                        "CIP49CERT4": float,
                        "CIP49BACHL": float,
                        "CIP50CERT1": float,
                        "CIP50CERT2": float,
                        "CIP50ASSOC": float,
                        "CIP50CERT4": float,
                        "CIP50BACHL": float,
                        "CIP51CERT1": float,
                        "CIP51CERT2": float,
                        "CIP51ASSOC": float,
                        "CIP51CERT4": float,
                        "CIP51BACHL": float,
                        "CIP52CERT1": float,
                        "CIP52CERT2": float,
                        "CIP52ASSOC": float,
                        "CIP52CERT4": float,
                        "CIP52BACHL": float,
                        "CIP54CERT1": float,
                        "CIP54CERT2": float,
                        "CIP54ASSOC": float,
                        "CIP54CERT4": float,
                        "CIP54BACHL": float,
                        "DISTANCEONLY": float,
                        "UGDS": float,
                        "UG": float,
                        "UGDS_WHITE": float,
                        "UGDS_BLACK": float,
                        "UGDS_HISP": float,
                        "UGDS_ASIAN": float,
                        "UGDS_AIAN": float,
                        "UGDS_NHPI": float,
                        "UGDS_2MOR": float,
                        "UGDS_NRA": float,
                        "UGDS_UNKN": float,
                        "UGDS_WHITENH": float,
                        "UGDS_BLACKNH": float,
                        "UGDS_API": float,
                        "UGDS_AIANOLD": float,
                        "UGDS_HISPOLD": float,
                        "UG_NRA": float,
                        "UG_UNKN": float,
                        "UG_WHITENH": float,
                        "UG_BLACKNH": float,
                        "UG_API": float,
                        "UG_AIANOLD": float,
                        "UG_HISPOLD": float,
                        "PPTUG_EF": float,
                        "PPTUG_EF2": float,
                        "CURROPER": float,
                        "NPT4_PUB": float,
                        "NPT4_PRIV": float,
                        "NPT4_PROG": float,
                        "NPT4_OTHER": float,
                        "NPT41_PUB": float,
                        "NPT42_PUB": float,
                        "NPT43_PUB": float,
                        "NPT44_PUB": float,
                        "NPT45_PUB": float,
                        "NPT41_PRIV": float,
                        "NPT42_PRIV": float,
                        "NPT43_PRIV": float,
                        "NPT44_PRIV": float,
                        "NPT45_PRIV": float,
                        "NPT41_PROG": float,
                        "NPT42_PROG": float,
                        "NPT43_PROG": float,
                        "NPT44_PROG": float,
                        "NPT45_PROG": float,
                        "NPT41_OTHER": float,
                        "NPT42_OTHER": float,
                        "NPT43_OTHER": float,
                        "NPT44_OTHER": float,
                        "NPT45_OTHER": float,
                        "NPT4_048_PUB": float,
                        "NPT4_048_PRIV": float,
                        "NPT4_048_PROG": float,
                        "NPT4_048_OTHER": float,
                        "NPT4_3075_PUB": float,
                        "NPT4_3075_PRIV": float,
                        "NPT4_75UP_PUB": float,
                        "NPT4_75UP_PRIV": float,
                        "NPT4_3075_PROG": float,
                        "NPT4_3075_OTHER": float,
                        "NPT4_75UP_PROG": float,
                        "NPT4_75UP_OTHER": float,
                        "NUM4_PUB": float,
                        "NUM4_PRIV": float,
                        "NUM4_PROG": float,
                        "NUM4_OTHER": float,
                        "NUM41_PUB": float,
                        "NUM42_PUB": float,
                        "NUM43_PUB": float,
                        "NUM44_PUB": float,
                        "NUM45_PUB": float,
                        "NUM41_PRIV": float,
                        "NUM42_PRIV": float,
                        "NUM43_PRIV": float,
                        "NUM44_PRIV": float,
                        "NUM45_PRIV": float,
                        "NUM41_PROG": float,
                        "NUM42_PROG": float,
                        "NUM43_PROG": float,
                        "NUM44_PROG": float,
                        "NUM45_PROG": float,
                        "NUM41_OTHER": float,
                        "NUM42_OTHER": float,
                        "NUM43_OTHER": float,
                        "NUM44_OTHER": float,
                        "NUM45_OTHER": float,
                        "COSTT4_A": float,
                        "COSTT4_P": float,
                        "TUITIONFEE_IN": float,
                        "TUITIONFEE_OUT": float,
                        "TUITIONFEE_PROG": float,
                        "TUITFTE": float,
                        "INEXPFTE": float,
                        "AVGFACSAL": float,
                        "PFTFAC": float,
                        "PCTPELL": float,
                        "C150_4": float,
                        "C150_L4": float,
                        "C150_4_POOLED": float,
                        "C150_L4_POOLED": float,
                        "POOLYRS": float,
                        "PFTFTUG1_EF": float,
                        "D150_4": float,
                        "D150_L4": float,
                        "D150_4_POOLED": float,
                        "D150_L4_POOLED": float,
                        "C150_4_WHITE": float,
                        "C150_4_BLACK": float,
                        "C150_4_HISP": float,
                        "C150_4_ASIAN": float,
                        "C150_4_AIAN": float,
                        "C150_4_NHPI": float,
                        "C150_4_2MOR": float,
                        "C150_4_NRA": float,
                        "C150_4_UNKN": float,
                        "C150_4_WHITENH": float,
                        "C150_4_BLACKNH": float,
                        "C150_4_API": float,
                        "C150_4_AIANOLD": float,
                        "C150_4_HISPOLD": float,
                        "C150_L4_WHITE": float,
                        "C150_L4_BLACK": float,
                        "C150_L4_HISP": float,
                        "C150_L4_ASIAN": float,
                        "C150_L4_AIAN": float,
                        "C150_L4_NHPI": float,
                        "C150_L4_2MOR": float,
                        "C150_L4_NRA": float,
                        "C150_L4_UNKN": float,
                        "C150_L4_WHITENH": float,
                        "C150_L4_BLACKNH": float,
                        "C150_L4_API": float,
                        "C150_L4_AIANOLD": float,
                        "C150_L4_HISPOLD": float,
                        "C200_4": float,
                        "C200_L4": float,
                        "D200_4": float,
                        "D200_L4": float,
                        "RET_FT4": float,
                        "RET_FTL4": float,
                        "RET_PT4": float,
                        "RET_PTL4": float,
                        "C200_4_POOLED": float,
                        "C200_L4_POOLED": float,
                        "POOLYRS200": float,
                        "D200_4_POOLED": float,
                        "D200_L4_POOLED": float,
                        "PCTFLOAN": float,
                        "UG25ABV": float,
                        "CDR2": float,
                        "CDR3": float,
                        "DEATH_YR2_RT": str,
                        "COMP_ORIG_YR2_RT": str,
                        "COMP_4YR_TRANS_YR2_RT": str,
                        "COMP_2YR_TRANS_YR2_RT": str,
                        "WDRAW_ORIG_YR2_RT": str,
                        "WDRAW_4YR_TRANS_YR2_RT": str,
                        "WDRAW_2YR_TRANS_YR2_RT": str,
                        "ENRL_ORIG_YR2_RT": str,
                        "ENRL_4YR_TRANS_YR2_RT": str,
                        "ENRL_2YR_TRANS_YR2_RT": str,
                        "UNKN_ORIG_YR2_RT": str,
                        "UNKN_4YR_TRANS_YR2_RT": str,
                        "UNKN_2YR_TRANS_YR2_RT": str,
                        "LO_INC_DEATH_YR2_RT": str,
                        "LO_INC_COMP_ORIG_YR2_RT": str,
                        "LO_INC_COMP_4YR_TRANS_YR2_RT": str,
                        "LO_INC_COMP_2YR_TRANS_YR2_RT": str,
                        "LO_INC_WDRAW_ORIG_YR2_RT": str,
                        "LO_INC_WDRAW_4YR_TRANS_YR2_RT": str,
                        "LO_INC_WDRAW_2YR_TRANS_YR2_RT": str,
                        "LO_INC_ENRL_ORIG_YR2_RT": str,
                        "LO_INC_ENRL_4YR_TRANS_YR2_RT": str,
                        "LO_INC_ENRL_2YR_TRANS_YR2_RT": str,
                        "LO_INC_UNKN_ORIG_YR2_RT": str,
                        "LO_INC_UNKN_4YR_TRANS_YR2_RT": str,
                        "LO_INC_UNKN_2YR_TRANS_YR2_RT": str,
                        "MD_INC_DEATH_YR2_RT": str,
                        "MD_INC_COMP_ORIG_YR2_RT": str,
                        "MD_INC_COMP_4YR_TRANS_YR2_RT": str,
                        "MD_INC_COMP_2YR_TRANS_YR2_RT": str,
                        "MD_INC_WDRAW_ORIG_YR2_RT": str,
                        "MD_INC_WDRAW_4YR_TRANS_YR2_RT": str,
                        "MD_INC_WDRAW_2YR_TRANS_YR2_RT": str,
                        "MD_INC_ENRL_ORIG_YR2_RT": str,
                        "MD_INC_ENRL_4YR_TRANS_YR2_RT": str,
                        "MD_INC_ENRL_2YR_TRANS_YR2_RT": str,
                        "MD_INC_UNKN_ORIG_YR2_RT": str,
                        "MD_INC_UNKN_4YR_TRANS_YR2_RT": str,
                        "MD_INC_UNKN_2YR_TRANS_YR2_RT": str,
                        "HI_INC_DEATH_YR2_RT": str,
                        "HI_INC_COMP_ORIG_YR2_RT": str,
                        "HI_INC_COMP_4YR_TRANS_YR2_RT": str,
                        "HI_INC_COMP_2YR_TRANS_YR2_RT": str,
                        "HI_INC_WDRAW_ORIG_YR2_RT": str,
                        "HI_INC_WDRAW_4YR_TRANS_YR2_RT": str,
                        "HI_INC_WDRAW_2YR_TRANS_YR2_RT": str,
                        "HI_INC_ENRL_ORIG_YR2_RT": str,
                        "HI_INC_ENRL_4YR_TRANS_YR2_RT": str,
                        "HI_INC_ENRL_2YR_TRANS_YR2_RT": str,
                        "HI_INC_UNKN_ORIG_YR2_RT": str,
                        "HI_INC_UNKN_4YR_TRANS_YR2_RT": str,
                        "HI_INC_UNKN_2YR_TRANS_YR2_RT": str,
                        "DEP_DEATH_YR2_RT": str,
                        "DEP_COMP_ORIG_YR2_RT": str,
                        "DEP_COMP_4YR_TRANS_YR2_RT": str,
                        "DEP_COMP_2YR_TRANS_YR2_RT": str,
                        "DEP_WDRAW_ORIG_YR2_RT": str,
                        "DEP_WDRAW_4YR_TRANS_YR2_RT": str,
                        "DEP_WDRAW_2YR_TRANS_YR2_RT": str,
                        "DEP_ENRL_ORIG_YR2_RT": str,
                        "DEP_ENRL_4YR_TRANS_YR2_RT": str,
                        "DEP_ENRL_2YR_TRANS_YR2_RT": str,
                        "DEP_UNKN_ORIG_YR2_RT": str,
                        "DEP_UNKN_4YR_TRANS_YR2_RT": str,
                        "DEP_UNKN_2YR_TRANS_YR2_RT": str,
                        "IND_DEATH_YR2_RT": str,
                        "IND_COMP_ORIG_YR2_RT": str,
                        "IND_COMP_4YR_TRANS_YR2_RT": str,
                        "IND_COMP_2YR_TRANS_YR2_RT": str,
                        "IND_WDRAW_ORIG_YR2_RT": str,
                        "IND_WDRAW_4YR_TRANS_YR2_RT": str,
                        "IND_WDRAW_2YR_TRANS_YR2_RT": str,
                        "IND_ENRL_ORIG_YR2_RT": str,
                        "IND_ENRL_4YR_TRANS_YR2_RT": str,
                        "IND_ENRL_2YR_TRANS_YR2_RT": str,
                        "IND_UNKN_ORIG_YR2_RT": str,
                        "IND_UNKN_4YR_TRANS_YR2_RT": str,
                        "IND_UNKN_2YR_TRANS_YR2_RT": str,
                        "FEMALE_DEATH_YR2_RT": str,
                        "FEMALE_COMP_ORIG_YR2_RT": str,
                        "FEMALE_COMP_4YR_TRANS_YR2_RT": str,
                        "FEMALE_COMP_2YR_TRANS_YR2_RT": str,
                        "FEMALE_WDRAW_ORIG_YR2_RT": str,
                        "FEMALE_WDRAW_4YR_TRANS_YR2_RT": str,
                        "FEMALE_WDRAW_2YR_TRANS_YR2_RT": str,
                        "FEMALE_ENRL_ORIG_YR2_RT": str,
                        "FEMALE_ENRL_4YR_TRANS_YR2_RT": str,
                        "FEMALE_ENRL_2YR_TRANS_YR2_RT": str,
                        "FEMALE_UNKN_ORIG_YR2_RT": str,
                        "FEMALE_UNKN_4YR_TRANS_YR2_RT": str,
                        "FEMALE_UNKN_2YR_TRANS_YR2_RT": str,
                        "MALE_DEATH_YR2_RT": str,
                        "MALE_COMP_ORIG_YR2_RT": str,
                        "MALE_COMP_4YR_TRANS_YR2_RT": str,
                        "MALE_COMP_2YR_TRANS_YR2_RT": str,
                        "MALE_WDRAW_ORIG_YR2_RT": str,
                        "MALE_WDRAW_4YR_TRANS_YR2_RT": str,
                        "MALE_WDRAW_2YR_TRANS_YR2_RT": str,
                        "MALE_ENRL_ORIG_YR2_RT": str,
                        "MALE_ENRL_4YR_TRANS_YR2_RT": str,
                        "MALE_ENRL_2YR_TRANS_YR2_RT": str,
                        "MALE_UNKN_ORIG_YR2_RT": str,
                        "MALE_UNKN_4YR_TRANS_YR2_RT": str,
                        "MALE_UNKN_2YR_TRANS_YR2_RT": str,
                        "PELL_DEATH_YR2_RT": str,
                        "PELL_COMP_ORIG_YR2_RT": str,
                        "PELL_COMP_4YR_TRANS_YR2_RT": str,
                        "PELL_COMP_2YR_TRANS_YR2_RT": str,
                        "PELL_WDRAW_ORIG_YR2_RT": str,
                        "PELL_WDRAW_4YR_TRANS_YR2_RT": str,
                        "PELL_WDRAW_2YR_TRANS_YR2_RT": str,
                        "PELL_ENRL_ORIG_YR2_RT": str,
                        "PELL_ENRL_4YR_TRANS_YR2_RT": str,
                        "PELL_ENRL_2YR_TRANS_YR2_RT": str,
                        "PELL_UNKN_ORIG_YR2_RT": str,
                        "PELL_UNKN_4YR_TRANS_YR2_RT": str,
                        "PELL_UNKN_2YR_TRANS_YR2_RT": str,
                        "NOPELL_DEATH_YR2_RT": str,
                        "NOPELL_COMP_ORIG_YR2_RT": str,
                        "NOPELL_COMP_4YR_TRANS_YR2_RT": str,
                        "NOPELL_COMP_2YR_TRANS_YR2_RT": str,
                        "NOPELL_WDRAW_ORIG_YR2_RT": str,
                        "NOPELL_WDRAW_4YR_TRANS_YR2_RT": str,
                        "NOPELL_WDRAW_2YR_TRANS_YR2_RT": str,
                        "NOPELL_ENRL_ORIG_YR2_RT": str,
                        "NOPELL_ENRL_4YR_TRANS_YR2_RT": str,
                        "NOPELL_ENRL_2YR_TRANS_YR2_RT": str,
                        "NOPELL_UNKN_ORIG_YR2_RT": str,
                        "NOPELL_UNKN_4YR_TRANS_YR2_RT": str,
                        "NOPELL_UNKN_2YR_TRANS_YR2_RT": str,
                        "LOAN_DEATH_YR2_RT": str,
                        "LOAN_COMP_ORIG_YR2_RT": str,
                        "LOAN_COMP_4YR_TRANS_YR2_RT": str,
                        "LOAN_COMP_2YR_TRANS_YR2_RT": str,
                        "LOAN_WDRAW_ORIG_YR2_RT": str,
                        "LOAN_WDRAW_4YR_TRANS_YR2_RT": str,
                        "LOAN_WDRAW_2YR_TRANS_YR2_RT": str,
                        "LOAN_ENRL_ORIG_YR2_RT": str,
                        "LOAN_ENRL_4YR_TRANS_YR2_RT": str,
                        "LOAN_ENRL_2YR_TRANS_YR2_RT": str,
                        "LOAN_UNKN_ORIG_YR2_RT": str,
                        "LOAN_UNKN_4YR_TRANS_YR2_RT": str,
                        "LOAN_UNKN_2YR_TRANS_YR2_RT": str,
                        "NOLOAN_DEATH_YR2_RT": str,
                        "NOLOAN_COMP_ORIG_YR2_RT": str,
                        "NOLOAN_COMP_4YR_TRANS_YR2_RT": str,
                        "NOLOAN_COMP_2YR_TRANS_YR2_RT": str,
                        "NOLOAN_WDRAW_ORIG_YR2_RT": str,
                        "NOLOAN_WDRAW_4YR_TRANS_YR2_RT": str,
                        "NOLOAN_WDRAW_2YR_TRANS_YR2_RT": str,
                        "NOLOAN_ENRL_ORIG_YR2_RT": str,
                        "NOLOAN_ENRL_4YR_TRANS_YR2_RT": str,
                        "NOLOAN_ENRL_2YR_TRANS_YR2_RT": str,
                        "NOLOAN_UNKN_ORIG_YR2_RT": str,
                        "NOLOAN_UNKN_4YR_TRANS_YR2_RT": str,
                        "NOLOAN_UNKN_2YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_DEATH_YR2_RT": str,
                        "FIRSTGEN_COMP_ORIG_YR2_RT": str,
                        "FIRSTGEN_COMP_4YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_COMP_2YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_WDRAW_ORIG_YR2_RT": str,
                        "FIRSTGEN_WDRAW_4YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_WDRAW_2YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_ENRL_ORIG_YR2_RT": str,
                        "FIRSTGEN_ENRL_4YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_ENRL_2YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_UNKN_ORIG_YR2_RT": str,
                        "FIRSTGEN_UNKN_4YR_TRANS_YR2_RT": str,
                        "FIRSTGEN_UNKN_2YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_DEATH_YR2_RT": str,
                        "NOT1STGEN_COMP_ORIG_YR2_RT": str,
                        "NOT1STGEN_COMP_4YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_COMP_2YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_WDRAW_ORIG_YR2_RT": str,
                        "NOT1STGEN_WDRAW_4YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_WDRAW_2YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_ENRL_ORIG_YR2_RT": str,
                        "NOT1STGEN_ENRL_4YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_ENRL_2YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_UNKN_ORIG_YR2_RT": str,
                        "NOT1STGEN_UNKN_4YR_TRANS_YR2_RT": str,
                        "NOT1STGEN_UNKN_2YR_TRANS_YR2_RT": str,
                        "DEATH_YR3_RT": str,
                        "COMP_ORIG_YR3_RT": str,
                        "COMP_4YR_TRANS_YR3_RT": str,
                        "COMP_2YR_TRANS_YR3_RT": str,
                        "WDRAW_ORIG_YR3_RT": str,
                        "WDRAW_4YR_TRANS_YR3_RT": str,
                        "WDRAW_2YR_TRANS_YR3_RT": str,
                        "ENRL_ORIG_YR3_RT": str,
                        "ENRL_4YR_TRANS_YR3_RT": str,
                        "ENRL_2YR_TRANS_YR3_RT": str,
                        "UNKN_ORIG_YR3_RT": str,
                        "UNKN_4YR_TRANS_YR3_RT": str,
                        "UNKN_2YR_TRANS_YR3_RT": str,
                        "LO_INC_DEATH_YR3_RT": str,
                        "LO_INC_COMP_ORIG_YR3_RT": str,
                        "LO_INC_COMP_4YR_TRANS_YR3_RT": str,
                        "LO_INC_COMP_2YR_TRANS_YR3_RT": str,
                        "LO_INC_WDRAW_ORIG_YR3_RT": str,
                        "LO_INC_WDRAW_4YR_TRANS_YR3_RT": str,
                        "LO_INC_WDRAW_2YR_TRANS_YR3_RT": str,
                        "LO_INC_ENRL_ORIG_YR3_RT": str,
                        "LO_INC_ENRL_4YR_TRANS_YR3_RT": str,
                        "LO_INC_ENRL_2YR_TRANS_YR3_RT": str,
                        "LO_INC_UNKN_ORIG_YR3_RT": str,
                        "LO_INC_UNKN_4YR_TRANS_YR3_RT": str,
                        "LO_INC_UNKN_2YR_TRANS_YR3_RT": str,
                        "MD_INC_DEATH_YR3_RT": str,
                        "MD_INC_COMP_ORIG_YR3_RT": str,
                        "MD_INC_COMP_4YR_TRANS_YR3_RT": str,
                        "MD_INC_COMP_2YR_TRANS_YR3_RT": str,
                        "MD_INC_WDRAW_ORIG_YR3_RT": str,
                        "MD_INC_WDRAW_4YR_TRANS_YR3_RT": str,
                        "MD_INC_WDRAW_2YR_TRANS_YR3_RT": str,
                        "MD_INC_ENRL_ORIG_YR3_RT": str,
                        "MD_INC_ENRL_4YR_TRANS_YR3_RT": str,
                        "MD_INC_ENRL_2YR_TRANS_YR3_RT": str,
                        "MD_INC_UNKN_ORIG_YR3_RT": str,
                        "MD_INC_UNKN_4YR_TRANS_YR3_RT": str,
                        "MD_INC_UNKN_2YR_TRANS_YR3_RT": str,
                        "HI_INC_DEATH_YR3_RT": str,
                        "HI_INC_COMP_ORIG_YR3_RT": str,
                        "HI_INC_COMP_4YR_TRANS_YR3_RT": str,
                        "HI_INC_COMP_2YR_TRANS_YR3_RT": str,
                        "HI_INC_WDRAW_ORIG_YR3_RT": str,
                        "HI_INC_WDRAW_4YR_TRANS_YR3_RT": str,
                        "HI_INC_WDRAW_2YR_TRANS_YR3_RT": str,
                        "HI_INC_ENRL_ORIG_YR3_RT": str,
                        "HI_INC_ENRL_4YR_TRANS_YR3_RT": str,
                        "HI_INC_ENRL_2YR_TRANS_YR3_RT": str,
                        "HI_INC_UNKN_ORIG_YR3_RT": str,
                        "HI_INC_UNKN_4YR_TRANS_YR3_RT": str,
                        "HI_INC_UNKN_2YR_TRANS_YR3_RT": str,
                        "DEP_DEATH_YR3_RT": str,
                        "DEP_COMP_ORIG_YR3_RT": str,
                        "DEP_COMP_4YR_TRANS_YR3_RT": str,
                        "DEP_COMP_2YR_TRANS_YR3_RT": str,
                        "DEP_WDRAW_ORIG_YR3_RT": str,
                        "DEP_WDRAW_4YR_TRANS_YR3_RT": str,
                        "DEP_WDRAW_2YR_TRANS_YR3_RT": str,
                        "DEP_ENRL_ORIG_YR3_RT": str,
                        "DEP_ENRL_4YR_TRANS_YR3_RT": str,
                        "DEP_ENRL_2YR_TRANS_YR3_RT": str,
                        "DEP_UNKN_ORIG_YR3_RT": str,
                        "DEP_UNKN_4YR_TRANS_YR3_RT": str,
                        "DEP_UNKN_2YR_TRANS_YR3_RT": str,
                        "IND_DEATH_YR3_RT": str,
                        "IND_COMP_ORIG_YR3_RT": str,
                        "IND_COMP_4YR_TRANS_YR3_RT": str,
                        "IND_COMP_2YR_TRANS_YR3_RT": str,
                        "IND_WDRAW_ORIG_YR3_RT": str,
                        "IND_WDRAW_4YR_TRANS_YR3_RT": str,
                        "IND_WDRAW_2YR_TRANS_YR3_RT": str,
                        "IND_ENRL_ORIG_YR3_RT": str,
                        "IND_ENRL_4YR_TRANS_YR3_RT": str,
                        "IND_ENRL_2YR_TRANS_YR3_RT": str,
                        "IND_UNKN_ORIG_YR3_RT": str,
                        "IND_UNKN_4YR_TRANS_YR3_RT": str,
                        "IND_UNKN_2YR_TRANS_YR3_RT": str,
                        "FEMALE_DEATH_YR3_RT": str,
                        "FEMALE_COMP_ORIG_YR3_RT": str,
                        "FEMALE_COMP_4YR_TRANS_YR3_RT": str,
                        "FEMALE_COMP_2YR_TRANS_YR3_RT": str,
                        "FEMALE_WDRAW_ORIG_YR3_RT": str,
                        "FEMALE_WDRAW_4YR_TRANS_YR3_RT": str,
                        "FEMALE_WDRAW_2YR_TRANS_YR3_RT": str,
                        "FEMALE_ENRL_ORIG_YR3_RT": str,
                        "FEMALE_ENRL_4YR_TRANS_YR3_RT": str,
                        "FEMALE_ENRL_2YR_TRANS_YR3_RT": str,
                        "FEMALE_UNKN_ORIG_YR3_RT": str,
                        "FEMALE_UNKN_4YR_TRANS_YR3_RT": str,
                        "FEMALE_UNKN_2YR_TRANS_YR3_RT": str,
                        "MALE_DEATH_YR3_RT": str,
                        "MALE_COMP_ORIG_YR3_RT": str,
                        "MALE_COMP_4YR_TRANS_YR3_RT": str,
                        "MALE_COMP_2YR_TRANS_YR3_RT": str,
                        "MALE_WDRAW_ORIG_YR3_RT": str,
                        "MALE_WDRAW_4YR_TRANS_YR3_RT": str,
                        "MALE_WDRAW_2YR_TRANS_YR3_RT": str,
                        "MALE_ENRL_ORIG_YR3_RT": str,
                        "MALE_ENRL_4YR_TRANS_YR3_RT": str,
                        "MALE_ENRL_2YR_TRANS_YR3_RT": str,
                        "MALE_UNKN_ORIG_YR3_RT": str,
                        "MALE_UNKN_4YR_TRANS_YR3_RT": str,
                        "MALE_UNKN_2YR_TRANS_YR3_RT": str,
                        "PELL_DEATH_YR3_RT": str,
                        "PELL_COMP_ORIG_YR3_RT": str,
                        "PELL_COMP_4YR_TRANS_YR3_RT": str,
                        "PELL_COMP_2YR_TRANS_YR3_RT": str,
                        "PELL_WDRAW_ORIG_YR3_RT": str,
                        "PELL_WDRAW_4YR_TRANS_YR3_RT": str,
                        "PELL_WDRAW_2YR_TRANS_YR3_RT": str,
                        "PELL_ENRL_ORIG_YR3_RT": str,
                        "PELL_ENRL_4YR_TRANS_YR3_RT": str,
                        "PELL_ENRL_2YR_TRANS_YR3_RT": str,
                        "PELL_UNKN_ORIG_YR3_RT": str,
                        "PELL_UNKN_4YR_TRANS_YR3_RT": str,
                        "PELL_UNKN_2YR_TRANS_YR3_RT": str,
                        "NOPELL_DEATH_YR3_RT": str,
                        "NOPELL_COMP_ORIG_YR3_RT": str,
                        "NOPELL_COMP_4YR_TRANS_YR3_RT": str,
                        "NOPELL_COMP_2YR_TRANS_YR3_RT": str,
                        "NOPELL_WDRAW_ORIG_YR3_RT": str,
                        "NOPELL_WDRAW_4YR_TRANS_YR3_RT": str,
                        "NOPELL_WDRAW_2YR_TRANS_YR3_RT": str,
                        "NOPELL_ENRL_ORIG_YR3_RT": str,
                        "NOPELL_ENRL_4YR_TRANS_YR3_RT": str,
                        "NOPELL_ENRL_2YR_TRANS_YR3_RT": str,
                        "NOPELL_UNKN_ORIG_YR3_RT": str,
                        "NOPELL_UNKN_4YR_TRANS_YR3_RT": str,
                        "NOPELL_UNKN_2YR_TRANS_YR3_RT": str,
                        "LOAN_DEATH_YR3_RT": str,
                        "LOAN_COMP_ORIG_YR3_RT": str,
                        "LOAN_COMP_4YR_TRANS_YR3_RT": str,
                        "LOAN_COMP_2YR_TRANS_YR3_RT": str,
                        "LOAN_WDRAW_ORIG_YR3_RT": str,
                        "LOAN_WDRAW_4YR_TRANS_YR3_RT": str,
                        "LOAN_WDRAW_2YR_TRANS_YR3_RT": str,
                        "LOAN_ENRL_ORIG_YR3_RT": str,
                        "LOAN_ENRL_4YR_TRANS_YR3_RT": str,
                        "LOAN_ENRL_2YR_TRANS_YR3_RT": str,
                        "LOAN_UNKN_ORIG_YR3_RT": str,
                        "LOAN_UNKN_4YR_TRANS_YR3_RT": str,
                        "LOAN_UNKN_2YR_TRANS_YR3_RT": str,
                        "NOLOAN_DEATH_YR3_RT": str,
                        "NOLOAN_COMP_ORIG_YR3_RT": str,
                        "NOLOAN_COMP_4YR_TRANS_YR3_RT": str,
                        "NOLOAN_COMP_2YR_TRANS_YR3_RT": str,
                        "NOLOAN_WDRAW_ORIG_YR3_RT": str,
                        "NOLOAN_WDRAW_4YR_TRANS_YR3_RT": str,
                        "NOLOAN_WDRAW_2YR_TRANS_YR3_RT": str,
                        "NOLOAN_ENRL_ORIG_YR3_RT": str,
                        "NOLOAN_ENRL_4YR_TRANS_YR3_RT": str,
                        "NOLOAN_ENRL_2YR_TRANS_YR3_RT": str,
                        "NOLOAN_UNKN_ORIG_YR3_RT": str,
                        "NOLOAN_UNKN_4YR_TRANS_YR3_RT": str,
                        "NOLOAN_UNKN_2YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_DEATH_YR3_RT": str,
                        "FIRSTGEN_COMP_ORIG_YR3_RT": str,
                        "FIRSTGEN_COMP_4YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_COMP_2YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_WDRAW_ORIG_YR3_RT": str,
                        "FIRSTGEN_WDRAW_4YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_WDRAW_2YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_ENRL_ORIG_YR3_RT": str,
                        "FIRSTGEN_ENRL_4YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_ENRL_2YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_UNKN_ORIG_YR3_RT": str,
                        "FIRSTGEN_UNKN_4YR_TRANS_YR3_RT": str,
                        "FIRSTGEN_UNKN_2YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_DEATH_YR3_RT": str,
                        "NOT1STGEN_COMP_ORIG_YR3_RT": str,
                        "NOT1STGEN_COMP_4YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_COMP_2YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_WDRAW_ORIG_YR3_RT": str,
                        "NOT1STGEN_WDRAW_4YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_WDRAW_2YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_ENRL_ORIG_YR3_RT": str,
                        "NOT1STGEN_ENRL_4YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_ENRL_2YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_UNKN_ORIG_YR3_RT": str,
                        "NOT1STGEN_UNKN_4YR_TRANS_YR3_RT": str,
                        "NOT1STGEN_UNKN_2YR_TRANS_YR3_RT": str,
                        "DEATH_YR4_RT": str,
                        "COMP_ORIG_YR4_RT": str,
                        "COMP_4YR_TRANS_YR4_RT": str,
                        "COMP_2YR_TRANS_YR4_RT": str,
                        "WDRAW_ORIG_YR4_RT": str,
                        "WDRAW_4YR_TRANS_YR4_RT": str,
                        "WDRAW_2YR_TRANS_YR4_RT": str,
                        "ENRL_ORIG_YR4_RT": str,
                        "ENRL_4YR_TRANS_YR4_RT": str,
                        "ENRL_2YR_TRANS_YR4_RT": str,
                        "UNKN_ORIG_YR4_RT": str,
                        "UNKN_4YR_TRANS_YR4_RT": str,
                        "UNKN_2YR_TRANS_YR4_RT": str,
                        "LO_INC_DEATH_YR4_RT": str,
                        "LO_INC_COMP_ORIG_YR4_RT": str,
                        "LO_INC_COMP_4YR_TRANS_YR4_RT": str,
                        "LO_INC_COMP_2YR_TRANS_YR4_RT": str,
                        "LO_INC_WDRAW_ORIG_YR4_RT": str,
                        "LO_INC_WDRAW_4YR_TRANS_YR4_RT": str,
                        "LO_INC_WDRAW_2YR_TRANS_YR4_RT": str,
                        "LO_INC_ENRL_ORIG_YR4_RT": str,
                        "LO_INC_ENRL_4YR_TRANS_YR4_RT": str,
                        "LO_INC_ENRL_2YR_TRANS_YR4_RT": str,
                        "LO_INC_UNKN_ORIG_YR4_RT": str,
                        "LO_INC_UNKN_4YR_TRANS_YR4_RT": str,
                        "LO_INC_UNKN_2YR_TRANS_YR4_RT": str,
                        "MD_INC_DEATH_YR4_RT": str,
                        "MD_INC_COMP_ORIG_YR4_RT": str,
                        "MD_INC_COMP_4YR_TRANS_YR4_RT": str,
                        "MD_INC_COMP_2YR_TRANS_YR4_RT": str,
                        "MD_INC_WDRAW_ORIG_YR4_RT": str,
                        "MD_INC_WDRAW_4YR_TRANS_YR4_RT": str,
                        "MD_INC_WDRAW_2YR_TRANS_YR4_RT": str,
                        "MD_INC_ENRL_ORIG_YR4_RT": str,
                        "MD_INC_ENRL_4YR_TRANS_YR4_RT": str,
                        "MD_INC_ENRL_2YR_TRANS_YR4_RT": str,
                        "MD_INC_UNKN_ORIG_YR4_RT": str,
                        "MD_INC_UNKN_4YR_TRANS_YR4_RT": str,
                        "MD_INC_UNKN_2YR_TRANS_YR4_RT": str,
                        "HI_INC_DEATH_YR4_RT": str,
                        "HI_INC_COMP_ORIG_YR4_RT": str,
                        "HI_INC_COMP_4YR_TRANS_YR4_RT": str,
                        "HI_INC_COMP_2YR_TRANS_YR4_RT": str,
                        "HI_INC_WDRAW_ORIG_YR4_RT": str,
                        "HI_INC_WDRAW_4YR_TRANS_YR4_RT": str,
                        "HI_INC_WDRAW_2YR_TRANS_YR4_RT": str,
                        "HI_INC_ENRL_ORIG_YR4_RT": str,
                        "HI_INC_ENRL_4YR_TRANS_YR4_RT": str,
                        "HI_INC_ENRL_2YR_TRANS_YR4_RT": str,
                        "HI_INC_UNKN_ORIG_YR4_RT": str,
                        "HI_INC_UNKN_4YR_TRANS_YR4_RT": str,
                        "HI_INC_UNKN_2YR_TRANS_YR4_RT": str,
                        "DEP_DEATH_YR4_RT": str,
                        "DEP_COMP_ORIG_YR4_RT": str,
                        "DEP_COMP_4YR_TRANS_YR4_RT": str,
                        "DEP_COMP_2YR_TRANS_YR4_RT": str,
                        "DEP_WDRAW_ORIG_YR4_RT": str,
                        "DEP_WDRAW_4YR_TRANS_YR4_RT": str,
                        "DEP_WDRAW_2YR_TRANS_YR4_RT": str,
                        "DEP_ENRL_ORIG_YR4_RT": str,
                        "DEP_ENRL_4YR_TRANS_YR4_RT": str,
                        "DEP_ENRL_2YR_TRANS_YR4_RT": str,
                        "DEP_UNKN_ORIG_YR4_RT": str,
                        "DEP_UNKN_4YR_TRANS_YR4_RT": str,
                        "DEP_UNKN_2YR_TRANS_YR4_RT": str,
                        "IND_DEATH_YR4_RT": str,
                        "IND_COMP_ORIG_YR4_RT": str,
                        "IND_COMP_4YR_TRANS_YR4_RT": str,
                        "IND_COMP_2YR_TRANS_YR4_RT": str,
                        "IND_WDRAW_ORIG_YR4_RT": str,
                        "IND_WDRAW_4YR_TRANS_YR4_RT": str,
                        "IND_WDRAW_2YR_TRANS_YR4_RT": str,
                        "IND_ENRL_ORIG_YR4_RT": str,
                        "IND_ENRL_4YR_TRANS_YR4_RT": str,
                        "IND_ENRL_2YR_TRANS_YR4_RT": str,
                        "IND_UNKN_ORIG_YR4_RT": str,
                        "IND_UNKN_4YR_TRANS_YR4_RT": str,
                        "IND_UNKN_2YR_TRANS_YR4_RT": str,
                        "FEMALE_DEATH_YR4_RT": str,
                        "FEMALE_COMP_ORIG_YR4_RT": str,
                        "FEMALE_COMP_4YR_TRANS_YR4_RT": str,
                        "FEMALE_COMP_2YR_TRANS_YR4_RT": str,
                        "FEMALE_WDRAW_ORIG_YR4_RT": str,
                        "FEMALE_WDRAW_4YR_TRANS_YR4_RT": str,
                        "FEMALE_WDRAW_2YR_TRANS_YR4_RT": str,
                        "FEMALE_ENRL_ORIG_YR4_RT": str,
                        "FEMALE_ENRL_4YR_TRANS_YR4_RT": str,
                        "FEMALE_ENRL_2YR_TRANS_YR4_RT": str,
                        "FEMALE_UNKN_ORIG_YR4_RT": str,
                        "FEMALE_UNKN_4YR_TRANS_YR4_RT": str,
                        "FEMALE_UNKN_2YR_TRANS_YR4_RT": str,
                        "MALE_DEATH_YR4_RT": str,
                        "MALE_COMP_ORIG_YR4_RT": str,
                        "MALE_COMP_4YR_TRANS_YR4_RT": str,
                        "MALE_COMP_2YR_TRANS_YR4_RT": str,
                        "MALE_WDRAW_ORIG_YR4_RT": str,
                        "MALE_WDRAW_4YR_TRANS_YR4_RT": str,
                        "MALE_WDRAW_2YR_TRANS_YR4_RT": str,
                        "MALE_ENRL_ORIG_YR4_RT": str,
                        "MALE_ENRL_4YR_TRANS_YR4_RT": str,
                        "MALE_ENRL_2YR_TRANS_YR4_RT": str,
                        "MALE_UNKN_ORIG_YR4_RT": str,
                        "MALE_UNKN_4YR_TRANS_YR4_RT": str,
                        "MALE_UNKN_2YR_TRANS_YR4_RT": str,
                        "PELL_DEATH_YR4_RT": str,
                        "PELL_COMP_ORIG_YR4_RT": str,
                        "PELL_COMP_4YR_TRANS_YR4_RT": str,
                        "PELL_COMP_2YR_TRANS_YR4_RT": str,
                        "PELL_WDRAW_ORIG_YR4_RT": str,
                        "PELL_WDRAW_4YR_TRANS_YR4_RT": str,
                        "PELL_WDRAW_2YR_TRANS_YR4_RT": str,
                        "PELL_ENRL_ORIG_YR4_RT": str,
                        "PELL_ENRL_4YR_TRANS_YR4_RT": str,
                        "PELL_ENRL_2YR_TRANS_YR4_RT": str,
                        "PELL_UNKN_ORIG_YR4_RT": str,
                        "PELL_UNKN_4YR_TRANS_YR4_RT": str,
                        "PELL_UNKN_2YR_TRANS_YR4_RT": str,
                        "NOPELL_DEATH_YR4_RT": str,
                        "NOPELL_COMP_ORIG_YR4_RT": str,
                        "NOPELL_COMP_4YR_TRANS_YR4_RT": str,
                        "NOPELL_COMP_2YR_TRANS_YR4_RT": str,
                        "NOPELL_WDRAW_ORIG_YR4_RT": str,
                        "NOPELL_WDRAW_4YR_TRANS_YR4_RT": str,
                        "NOPELL_WDRAW_2YR_TRANS_YR4_RT": str,
                        "NOPELL_ENRL_ORIG_YR4_RT": str,
                        "NOPELL_ENRL_4YR_TRANS_YR4_RT": str,
                        "NOPELL_ENRL_2YR_TRANS_YR4_RT": str,
                        "NOPELL_UNKN_ORIG_YR4_RT": str,
                        "NOPELL_UNKN_4YR_TRANS_YR4_RT": str,
                        "NOPELL_UNKN_2YR_TRANS_YR4_RT": str,
                        "LOAN_DEATH_YR4_RT": str,
                        "LOAN_COMP_ORIG_YR4_RT": str,
                        "LOAN_COMP_4YR_TRANS_YR4_RT": str,
                        "LOAN_COMP_2YR_TRANS_YR4_RT": str,
                        "LOAN_WDRAW_ORIG_YR4_RT": str,
                        "LOAN_WDRAW_4YR_TRANS_YR4_RT": str,
                        "LOAN_WDRAW_2YR_TRANS_YR4_RT": str,
                        "LOAN_ENRL_ORIG_YR4_RT": str,
                        "LOAN_ENRL_4YR_TRANS_YR4_RT": str,
                        "LOAN_ENRL_2YR_TRANS_YR4_RT": str,
                        "LOAN_UNKN_ORIG_YR4_RT": str,
                        "LOAN_UNKN_4YR_TRANS_YR4_RT": str,
                        "LOAN_UNKN_2YR_TRANS_YR4_RT": str,
                        "NOLOAN_DEATH_YR4_RT": str,
                        "NOLOAN_COMP_ORIG_YR4_RT": str,
                        "NOLOAN_COMP_4YR_TRANS_YR4_RT": str,
                        "NOLOAN_COMP_2YR_TRANS_YR4_RT": str,
                        "NOLOAN_WDRAW_ORIG_YR4_RT": str,
                        "NOLOAN_WDRAW_4YR_TRANS_YR4_RT": str,
                        "NOLOAN_WDRAW_2YR_TRANS_YR4_RT": str,
                        "NOLOAN_ENRL_ORIG_YR4_RT": str,
                        "NOLOAN_ENRL_4YR_TRANS_YR4_RT": str,
                        "NOLOAN_ENRL_2YR_TRANS_YR4_RT": str,
                        "NOLOAN_UNKN_ORIG_YR4_RT": str,
                        "NOLOAN_UNKN_4YR_TRANS_YR4_RT": str,
                        "NOLOAN_UNKN_2YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_DEATH_YR4_RT": str,
                        "FIRSTGEN_COMP_ORIG_YR4_RT": str,
                        "FIRSTGEN_COMP_4YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_COMP_2YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_WDRAW_ORIG_YR4_RT": str,
                        "FIRSTGEN_WDRAW_4YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_WDRAW_2YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_ENRL_ORIG_YR4_RT": str,
                        "FIRSTGEN_ENRL_4YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_ENRL_2YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_UNKN_ORIG_YR4_RT": str,
                        "FIRSTGEN_UNKN_4YR_TRANS_YR4_RT": str,
                        "FIRSTGEN_UNKN_2YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_DEATH_YR4_RT": str,
                        "NOT1STGEN_COMP_ORIG_YR4_RT": str,
                        "NOT1STGEN_COMP_4YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_COMP_2YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_WDRAW_ORIG_YR4_RT": str,
                        "NOT1STGEN_WDRAW_4YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_WDRAW_2YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_ENRL_ORIG_YR4_RT": str,
                        "NOT1STGEN_ENRL_4YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_ENRL_2YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_UNKN_ORIG_YR4_RT": str,
                        "NOT1STGEN_UNKN_4YR_TRANS_YR4_RT": str,
                        "NOT1STGEN_UNKN_2YR_TRANS_YR4_RT": str,
                        "DEATH_YR6_RT": str,
                        "COMP_ORIG_YR6_RT": str,
                        "COMP_4YR_TRANS_YR6_RT": str,
                        "COMP_2YR_TRANS_YR6_RT": str,
                        "WDRAW_ORIG_YR6_RT": str,
                        "WDRAW_4YR_TRANS_YR6_RT": str,
                        "WDRAW_2YR_TRANS_YR6_RT": str,
                        "ENRL_ORIG_YR6_RT": str,
                        "ENRL_4YR_TRANS_YR6_RT": str,
                        "ENRL_2YR_TRANS_YR6_RT": str,
                        "UNKN_ORIG_YR6_RT": str,
                        "UNKN_4YR_TRANS_YR6_RT": str,
                        "UNKN_2YR_TRANS_YR6_RT": str,
                        "LO_INC_DEATH_YR6_RT": str,
                        "LO_INC_COMP_ORIG_YR6_RT": str,
                        "LO_INC_COMP_4YR_TRANS_YR6_RT": str,
                        "LO_INC_COMP_2YR_TRANS_YR6_RT": str,
                        "LO_INC_WDRAW_ORIG_YR6_RT": str,
                        "LO_INC_WDRAW_4YR_TRANS_YR6_RT": str,
                        "LO_INC_WDRAW_2YR_TRANS_YR6_RT": str,
                        "LO_INC_ENRL_ORIG_YR6_RT": str,
                        "LO_INC_ENRL_4YR_TRANS_YR6_RT": str,
                        "LO_INC_ENRL_2YR_TRANS_YR6_RT": str,
                        "LO_INC_UNKN_ORIG_YR6_RT": str,
                        "LO_INC_UNKN_4YR_TRANS_YR6_RT": str,
                        "LO_INC_UNKN_2YR_TRANS_YR6_RT": str,
                        "MD_INC_DEATH_YR6_RT": str,
                        "MD_INC_COMP_ORIG_YR6_RT": str,
                        "MD_INC_COMP_4YR_TRANS_YR6_RT": str,
                        "MD_INC_COMP_2YR_TRANS_YR6_RT": str,
                        "MD_INC_WDRAW_ORIG_YR6_RT": str,
                        "MD_INC_WDRAW_4YR_TRANS_YR6_RT": str,
                        "MD_INC_WDRAW_2YR_TRANS_YR6_RT": str,
                        "MD_INC_ENRL_ORIG_YR6_RT": str,
                        "MD_INC_ENRL_4YR_TRANS_YR6_RT": str,
                        "MD_INC_ENRL_2YR_TRANS_YR6_RT": str,
                        "MD_INC_UNKN_ORIG_YR6_RT": str,
                        "MD_INC_UNKN_4YR_TRANS_YR6_RT": str,
                        "MD_INC_UNKN_2YR_TRANS_YR6_RT": str,
                        "HI_INC_DEATH_YR6_RT": str,
                        "HI_INC_COMP_ORIG_YR6_RT": str,
                        "HI_INC_COMP_4YR_TRANS_YR6_RT": str,
                        "HI_INC_COMP_2YR_TRANS_YR6_RT": str,
                        "HI_INC_WDRAW_ORIG_YR6_RT": str,
                        "HI_INC_WDRAW_4YR_TRANS_YR6_RT": str,
                        "HI_INC_WDRAW_2YR_TRANS_YR6_RT": str,
                        "HI_INC_ENRL_ORIG_YR6_RT": str,
                        "HI_INC_ENRL_4YR_TRANS_YR6_RT": str,
                        "HI_INC_ENRL_2YR_TRANS_YR6_RT": str,
                        "HI_INC_UNKN_ORIG_YR6_RT": str,
                        "HI_INC_UNKN_4YR_TRANS_YR6_RT": str,
                        "HI_INC_UNKN_2YR_TRANS_YR6_RT": str,
                        "DEP_DEATH_YR6_RT": str,
                        "DEP_COMP_ORIG_YR6_RT": str,
                        "DEP_COMP_4YR_TRANS_YR6_RT": str,
                        "DEP_COMP_2YR_TRANS_YR6_RT": str,
                        "DEP_WDRAW_ORIG_YR6_RT": str,
                        "DEP_WDRAW_4YR_TRANS_YR6_RT": str,
                        "DEP_WDRAW_2YR_TRANS_YR6_RT": str,
                        "DEP_ENRL_ORIG_YR6_RT": str,
                        "DEP_ENRL_4YR_TRANS_YR6_RT": str,
                        "DEP_ENRL_2YR_TRANS_YR6_RT": str,
                        "DEP_UNKN_ORIG_YR6_RT": str,
                        "DEP_UNKN_4YR_TRANS_YR6_RT": str,
                        "DEP_UNKN_2YR_TRANS_YR6_RT": str,
                        "IND_DEATH_YR6_RT": str,
                        "IND_COMP_ORIG_YR6_RT": str,
                        "IND_COMP_4YR_TRANS_YR6_RT": str,
                        "IND_COMP_2YR_TRANS_YR6_RT": str,
                        "IND_WDRAW_ORIG_YR6_RT": str,
                        "IND_WDRAW_4YR_TRANS_YR6_RT": str,
                        "IND_WDRAW_2YR_TRANS_YR6_RT": str,
                        "IND_ENRL_ORIG_YR6_RT": str,
                        "IND_ENRL_4YR_TRANS_YR6_RT": str,
                        "IND_ENRL_2YR_TRANS_YR6_RT": str,
                        "IND_UNKN_ORIG_YR6_RT": str,
                        "IND_UNKN_4YR_TRANS_YR6_RT": str,
                        "IND_UNKN_2YR_TRANS_YR6_RT": str,
                        "FEMALE_DEATH_YR6_RT": str,
                        "FEMALE_COMP_ORIG_YR6_RT": str,
                        "FEMALE_COMP_4YR_TRANS_YR6_RT": str,
                        "FEMALE_COMP_2YR_TRANS_YR6_RT": str,
                        "FEMALE_WDRAW_ORIG_YR6_RT": str,
                        "FEMALE_WDRAW_4YR_TRANS_YR6_RT": str,
                        "FEMALE_WDRAW_2YR_TRANS_YR6_RT": str,
                        "FEMALE_ENRL_ORIG_YR6_RT": str,
                        "FEMALE_ENRL_4YR_TRANS_YR6_RT": str,
                        "FEMALE_ENRL_2YR_TRANS_YR6_RT": str,
                        "FEMALE_UNKN_ORIG_YR6_RT": str,
                        "FEMALE_UNKN_4YR_TRANS_YR6_RT": str,
                        "FEMALE_UNKN_2YR_TRANS_YR6_RT": str,
                        "MALE_DEATH_YR6_RT": str,
                        "MALE_COMP_ORIG_YR6_RT": str,
                        "MALE_COMP_4YR_TRANS_YR6_RT": str,
                        "MALE_COMP_2YR_TRANS_YR6_RT": str,
                        "MALE_WDRAW_ORIG_YR6_RT": str,
                        "MALE_WDRAW_4YR_TRANS_YR6_RT": str,
                        "MALE_WDRAW_2YR_TRANS_YR6_RT": str,
                        "MALE_ENRL_ORIG_YR6_RT": str,
                        "MALE_ENRL_4YR_TRANS_YR6_RT": str,
                        "MALE_ENRL_2YR_TRANS_YR6_RT": str,
                        "MALE_UNKN_ORIG_YR6_RT": str,
                        "MALE_UNKN_4YR_TRANS_YR6_RT": str,
                        "MALE_UNKN_2YR_TRANS_YR6_RT": str,
                        "PELL_DEATH_YR6_RT": str,
                        "PELL_COMP_ORIG_YR6_RT": str,
                        "PELL_COMP_4YR_TRANS_YR6_RT": str,
                        "PELL_COMP_2YR_TRANS_YR6_RT": str,
                        "PELL_WDRAW_ORIG_YR6_RT": str,
                        "PELL_WDRAW_4YR_TRANS_YR6_RT": str,
                        "PELL_WDRAW_2YR_TRANS_YR6_RT": str,
                        "PELL_ENRL_ORIG_YR6_RT": str,
                        "PELL_ENRL_4YR_TRANS_YR6_RT": str,
                        "PELL_ENRL_2YR_TRANS_YR6_RT": str,
                        "PELL_UNKN_ORIG_YR6_RT": str,
                        "PELL_UNKN_4YR_TRANS_YR6_RT": str,
                        "PELL_UNKN_2YR_TRANS_YR6_RT": str,
                        "NOPELL_DEATH_YR6_RT": str,
                        "NOPELL_COMP_ORIG_YR6_RT": str,
                        "NOPELL_COMP_4YR_TRANS_YR6_RT": str,
                        "NOPELL_COMP_2YR_TRANS_YR6_RT": str,
                        "NOPELL_WDRAW_ORIG_YR6_RT": str,
                        "NOPELL_WDRAW_4YR_TRANS_YR6_RT": str,
                        "NOPELL_WDRAW_2YR_TRANS_YR6_RT": str,
                        "NOPELL_ENRL_ORIG_YR6_RT": str,
                        "NOPELL_ENRL_4YR_TRANS_YR6_RT": str,
                        "NOPELL_ENRL_2YR_TRANS_YR6_RT": str,
                        "NOPELL_UNKN_ORIG_YR6_RT": str,
                        "NOPELL_UNKN_4YR_TRANS_YR6_RT": str,
                        "NOPELL_UNKN_2YR_TRANS_YR6_RT": str,
                        "LOAN_DEATH_YR6_RT": str,
                        "LOAN_COMP_ORIG_YR6_RT": str,
                        "LOAN_COMP_4YR_TRANS_YR6_RT": str,
                        "LOAN_COMP_2YR_TRANS_YR6_RT": str,
                        "LOAN_WDRAW_ORIG_YR6_RT": str,
                        "LOAN_WDRAW_4YR_TRANS_YR6_RT": str,
                        "LOAN_WDRAW_2YR_TRANS_YR6_RT": str,
                        "LOAN_ENRL_ORIG_YR6_RT": str,
                        "LOAN_ENRL_4YR_TRANS_YR6_RT": str,
                        "LOAN_ENRL_2YR_TRANS_YR6_RT": str,
                        "LOAN_UNKN_ORIG_YR6_RT": str,
                        "LOAN_UNKN_4YR_TRANS_YR6_RT": str,
                        "LOAN_UNKN_2YR_TRANS_YR6_RT": str,
                        "NOLOAN_DEATH_YR6_RT": str,
                        "NOLOAN_COMP_ORIG_YR6_RT": str,
                        "NOLOAN_COMP_4YR_TRANS_YR6_RT": str,
                        "NOLOAN_COMP_2YR_TRANS_YR6_RT": str,
                        "NOLOAN_WDRAW_ORIG_YR6_RT": str,
                        "NOLOAN_WDRAW_4YR_TRANS_YR6_RT": str,
                        "NOLOAN_WDRAW_2YR_TRANS_YR6_RT": str,
                        "NOLOAN_ENRL_ORIG_YR6_RT": str,
                        "NOLOAN_ENRL_4YR_TRANS_YR6_RT": str,
                        "NOLOAN_ENRL_2YR_TRANS_YR6_RT": str,
                        "NOLOAN_UNKN_ORIG_YR6_RT": str,
                        "NOLOAN_UNKN_4YR_TRANS_YR6_RT": str,
                        "NOLOAN_UNKN_2YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_DEATH_YR6_RT": str,
                        "FIRSTGEN_COMP_ORIG_YR6_RT": str,
                        "FIRSTGEN_COMP_4YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_COMP_2YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_WDRAW_ORIG_YR6_RT": str,
                        "FIRSTGEN_WDRAW_4YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_WDRAW_2YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_ENRL_ORIG_YR6_RT": str,
                        "FIRSTGEN_ENRL_4YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_ENRL_2YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_UNKN_ORIG_YR6_RT": str,
                        "FIRSTGEN_UNKN_4YR_TRANS_YR6_RT": str,
                        "FIRSTGEN_UNKN_2YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_DEATH_YR6_RT": str,
                        "NOT1STGEN_COMP_ORIG_YR6_RT": str,
                        "NOT1STGEN_COMP_4YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_COMP_2YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_WDRAW_ORIG_YR6_RT": str,
                        "NOT1STGEN_WDRAW_4YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_WDRAW_2YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_ENRL_ORIG_YR6_RT": str,
                        "NOT1STGEN_ENRL_4YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_ENRL_2YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_UNKN_ORIG_YR6_RT": str,
                        "NOT1STGEN_UNKN_4YR_TRANS_YR6_RT": str,
                        "NOT1STGEN_UNKN_2YR_TRANS_YR6_RT": str,
                        "DEATH_YR8_RT": str,
                        "COMP_ORIG_YR8_RT": str,
                        "COMP_4YR_TRANS_YR8_RT": str,
                        "COMP_2YR_TRANS_YR8_RT": str,
                        "WDRAW_ORIG_YR8_RT": str,
                        "WDRAW_4YR_TRANS_YR8_RT": str,
                        "WDRAW_2YR_TRANS_YR8_RT": str,
                        "ENRL_ORIG_YR8_RT": str,
                        "ENRL_4YR_TRANS_YR8_RT": str,
                        "ENRL_2YR_TRANS_YR8_RT": str,
                        "UNKN_ORIG_YR8_RT": str,
                        "UNKN_4YR_TRANS_YR8_RT": str,
                        "UNKN_2YR_TRANS_YR8_RT": str,
                        "LO_INC_DEATH_YR8_RT": str,
                        "LO_INC_COMP_ORIG_YR8_RT": str,
                        "LO_INC_COMP_4YR_TRANS_YR8_RT": str,
                        "LO_INC_COMP_2YR_TRANS_YR8_RT": str,
                        "LO_INC_WDRAW_ORIG_YR8_RT": str,
                        "LO_INC_WDRAW_4YR_TRANS_YR8_RT": str,
                        "LO_INC_WDRAW_2YR_TRANS_YR8_RT": str,
                        "LO_INC_ENRL_ORIG_YR8_RT": str,
                        "LO_INC_ENRL_4YR_TRANS_YR8_RT": str,
                        "LO_INC_ENRL_2YR_TRANS_YR8_RT": str,
                        "LO_INC_UNKN_ORIG_YR8_RT": str,
                        "LO_INC_UNKN_4YR_TRANS_YR8_RT": str,
                        "LO_INC_UNKN_2YR_TRANS_YR8_RT": str,
                        "MD_INC_DEATH_YR8_RT": str,
                        "MD_INC_COMP_ORIG_YR8_RT": str,
                        "MD_INC_COMP_4YR_TRANS_YR8_RT": str,
                        "MD_INC_COMP_2YR_TRANS_YR8_RT": str,
                        "MD_INC_WDRAW_ORIG_YR8_RT": str,
                        "MD_INC_WDRAW_4YR_TRANS_YR8_RT": str,
                        "MD_INC_WDRAW_2YR_TRANS_YR8_RT": str,
                        "MD_INC_ENRL_ORIG_YR8_RT": str,
                        "MD_INC_ENRL_4YR_TRANS_YR8_RT": str,
                        "MD_INC_ENRL_2YR_TRANS_YR8_RT": str,
                        "MD_INC_UNKN_ORIG_YR8_RT": str,
                        "MD_INC_UNKN_4YR_TRANS_YR8_RT": str,
                        "MD_INC_UNKN_2YR_TRANS_YR8_RT": str,
                        "HI_INC_DEATH_YR8_RT": str,
                        "HI_INC_COMP_ORIG_YR8_RT": str,
                        "HI_INC_COMP_4YR_TRANS_YR8_RT": str,
                        "HI_INC_COMP_2YR_TRANS_YR8_RT": str,
                        "HI_INC_WDRAW_ORIG_YR8_RT": str,
                        "HI_INC_WDRAW_4YR_TRANS_YR8_RT": str,
                        "HI_INC_WDRAW_2YR_TRANS_YR8_RT": str,
                        "HI_INC_ENRL_ORIG_YR8_RT": str,
                        "HI_INC_ENRL_4YR_TRANS_YR8_RT": str,
                        "HI_INC_ENRL_2YR_TRANS_YR8_RT": str,
                        "HI_INC_UNKN_ORIG_YR8_RT": str,
                        "HI_INC_UNKN_4YR_TRANS_YR8_RT": str,
                        "HI_INC_UNKN_2YR_TRANS_YR8_RT": str,
                        "DEP_DEATH_YR8_RT": str,
                        "DEP_COMP_ORIG_YR8_RT": str,
                        "DEP_COMP_4YR_TRANS_YR8_RT": str,
                        "DEP_COMP_2YR_TRANS_YR8_RT": str,
                        "DEP_WDRAW_ORIG_YR8_RT": str,
                        "DEP_WDRAW_4YR_TRANS_YR8_RT": str,
                        "DEP_WDRAW_2YR_TRANS_YR8_RT": str,
                        "DEP_ENRL_ORIG_YR8_RT": str,
                        "DEP_ENRL_4YR_TRANS_YR8_RT": str,
                        "DEP_ENRL_2YR_TRANS_YR8_RT": str,
                        "DEP_UNKN_ORIG_YR8_RT": str,
                        "DEP_UNKN_4YR_TRANS_YR8_RT": str,
                        "DEP_UNKN_2YR_TRANS_YR8_RT": str,
                        "IND_DEATH_YR8_RT": str,
                        "IND_COMP_ORIG_YR8_RT": str,
                        "IND_COMP_4YR_TRANS_YR8_RT": str,
                        "IND_COMP_2YR_TRANS_YR8_RT": str,
                        "IND_WDRAW_ORIG_YR8_RT": str,
                        "IND_WDRAW_4YR_TRANS_YR8_RT": str,
                        "IND_WDRAW_2YR_TRANS_YR8_RT": str,
                        "IND_ENRL_ORIG_YR8_RT": str,
                        "IND_ENRL_4YR_TRANS_YR8_RT": str,
                        "IND_ENRL_2YR_TRANS_YR8_RT": str,
                        "IND_UNKN_ORIG_YR8_RT": str,
                        "IND_UNKN_4YR_TRANS_YR8_RT": str,
                        "IND_UNKN_2YR_TRANS_YR8_RT": str,
                        "FEMALE_DEATH_YR8_RT": str,
                        "FEMALE_COMP_ORIG_YR8_RT": str,
                        "FEMALE_COMP_4YR_TRANS_YR8_RT": str,
                        "FEMALE_COMP_2YR_TRANS_YR8_RT": str,
                        "FEMALE_WDRAW_ORIG_YR8_RT": str,
                        "FEMALE_WDRAW_4YR_TRANS_YR8_RT": str,
                        "FEMALE_WDRAW_2YR_TRANS_YR8_RT": str,
                        "FEMALE_ENRL_ORIG_YR8_RT": str,
                        "FEMALE_ENRL_4YR_TRANS_YR8_RT": str,
                        "FEMALE_ENRL_2YR_TRANS_YR8_RT": str,
                        "FEMALE_UNKN_ORIG_YR8_RT": str,
                        "FEMALE_UNKN_4YR_TRANS_YR8_RT": str,
                        "FEMALE_UNKN_2YR_TRANS_YR8_RT": str,
                        "MALE_DEATH_YR8_RT": str,
                        "MALE_COMP_ORIG_YR8_RT": str,
                        "MALE_COMP_4YR_TRANS_YR8_RT": str,
                        "MALE_COMP_2YR_TRANS_YR8_RT": str,
                        "MALE_WDRAW_ORIG_YR8_RT": str,
                        "MALE_WDRAW_4YR_TRANS_YR8_RT": str,
                        "MALE_WDRAW_2YR_TRANS_YR8_RT": str,
                        "MALE_ENRL_ORIG_YR8_RT": str,
                        "MALE_ENRL_4YR_TRANS_YR8_RT": str,
                        "MALE_ENRL_2YR_TRANS_YR8_RT": str,
                        "MALE_UNKN_ORIG_YR8_RT": str,
                        "MALE_UNKN_4YR_TRANS_YR8_RT": str,
                        "MALE_UNKN_2YR_TRANS_YR8_RT": str,
                        "PELL_DEATH_YR8_RT": str,
                        "PELL_COMP_ORIG_YR8_RT": str,
                        "PELL_COMP_4YR_TRANS_YR8_RT": str,
                        "PELL_COMP_2YR_TRANS_YR8_RT": str,
                        "PELL_WDRAW_ORIG_YR8_RT": str,
                        "PELL_WDRAW_4YR_TRANS_YR8_RT": str,
                        "PELL_WDRAW_2YR_TRANS_YR8_RT": str,
                        "PELL_ENRL_ORIG_YR8_RT": str,
                        "PELL_ENRL_4YR_TRANS_YR8_RT": str,
                        "PELL_ENRL_2YR_TRANS_YR8_RT": str,
                        "PELL_UNKN_ORIG_YR8_RT": str,
                        "PELL_UNKN_4YR_TRANS_YR8_RT": str,
                        "PELL_UNKN_2YR_TRANS_YR8_RT": str,
                        "NOPELL_DEATH_YR8_RT": str,
                        "NOPELL_COMP_ORIG_YR8_RT": str,
                        "NOPELL_COMP_4YR_TRANS_YR8_RT": str,
                        "NOPELL_COMP_2YR_TRANS_YR8_RT": str,
                        "NOPELL_WDRAW_ORIG_YR8_RT": str,
                        "NOPELL_WDRAW_4YR_TRANS_YR8_RT": str,
                        "NOPELL_WDRAW_2YR_TRANS_YR8_RT": str,
                        "NOPELL_ENRL_ORIG_YR8_RT": str,
                        "NOPELL_ENRL_4YR_TRANS_YR8_RT": str,
                        "NOPELL_ENRL_2YR_TRANS_YR8_RT": str,
                        "NOPELL_UNKN_ORIG_YR8_RT": str,
                        "NOPELL_UNKN_4YR_TRANS_YR8_RT": str,
                        "NOPELL_UNKN_2YR_TRANS_YR8_RT": str,
                        "LOAN_DEATH_YR8_RT": str,
                        "LOAN_COMP_ORIG_YR8_RT": str,
                        "LOAN_COMP_4YR_TRANS_YR8_RT": str,
                        "LOAN_COMP_2YR_TRANS_YR8_RT": str,
                        "LOAN_WDRAW_ORIG_YR8_RT": str,
                        "LOAN_WDRAW_4YR_TRANS_YR8_RT": str,
                        "LOAN_WDRAW_2YR_TRANS_YR8_RT": str,
                        "LOAN_ENRL_ORIG_YR8_RT": str,
                        "LOAN_ENRL_4YR_TRANS_YR8_RT": str,
                        "LOAN_ENRL_2YR_TRANS_YR8_RT": str,
                        "LOAN_UNKN_ORIG_YR8_RT": str,
                        "LOAN_UNKN_4YR_TRANS_YR8_RT": str,
                        "LOAN_UNKN_2YR_TRANS_YR8_RT": str,
                        "NOLOAN_DEATH_YR8_RT": str,
                        "NOLOAN_COMP_ORIG_YR8_RT": str,
                        "NOLOAN_COMP_4YR_TRANS_YR8_RT": str,
                        "NOLOAN_COMP_2YR_TRANS_YR8_RT": str,
                        "NOLOAN_WDRAW_ORIG_YR8_RT": str,
                        "NOLOAN_WDRAW_4YR_TRANS_YR8_RT": str,
                        "NOLOAN_WDRAW_2YR_TRANS_YR8_RT": str,
                        "NOLOAN_ENRL_ORIG_YR8_RT": str,
                        "NOLOAN_ENRL_4YR_TRANS_YR8_RT": str,
                        "NOLOAN_ENRL_2YR_TRANS_YR8_RT": str,
                        "NOLOAN_UNKN_ORIG_YR8_RT": str,
                        "NOLOAN_UNKN_4YR_TRANS_YR8_RT": str,
                        "NOLOAN_UNKN_2YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_DEATH_YR8_RT": str,
                        "FIRSTGEN_COMP_ORIG_YR8_RT": str,
                        "FIRSTGEN_COMP_4YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_COMP_2YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_WDRAW_ORIG_YR8_RT": str,
                        "FIRSTGEN_WDRAW_4YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_WDRAW_2YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_ENRL_ORIG_YR8_RT": str,
                        "FIRSTGEN_ENRL_4YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_ENRL_2YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_UNKN_ORIG_YR8_RT": str,
                        "FIRSTGEN_UNKN_4YR_TRANS_YR8_RT": str,
                        "FIRSTGEN_UNKN_2YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_DEATH_YR8_RT": str,
                        "NOT1STGEN_COMP_ORIG_YR8_RT": str,
                        "NOT1STGEN_COMP_4YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_COMP_2YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_WDRAW_ORIG_YR8_RT": str,
                        "NOT1STGEN_WDRAW_4YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_WDRAW_2YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_ENRL_ORIG_YR8_RT": str,
                        "NOT1STGEN_ENRL_4YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_ENRL_2YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_UNKN_ORIG_YR8_RT": str,
                        "NOT1STGEN_UNKN_4YR_TRANS_YR8_RT": str,
                        "NOT1STGEN_UNKN_2YR_TRANS_YR8_RT": str,
                        "RPY_1YR_RT": float,
                        "COMPL_RPY_1YR_RT": float,
                        "NONCOM_RPY_1YR_RT": float,
                        "LO_INC_RPY_1YR_RT": float,
                        "MD_INC_RPY_1YR_RT": float,
                        "HI_INC_RPY_1YR_RT": float,
                        "DEP_RPY_1YR_RT": float,
                        "IND_RPY_1YR_RT": float,
                        "PELL_RPY_1YR_RT": float,
                        "NOPELL_RPY_1YR_RT": float,
                        "FEMALE_RPY_1YR_RT": float,
                        "MALE_RPY_1YR_RT": float,
                        "FIRSTGEN_RPY_1YR_RT": float,
                        "NOTFIRSTGEN_RPY_1YR_RT": float,
                        "RPY_3YR_RT": float,
                        "COMPL_RPY_3YR_RT": float,
                        "NONCOM_RPY_3YR_RT": float,
                        "LO_INC_RPY_3YR_RT": float,
                        "MD_INC_RPY_3YR_RT": float,
                        "HI_INC_RPY_3YR_RT": float,
                        "DEP_RPY_3YR_RT": float,
                        "IND_RPY_3YR_RT": float,
                        "PELL_RPY_3YR_RT": float,
                        "NOPELL_RPY_3YR_RT": float,
                        "FEMALE_RPY_3YR_RT": float,
                        "MALE_RPY_3YR_RT": float,
                        "FIRSTGEN_RPY_3YR_RT": float,
                        "NOTFIRSTGEN_RPY_3YR_RT": float,
                        "RPY_5YR_RT": float,
                        "COMPL_RPY_5YR_RT": float,
                        "NONCOM_RPY_5YR_RT": float,
                        "LO_INC_RPY_5YR_RT": float,
                        "MD_INC_RPY_5YR_RT": float,
                        "HI_INC_RPY_5YR_RT": float,
                        "DEP_RPY_5YR_RT": float,
                        "IND_RPY_5YR_RT": float,
                        "PELL_RPY_5YR_RT": float,
                        "NOPELL_RPY_5YR_RT": float,
                        "FEMALE_RPY_5YR_RT": float,
                        "MALE_RPY_5YR_RT": float,
                        "FIRSTGEN_RPY_5YR_RT": float,
                        "NOTFIRSTGEN_RPY_5YR_RT": float,
                        "RPY_7YR_RT": float,
                        "COMPL_RPY_7YR_RT": float,
                        "NONCOM_RPY_7YR_RT": float,
                        "LO_INC_RPY_7YR_RT": float,
                        "MD_INC_RPY_7YR_RT": float,
                        "HI_INC_RPY_7YR_RT": float,
                        "DEP_RPY_7YR_RT": float,
                        "IND_RPY_7YR_RT": float,
                        "PELL_RPY_7YR_RT": float,
                        "NOPELL_RPY_7YR_RT": float,
                        "FEMALE_RPY_7YR_RT": float,
                        "MALE_RPY_7YR_RT": float,
                        "FIRSTGEN_RPY_7YR_RT": float,
                        "NOTFIRSTGEN_RPY_7YR_RT": float,
                        "INC_PCT_LO": float,
                        "DEP_STAT_PCT_IND": float,
                        "DEP_INC_PCT_LO": float,
                        "IND_INC_PCT_LO": float,
                        "PAR_ED_PCT_1STGEN": float,
                        "INC_PCT_M1": float,
                        "INC_PCT_M2": float,
                        "INC_PCT_H1": float,
                        "INC_PCT_H2": float,
                        "DEP_INC_PCT_M1": float,
                        "DEP_INC_PCT_M2": float,
                        "DEP_INC_PCT_H1": float,
                        "DEP_INC_PCT_H2": float,
                        "IND_INC_PCT_M1": float,
                        "IND_INC_PCT_M2": float,
                        "IND_INC_PCT_H1": float,
                        "IND_INC_PCT_H2": float,
                        "PAR_ED_PCT_MS": float,
                        "PAR_ED_PCT_HS": float,
                        "PAR_ED_PCT_PS": float,
                        "APPL_SCH_PCT_GE2": float,
                        "APPL_SCH_PCT_GE3": float,
                        "APPL_SCH_PCT_GE4": float,
                        "APPL_SCH_PCT_GE5": float,
                        "DEP_INC_AVG": float,
                        "IND_INC_AVG": float,
                        "OVERALL_YR2_N": str,
                        "LO_INC_YR2_N": str,
                        "MD_INC_YR2_N": str,
                        "HI_INC_YR2_N": str,
                        "DEP_YR2_N": str,
                        "IND_YR2_N": str,
                        "FEMALE_YR2_N": str,
                        "MALE_YR2_N": str,
                        "PELL_YR2_N": str,
                        "NOPELL_YR2_N": str,
                        "LOAN_YR2_N": str,
                        "NOLOAN_YR2_N": str,
                        "FIRSTGEN_YR2_N": str,
                        "NOT1STGEN_YR2_N": str,
                        "OVERALL_YR3_N": str,
                        "LO_INC_YR3_N": str,
                        "MD_INC_YR3_N": str,
                        "HI_INC_YR3_N": str,
                        "DEP_YR3_N": str,
                        "IND_YR3_N": str,
                        "FEMALE_YR3_N": str,
                        "MALE_YR3_N": str,
                        "PELL_YR3_N": str,
                        "NOPELL_YR3_N": str,
                        "LOAN_YR3_N": str,
                        "NOLOAN_YR3_N": str,
                        "FIRSTGEN_YR3_N": str,
                        "NOT1STGEN_YR3_N": str,
                        "OVERALL_YR4_N": str,
                        "LO_INC_YR4_N": str,
                        "MD_INC_YR4_N": str,
                        "HI_INC_YR4_N": str,
                        "DEP_YR4_N": str,
                        "IND_YR4_N": str,
                        "FEMALE_YR4_N": str,
                        "MALE_YR4_N": str,
                        "PELL_YR4_N": str,
                        "NOPELL_YR4_N": str,
                        "LOAN_YR4_N": str,
                        "NOLOAN_YR4_N": str,
                        "FIRSTGEN_YR4_N": str,
                        "NOT1STGEN_YR4_N": str,
                        "OVERALL_YR6_N": str,
                        "LO_INC_YR6_N": str,
                        "MD_INC_YR6_N": str,
                        "HI_INC_YR6_N": str,
                        "DEP_YR6_N": str,
                        "IND_YR6_N": str,
                        "FEMALE_YR6_N": str,
                        "MALE_YR6_N": str,
                        "PELL_YR6_N": str,
                        "NOPELL_YR6_N": str,
                        "LOAN_YR6_N": str,
                        "NOLOAN_YR6_N": str,
                        "FIRSTGEN_YR6_N": str,
                        "NOT1STGEN_YR6_N": str,
                        "OVERALL_YR8_N": str,
                        "LO_INC_YR8_N": str,
                        "MD_INC_YR8_N": str,
                        "HI_INC_YR8_N": str,
                        "DEP_YR8_N": str,
                        "IND_YR8_N": str,
                        "FEMALE_YR8_N": str,
                        "MALE_YR8_N": str,
                        "PELL_YR8_N": str,
                        "NOPELL_YR8_N": str,
                        "LOAN_YR8_N": str,
                        "NOLOAN_YR8_N": str,
                        "FIRSTGEN_YR8_N": str,
                        "NOT1STGEN_YR8_N": str,
                        "DEBT_MDN": str,
                        "GRAD_DEBT_MDN": str,
                        "WDRAW_DEBT_MDN": str,
                        "LO_INC_DEBT_MDN": str,
                        "MD_INC_DEBT_MDN": str,
                        "HI_INC_DEBT_MDN": str,
                        "DEP_DEBT_MDN": str,
                        "IND_DEBT_MDN": str,
                        "PELL_DEBT_MDN": str,
                        "NOPELL_DEBT_MDN": str,
                        "FEMALE_DEBT_MDN": str,
                        "MALE_DEBT_MDN": str,
                        "FIRSTGEN_DEBT_MDN": str,
                        "NOTFIRSTGEN_DEBT_MDN": str,
                        "DEBT_N": str,
                        "GRAD_DEBT_N": str,
                        "WDRAW_DEBT_N": str,
                        "LO_INC_DEBT_N": str,
                        "MD_INC_DEBT_N": str,
                        "HI_INC_DEBT_N": str,
                        "DEP_DEBT_N": str,
                        "IND_DEBT_N": str,
                        "PELL_DEBT_N": str,
                        "NOPELL_DEBT_N": str,
                        "FEMALE_DEBT_N": str,
                        "MALE_DEBT_N": str,
                        "FIRSTGEN_DEBT_N": str,
                        "NOTFIRSTGEN_DEBT_N": str,
                        "GRAD_DEBT_MDN10YR": float,
                        "CUML_DEBT_N": float,
                        "CUML_DEBT_P90": float,
                        "CUML_DEBT_P75": float,
                        "CUML_DEBT_P25": float,
                        "CUML_DEBT_P10": float,
                        "INC_N": float,
                        "DEP_INC_N": float,
                        "IND_INC_N": float,
                        "DEP_STAT_N": float,
                        "PAR_ED_N": float,
                        "APPL_SCH_N": float,
                        "REPAY_DT_MDN": float,
                        "SEPAR_DT_MDN": float,
                        "REPAY_DT_N": float,
                        "SEPAR_DT_N": float,
                        "RPY_1YR_N": float,
                        "COMPL_RPY_1YR_N": float,
                        "NONCOM_RPY_1YR_N": float,
                        "LO_INC_RPY_1YR_N": float,
                        "MD_INC_RPY_1YR_N": float,
                        "HI_INC_RPY_1YR_N": float,
                        "DEP_RPY_1YR_N": float,
                        "IND_RPY_1YR_N": float,
                        "PELL_RPY_1YR_N": float,
                        "NOPELL_RPY_1YR_N": float,
                        "FEMALE_RPY_1YR_N": float,
                        "MALE_RPY_1YR_N": float,
                        "FIRSTGEN_RPY_1YR_N": float,
                        "NOTFIRSTGEN_RPY_1YR_N": float,
                        "RPY_3YR_N": float,
                        "COMPL_RPY_3YR_N": float,
                        "NONCOM_RPY_3YR_N": float,
                        "LO_INC_RPY_3YR_N": float,
                        "MD_INC_RPY_3YR_N": float,
                        "HI_INC_RPY_3YR_N": float,
                        "DEP_RPY_3YR_N": float,
                        "IND_RPY_3YR_N": float,
                        "PELL_RPY_3YR_N": float,
                        "NOPELL_RPY_3YR_N": float,
                        "FEMALE_RPY_3YR_N": float,
                        "MALE_RPY_3YR_N": float,
                        "FIRSTGEN_RPY_3YR_N": float,
                        "NOTFIRSTGEN_RPY_3YR_N": float,
                        "RPY_5YR_N": float,
                        "COMPL_RPY_5YR_N": float,
                        "NONCOM_RPY_5YR_N": float,
                        "LO_INC_RPY_5YR_N": float,
                        "MD_INC_RPY_5YR_N": float,
                        "HI_INC_RPY_5YR_N": float,
                        "DEP_RPY_5YR_N": float,
                        "IND_RPY_5YR_N": float,
                        "PELL_RPY_5YR_N": float,
                        "NOPELL_RPY_5YR_N": float,
                        "FEMALE_RPY_5YR_N": float,
                        "MALE_RPY_5YR_N": float,
                        "FIRSTGEN_RPY_5YR_N": float,
                        "NOTFIRSTGEN_RPY_5YR_N": float,
                        "RPY_7YR_N": float,
                        "COMPL_RPY_7YR_N": float,
                        "NONCOM_RPY_7YR_N": float,
                        "LO_INC_RPY_7YR_N": float,
                        "MD_INC_RPY_7YR_N": float,
                        "HI_INC_RPY_7YR_N": float,
                        "DEP_RPY_7YR_N": float,
                        "IND_RPY_7YR_N": float,
                        "PELL_RPY_7YR_N": float,
                        "NOPELL_RPY_7YR_N": float,
                        "FEMALE_RPY_7YR_N": float,
                        "MALE_RPY_7YR_N": float,
                        "FIRSTGEN_RPY_7YR_N": float,
                        "NOTFIRSTGEN_RPY_7YR_N": float,
                        "COUNT_ED": float,
                        "LOAN_EVER": float,
                        "PELL_EVER": float,
                        "AGE_ENTRY": float,
                        "AGE_ENTRY_SQ": float,
                        "AGEGE24": float,
                        "FEMALE": float,
                        "MARRIED": float,
                        "DEPENDENT": float,
                        "VETERAN": float,
                        "FIRST_GEN": float,
                        "FAMINC": float,
                        "MD_FAMINC": float,
                        "FAMINC_IND": float,
                        "LNFAMINC": float,
                        "LNFAMINC_IND": float,
                        "PCT_WHITE": float,
                        "PCT_BLACK": float,
                        "PCT_ASIAN": float,
                        "PCT_HISPANIC": float,
                        "PCT_BA": float,
                        "PCT_GRAD_PROF": float,
                        "PCT_BORN_US": float,
                        "MEDIAN_HH_INC": float,
                        "POVERTY_RATE": float,
                        "UNEMP_RATE": float,
                        "LN_MEDIAN_HH_INC": float,
                        "FSEND_COUNT": float,
                        "FSEND_1": float,
                        "FSEND_2": float,
                        "FSEND_3": float,
                        "FSEND_4": float,
                        "FSEND_5": float,
                        "COUNT_NWNE_P10": float,
                        "COUNT_WNE_P10": float,
                        "MN_EARN_WNE_P10": float,
                        "MD_EARN_WNE_P10": float,
                        "PCT10_EARN_WNE_P10": float,
                        "PCT25_EARN_WNE_P10": float,
                        "PCT75_EARN_WNE_P10": float,
                        "PCT90_EARN_WNE_P10": float,
                        "SD_EARN_WNE_P10": float,
                        "COUNT_WNE_INC1_P10": float,
                        "COUNT_WNE_INC2_P10": float,
                        "COUNT_WNE_INC3_P10": float,
                        "COUNT_WNE_INDEP0_INC1_P10": float,
                        "COUNT_WNE_INDEP0_P10": float,
                        "COUNT_WNE_INDEP1_P10": float,
                        "COUNT_WNE_MALE0_P10": float,
                        "COUNT_WNE_MALE1_P10": float,
                        "GT_25K_P10": float,
                        "MN_EARN_WNE_INC1_P10": float,
                        "MN_EARN_WNE_INC2_P10": float,
                        "MN_EARN_WNE_INC3_P10": float,
                        "MN_EARN_WNE_INDEP0_INC1_P10": float,
                        "MN_EARN_WNE_INDEP0_P10": float,
                        "MN_EARN_WNE_INDEP1_P10": float,
                        "MN_EARN_WNE_MALE0_P10": float,
                        "MN_EARN_WNE_MALE1_P10": float,
                        "COUNT_NWNE_P6": float,
                        "COUNT_WNE_P6": float,
                        "MN_EARN_WNE_P6": float,
                        "MD_EARN_WNE_P6": float,
                        "PCT10_EARN_WNE_P6": float,
                        "PCT25_EARN_WNE_P6": float,
                        "PCT75_EARN_WNE_P6": float,
                        "PCT90_EARN_WNE_P6": float,
                        "SD_EARN_WNE_P6": float,
                        "COUNT_WNE_INC1_P6": float,
                        "COUNT_WNE_INC2_P6": float,
                        "COUNT_WNE_INC3_P6": float,
                        "COUNT_WNE_INDEP0_INC1_P6": float,
                        "COUNT_WNE_INDEP0_P6": float,
                        "COUNT_WNE_INDEP1_P6": float,
                        "COUNT_WNE_MALE0_P6": float,
                        "COUNT_WNE_MALE1_P6": float,
                        "GT_25K_P6": float,
                        "MN_EARN_WNE_INC1_P6": float,
                        "MN_EARN_WNE_INC2_P6": float,
                        "MN_EARN_WNE_INC3_P6": float,
                        "MN_EARN_WNE_INDEP0_INC1_P6": float,
                        "MN_EARN_WNE_INDEP0_P6": float,
                        "MN_EARN_WNE_INDEP1_P6": float,
                        "MN_EARN_WNE_MALE0_P6": float,
                        "MN_EARN_WNE_MALE1_P6": float,
                        "COUNT_NWNE_P7": float,
                        "COUNT_WNE_P7": float,
                        "MN_EARN_WNE_P7": float,
                        "SD_EARN_WNE_P7": float,
                        "GT_25K_P7": float,
                        "COUNT_NWNE_P8": float,
                        "COUNT_WNE_P8": float,
                        "MN_EARN_WNE_P8": float,
                        "MD_EARN_WNE_P8": float,
                        "PCT10_EARN_WNE_P8": float,
                        "PCT25_EARN_WNE_P8": float,
                        "PCT75_EARN_WNE_P8": float,
                        "PCT90_EARN_WNE_P8": float,
                        "SD_EARN_WNE_P8": float,
                        "GT_25K_P8": float,
                        "COUNT_NWNE_P9": float,
                        "COUNT_WNE_P9": float,
                        "MN_EARN_WNE_P9": float,
                        "SD_EARN_WNE_P9": float,
                        "GT_25K_P9": float,
                        "DEBT_MDN_SUPP": str,
                        "GRAD_DEBT_MDN_SUPP": str,
                        "GRAD_DEBT_MDN10YR_SUPP": float,
                        "RPY_3YR_RT_SUPP": float,
                        "LO_INC_RPY_3YR_RT_SUPP": float,
                        "MD_INC_RPY_3YR_RT_SUPP": float,
                        "HI_INC_RPY_3YR_RT_SUPP": float,
                        "COMPL_RPY_3YR_RT_SUPP": float,
                        "NONCOM_RPY_3YR_RT_SUPP": float,
                        "DEP_RPY_3YR_RT_SUPP": float,
                        "IND_RPY_3YR_RT_SUPP": float,
                        "PELL_RPY_3YR_RT_SUPP": float,
                        "NOPELL_RPY_3YR_RT_SUPP": float,
                        "FEMALE_RPY_3YR_RT_SUPP": float,
                        "MALE_RPY_3YR_RT_SUPP": float,
                        "FIRSTGEN_RPY_3YR_RT_SUPP": float,
                        "NOTFIRSTGEN_RPY_3YR_RT_SUPP": float,
                        "C150_L4_POOLED_SUPP": float,
                        "C150_4_POOLED_SUPP": float,
                        "C200_L4_POOLED_SUPP": float,
                        "C200_4_POOLED_SUPP": float,
                        "ALIAS": str,
                        "C100_4": float,
                        "D100_4": float,
                        "C100_L4": float,
                        "D100_L4": float,
                        "TRANS_4": float,
                        "DTRANS_4": float,
                        "TRANS_L4": float,
                        "DTRANS_L4": float,
                        "ICLEVEL": pd.Int64Dtype(),
                        "UGDS_MEN": float,
                        "UGDS_WOMEN": float,
                        "CDR3_DENOM": float,
                        "CDR2_DENOM": float,
                        "T4APPROVALDATE": float,
                        "D150_4_WHITE": float,
                        "D150_4_BLACK": float,
                        "D150_4_HISP": float,
                        "D150_4_ASIAN": float,
                        "D150_4_AIAN": float,
                        "D150_4_NHPI": float,
                        "D150_4_2MOR": float,
                        "D150_4_NRA": float,
                        "D150_4_UNKN": float,
                        "D150_4_WHITENH": float,
                        "D150_4_BLACKNH": float,
                        "D150_4_API": float,
                        "D150_4_AIANOLD": float,
                        "D150_4_HISPOLD": float,
                        "D150_L4_WHITE": float,
                        "D150_L4_BLACK": float,
                        "D150_L4_HISP": float,
                        "D150_L4_ASIAN": float,
                        "D150_L4_AIAN": float,
                        "D150_L4_NHPI": float,
                        "D150_L4_2MOR": float,
                        "D150_L4_NRA": float,
                        "D150_L4_UNKN": float,
                        "D150_L4_WHITENH": float,
                        "D150_L4_BLACKNH": float,
                        "D150_L4_API": float,
                        "D150_L4_AIANOLD": float,
                        "D150_L4_HISPOLD": float,
                        "D_PCTPELL_PCTFLOAN": float,
                        "OPENADMP": float,
                        "UGNONDS": float,
                        "GRADS": float,
                        "ACCREDCODE": float,
                        "OMACHT6_FTFT": float,
                        "OMAWDP6_FTFT": float,
                        "OMACHT8_FTFT": float,
                        "OMAWDP8_FTFT": float,
                        "OMENRYP8_FTFT": float,
                        "OMENRAP8_FTFT": float,
                        "OMENRUP8_FTFT": float,
                        "OMACHT6_PTFT": float,
                        "OMAWDP6_PTFT": float,
                        "OMACHT8_PTFT": float,
                        "OMAWDP8_PTFT": float,
                        "OMENRYP8_PTFT": float,
                        "OMENRAP8_PTFT": float,
                        "OMENRUP8_PTFT": float,
                        "OMACHT6_FTNFT": float,
                        "OMAWDP6_FTNFT": float,
                        "OMACHT8_FTNFT": float,
                        "OMAWDP8_FTNFT": float,
                        "OMENRYP8_FTNFT": float,
                        "OMENRAP8_FTNFT": float,
                        "OMENRUP8_FTNFT": float,
                        "OMACHT6_PTNFT": float,
                        "OMAWDP6_PTNFT": float,
                        "OMACHT8_PTNFT": float,
                        "OMAWDP8_PTNFT": float,
                        "OMENRYP8_PTNFT": float,
                        "OMENRAP8_PTNFT": float,
                        "OMENRUP8_PTNFT": float,
                        "RET_FT4_POOLED": float,
                        "RET_FTL4_POOLED": float,
                        "RET_PT4_POOLED": float,
                        "RET_PTL4_POOLED": float,
                        "RET_FT_DEN4_POOLED": float,
                        "RET_FT_DENL4_POOLED": float,
                        "RET_PT_DEN4_POOLED": float,
                        "RET_PT_DENL4_POOLED": float,
                        "POOLYRSRET_FT": float,
                        "POOLYRSRET_PT": float,
                        "RET_FT4_POOLED_SUPP": float,
                        "RET_FTL4_POOLED_SUPP": float,
                        "RET_PT4_POOLED_SUPP": float,
                        "RET_PTL4_POOLED_SUPP": float,
                        "TRANS_4_POOLED": float,
                        "TRANS_L4_POOLED": float,
                        "DTRANS_4_POOLED": float,
                        "DTRANS_L4_POOLED": float,
                        "TRANS_4_POOLED_SUPP": float,
                        "TRANS_L4_POOLED_SUPP": float,
                        "C100_4_POOLED": float,
                        "C100_L4_POOLED": float,
                        "D100_4_POOLED": float,
                        "D100_L4_POOLED": float,
                        "POOLYRS100": float,
                        "C100_4_POOLED_SUPP": float,
                        "C100_L4_POOLED_SUPP": float,
                        "C150_4_PELL": float,
                        "D150_4_PELL": float,
                        "C150_L4_PELL": float,
                        "D150_L4_PELL": float,
                        "C150_4_LOANNOPELL": float,
                        "D150_4_LOANNOPELL": float,
                        "C150_L4_LOANNOPELL": float,
                        "D150_L4_LOANNOPELL": float,
                        "C150_4_NOLOANNOPELL": float,
                        "D150_4_NOLOANNOPELL": float,
                        "C150_L4_NOLOANNOPELL": float,
                        "D150_L4_NOLOANNOPELL": float,
                        "GT_28K_P10": float,
                        "GT_28K_P8": float,
                        "GT_28K_P6": float,
                        "OMACHT6_FTFT_POOLED": float,
                        "OMAWDP6_FTFT_POOLED": float,
                        "OMACHT8_FTFT_POOLED": float,
                        "OMAWDP8_FTFT_POOLED": float,
                        "OMENRYP8_FTFT_POOLED": float,
                        "OMENRAP8_FTFT_POOLED": float,
                        "OMENRUP8_FTFT_POOLED": float,
                        "OMACHT6_PTFT_POOLED": float,
                        "OMAWDP6_PTFT_POOLED": float,
                        "OMACHT8_PTFT_POOLED": float,
                        "OMAWDP8_PTFT_POOLED": float,
                        "OMENRYP8_PTFT_POOLED": float,
                        "OMENRAP8_PTFT_POOLED": float,
                        "OMENRUP8_PTFT_POOLED": float,
                        "OMACHT6_FTNFT_POOLED": float,
                        "OMAWDP6_FTNFT_POOLED": float,
                        "OMACHT8_FTNFT_POOLED": float,
                        "OMAWDP8_FTNFT_POOLED": float,
                        "OMENRYP8_FTNFT_POOLED": float,
                        "OMENRAP8_FTNFT_POOLED": float,
                        "OMENRUP8_FTNFT_POOLED": float,
                        "OMACHT6_PTNFT_POOLED": float,
                        "OMAWDP6_PTNFT_POOLED": float,
                        "OMACHT8_PTNFT_POOLED": float,
                        "OMAWDP8_PTNFT_POOLED": float,
                        "OMENRYP8_PTNFT_POOLED": float,
                        "OMENRAP8_PTNFT_POOLED": float,
                        "OMENRUP8_PTNFT_POOLED": float,
                        "POOLYRSOM_FTFT": float,
                        "POOLYRSOM_PTFT": float,
                        "POOLYRSOM_FTNFT": float,
                        "POOLYRSOM_PTNFT": float,
                        "OMAWDP6_FTFT_POOLED_SUPP": float,
                        "OMAWDP8_FTFT_POOLED_SUPP": float,
                        "OMENRYP8_FTFT_POOLED_SUPP": float,
                        "OMENRAP8_FTFT_POOLED_SUPP": float,
                        "OMENRUP8_FTFT_POOLED_SUPP": float,
                        "OMAWDP6_PTFT_POOLED_SUPP": float,
                        "OMAWDP8_PTFT_POOLED_SUPP": float,
                        "OMENRYP8_PTFT_POOLED_SUPP": float,
                        "OMENRAP8_PTFT_POOLED_SUPP": float,
                        "OMENRUP8_PTFT_POOLED_SUPP": float,
                        "OMAWDP6_FTNFT_POOLED_SUPP": float,
                        "OMAWDP8_FTNFT_POOLED_SUPP": float,
                        "OMENRYP8_FTNFT_POOLED_SUPP": float,
                        "OMENRAP8_FTNFT_POOLED_SUPP": float,
                        "OMENRUP8_FTNFT_POOLED_SUPP": float,
                        "OMAWDP6_PTNFT_POOLED_SUPP": float,
                        "OMAWDP8_PTNFT_POOLED_SUPP": float,
                        "OMENRYP8_PTNFT_POOLED_SUPP": float,
                        "OMENRAP8_PTNFT_POOLED_SUPP": float,
                        "OMENRUP8_PTNFT_POOLED_SUPP": float,
                        "SCHTYPE": float,
                        "OPEFLAG": pd.Int64Dtype(),
                        "PRGMOFR": float,
                        "CIPCODE1": float,
                        "CIPCODE2": float,
                        "CIPCODE3": float,
                        "CIPCODE4": float,
                        "CIPCODE5": float,
                        "CIPCODE6": float,
                        "CIPTITLE1": str,
                        "CIPTITLE2": str,
                        "CIPTITLE3": str,
                        "CIPTITLE4": str,
                        "CIPTITLE5": str,
                        "CIPTITLE6": str,
                        "CIPTFBS1": float,
                        "CIPTFBS2": float,
                        "CIPTFBS3": float,
                        "CIPTFBS4": float,
                        "CIPTFBS5": float,
                        "CIPTFBS6": float,
                        "CIPTFBSANNUAL1": float,
                        "CIPTFBSANNUAL2": float,
                        "CIPTFBSANNUAL3": float,
                        "CIPTFBSANNUAL4": float,
                        "CIPTFBSANNUAL5": float,
                        "CIPTFBSANNUAL6": float,
                        "MTHCMP1": float,
                        "MTHCMP2": float,
                        "MTHCMP3": float,
                        "MTHCMP4": float,
                        "MTHCMP5": float,
                        "MTHCMP6": float,
                        "POOLYRSOM_ALL": float,
                        "POOLYRSOM_FIRSTTIME": float,
                        "POOLYRSOM_NOTFIRSTTIME": float,
                        "POOLYRSOM_FULLTIME": float,
                        "POOLYRSOM_PARTTIME": float,
                        "OMENRYP_ALL": float,
                        "OMENRAP_ALL": float,
                        "OMAWDP8_ALL": float,
                        "OMENRUP_ALL": float,
                        "OMENRYP_FIRSTTIME": float,
                        "OMENRAP_FIRSTTIME": float,
                        "OMAWDP8_FIRSTTIME": float,
                        "OMENRUP_FIRSTTIME": float,
                        "OMENRYP_NOTFIRSTTIME": float,
                        "OMENRAP_NOTFIRSTTIME": float,
                        "OMAWDP8_NOTFIRSTTIME": float,
                        "OMENRUP_NOTFIRSTTIME": float,
                        "OMENRYP_FULLTIME": float,
                        "OMENRAP_FULLTIME": float,
                        "OMAWDP8_FULLTIME": float,
                        "OMENRUP_FULLTIME": float,
                        "OMENRYP_PARTTIME": float,
                        "OMENRAP_PARTTIME": float,
                        "OMAWDP8_PARTTIME": float,
                        "OMENRUP_PARTTIME": float,
                        "OMENRYP_ALL_POOLED_SUPP": float,
                        "OMENRAP_ALL_POOLED_SUPP": float,
                        "OMAWDP8_ALL_POOLED_SUPP": float,
                        "OMENRUP_ALL_POOLED_SUPP": float,
                        "OMENRYP_FIRSTTIME_POOLED_SUPP": float,
                        "OMENRAP_FIRSTTIME_POOLED_SUPP": float,
                        "OMAWDP8_FIRSTTIME_POOLED_SUPP": float,
                        "OMENRUP_FIRSTTIME_POOLED_SUPP": float,
                        "OMENRYP_NOTFIRSTTIME_POOLED_SUPP": float,
                        "OMENRAP_NOTFIRSTTIME_POOLED_SUPP": float,
                        "OMAWDP8_NOTFIRSTTIME_POOLED_SUPP": float,
                        "OMENRUP_NOTFIRSTTIME_POOLED_SUPP": float,
                        "OMENRYP_FULLTIME_POOLED_SUPP": float,
                        "OMENRAP_FULLTIME_POOLED_SUPP": float,
                        "OMAWDP8_FULLTIME_POOLED_SUPP": float,
                        "OMENRUP_FULLTIME_POOLED_SUPP": float,
                        "OMENRYP_PARTTIME_POOLED_SUPP": float,
                        "OMENRAP_PARTTIME_POOLED_SUPP": float,
                        "OMAWDP8_PARTTIME_POOLED_SUPP": float,
                        "OMENRUP_PARTTIME_POOLED_SUPP": float,
                        "FTFTPCTPELL": float,
                        "FTFTPCTFLOAN": float,
                        "UG12MN": float,
                        "G12MN": float,
                        "SCUGFFN": float,
                        "POOLYRS_FTFTAIDPCT": float,
                        "FTFTPCTPELL_POOLED_SUPP": float,
                        "FTFTPCTFLOAN_POOLED_SUPP": float,
                        "SCUGFFN_POOLED": float,
                        "PPLUS_PCT_LOW": float,
                        "PPLUS_PCT_HIGH": float,
                        "PPLUS_PCT_LOW_POOLED_SUPP": float,
                        "PPLUS_PCT_HIGH_POOLED_SUPP": float,
                        "POOLYRS_PLUSPCT": float,
                        "PLUS_DEBT_INST_N": str,
                        "PLUS_DEBT_INST_MD": str,
                        "PLUS_DEBT_ALL_N": str,
                        "PLUS_DEBT_ALL_MD": str,
                        "PLUS_DEBT_INST_COMP_N": str,
                        "PLUS_DEBT_INST_COMP_MD": str,
                        "PLUS_DEBT_INST_COMP_MDPAY10": float,
                        "PLUS_DEBT_INST_COMP_MD_SUPP": str,
                        "PLUS_DEBT_INST_COMP_MDPAY10_SUPP": float,
                        "PLUS_DEBT_ALL_COMP_N": str,
                        "PLUS_DEBT_ALL_COMP_MD": str,
                        "PLUS_DEBT_ALL_COMP_MDPAY10": float,
                        "PLUS_DEBT_ALL_COMP_MD_SUPP": str,
                        "PLUS_DEBT_ALL_COMP_MDPAY10_SUPP": float,
                        "PLUS_DEBT_INST_NOCOMP_N": str,
                        "PLUS_DEBT_INST_NOCOMP_MD": str,
                        "PLUS_DEBT_ALL_NOCOMP_N": str,
                        "PLUS_DEBT_ALL_NOCOMP_MD": str,
                        "PLUS_DEBT_INST_MALE_N": str,
                        "PLUS_DEBT_INST_MALE_MD": str,
                        "PLUS_DEBT_ALL_MALE_N": str,
                        "PLUS_DEBT_ALL_MALE_MD": str,
                        "PLUS_DEBT_INST_NOMALE_N": str,
                        "PLUS_DEBT_INST_NOMALE_MD": str,
                        "PLUS_DEBT_ALL_NOMALE_N": str,
                        "PLUS_DEBT_ALL_NOMALE_MD": str,
                        "PLUS_DEBT_INST_PELL_N": str,
                        "PLUS_DEBT_INST_PELL_MD": str,
                        "PLUS_DEBT_ALL_PELL_N": str,
                        "PLUS_DEBT_ALL_PELL_MD": str,
                        "PLUS_DEBT_INST_NOPELL_N": str,
                        "PLUS_DEBT_INST_NOPELL_MD": str,
                        "PLUS_DEBT_ALL_NOPELL_N": str,
                        "PLUS_DEBT_ALL_NOPELL_MD": str,
                        "PLUS_DEBT_INST_STAFFTHIS_N": str,
                        "PLUS_DEBT_INST_STAFFTHIS_MD": str,
                        "PLUS_DEBT_ALL_STAFFTHIS_N": str,
                        "PLUS_DEBT_ALL_STAFFTHIS_MD": str,
                        "PLUS_DEBT_INST_NOSTAFFTHIS_N": str,
                        "PLUS_DEBT_INST_NOSTAFFTHIS_MD": str,
                        "PLUS_DEBT_ALL_NOSTAFFTHIS_N": str,
                        "PLUS_DEBT_ALL_NOSTAFFTHIS_MD": str,
                        "PLUS_DEBT_INST_STAFFANY_N": str,
                        "PLUS_DEBT_INST_STAFFANY_MD": str,
                        "PLUS_DEBT_ALL_STAFFANY_N": str,
                        "PLUS_DEBT_ALL_STAFFANY_MD": str,
                        "PLUS_DEBT_INST_NOSTAFFANY_N": str,
                        "PLUS_DEBT_INST_NOSTAFFANY_MD": str,
                        "PLUS_DEBT_ALL_NOSTAFFANY_N": str,
                        "PLUS_DEBT_ALL_NOSTAFFANY_MD": str,
                        "COUNT_NWNE_3YR": float,
                        "COUNT_WNE_3YR": float,
                        "CNTOVER150_3YR": float,
                        "DBRR1_FED_UG_N": str,
                        "DBRR1_FED_UG_NUM": str,
                        "DBRR1_FED_UG_DEN": str,
                        "DBRR1_FED_UG_RT": str,
                        "DBRR1_FED_GR_N": str,
                        "DBRR1_FED_GR_NUM": str,
                        "DBRR1_FED_GR_DEN": str,
                        "DBRR1_FED_GR_RT": str,
                        "DBRR1_FED_UGCOMP_N": str,
                        "DBRR1_FED_UGCOMP_NUM": str,
                        "DBRR1_FED_UGCOMP_DEN": str,
                        "DBRR1_FED_UGCOMP_RT": str,
                        "DBRR1_FED_UGNOCOMP_N": str,
                        "DBRR1_FED_UGNOCOMP_NUM": str,
                        "DBRR1_FED_UGNOCOMP_DEN": str,
                        "DBRR1_FED_UGNOCOMP_RT": str,
                        "DBRR1_FED_UGUNK_N": str,
                        "DBRR1_FED_UGUNK_NUM": str,
                        "DBRR1_FED_UGUNK_DEN": str,
                        "DBRR1_FED_UGUNK_RT": str,
                        "DBRR1_FED_GRCOMP_N": str,
                        "DBRR1_FED_GRCOMP_NUM": str,
                        "DBRR1_FED_GRCOMP_DEN": str,
                        "DBRR1_FED_GRCOMP_RT": str,
                        "DBRR1_FED_GRNOCOMP_N": str,
                        "DBRR1_FED_GRNOCOMP_NUM": str,
                        "DBRR1_FED_GRNOCOMP_DEN": str,
                        "DBRR1_FED_GRNOCOMP_RT": str,
                        "DBRR4_FED_UG_N": float,
                        "DBRR4_FED_UG_NUM": float,
                        "DBRR4_FED_UG_DEN": float,
                        "DBRR4_FED_UG_RT": float,
                        "DBRR4_FED_GR_N": float,
                        "DBRR4_FED_GR_NUM": float,
                        "DBRR4_FED_GR_DEN": float,
                        "DBRR4_FED_GR_RT": float,
                        "DBRR4_FED_UGCOMP_N": float,
                        "DBRR4_FED_UGCOMP_NUM": float,
                        "DBRR4_FED_UGCOMP_DEN": float,
                        "DBRR4_FED_UGCOMP_RT": float,
                        "DBRR4_FED_UGNOCOMP_N": float,
                        "DBRR4_FED_UGNOCOMP_NUM": float,
                        "DBRR4_FED_UGNOCOMP_DEN": float,
                        "DBRR4_FED_UGNOCOMP_RT": float,
                        "DBRR4_FED_UGUNK_N": float,
                        "DBRR4_FED_UGUNK_NUM": float,
                        "DBRR4_FED_UGUNK_DEN": float,
                        "DBRR4_FED_UGUNK_RT": float,
                        "DBRR5_FED_UG_N": str,
                        "DBRR5_FED_UG_NUM": str,
                        "DBRR5_FED_UG_DEN": str,
                        "DBRR5_FED_UG_RT": str,
                        "DBRR5_FED_GR_N": str,
                        "DBRR5_FED_GR_NUM": str,
                        "DBRR5_FED_GR_DEN": str,
                        "DBRR5_FED_GR_RT": str,
                        "DBRR10_FED_UG_N": str,
                        "DBRR10_FED_UG_NUM": str,
                        "DBRR10_FED_UG_DEN": str,
                        "DBRR10_FED_UG_RT": str,
                        "DBRR10_FED_GR_N": str,
                        "DBRR10_FED_GR_NUM": str,
                        "DBRR10_FED_GR_DEN": str,
                        "DBRR10_FED_GR_RT": str,
                        "DBRR20_FED_UG_N": str,
                        "DBRR20_FED_UG_NUM": str,
                        "DBRR20_FED_UG_DEN": str,
                        "DBRR20_FED_UG_RT": str,
                        "DBRR20_FED_GR_N": str,
                        "DBRR20_FED_GR_NUM": str,
                        "DBRR20_FED_GR_DEN": str,
                        "DBRR20_FED_GR_RT": str,
                        "DBRR1_PP_UG_N": str,
                        "DBRR1_PP_UG_NUM": str,
                        "DBRR1_PP_UG_DEN": str,
                        "DBRR1_PP_UG_RT": str,
                        "DBRR1_PP_UGCOMP_N": str,
                        "DBRR1_PP_UGCOMP_NUM": str,
                        "DBRR1_PP_UGCOMP_DEN": str,
                        "DBRR1_PP_UGCOMP_RT": str,
                        "DBRR1_PP_UGNOCOMP_N": str,
                        "DBRR1_PP_UGNOCOMP_NUM": str,
                        "DBRR1_PP_UGNOCOMP_DEN": str,
                        "DBRR1_PP_UGNOCOMP_RT": str,
                        "DBRR1_PP_UGUNK_N": str,
                        "DBRR1_PP_UGUNK_NUM": str,
                        "DBRR1_PP_UGUNK_DEN": str,
                        "DBRR1_PP_UGUNK_RT": str,
                        "DBRR4_PP_UG_N": float,
                        "DBRR4_PP_UG_NUM": float,
                        "DBRR4_PP_UG_DEN": float,
                        "DBRR4_PP_UG_RT": float,
                        "DBRR4_PP_UGCOMP_N": float,
                        "DBRR4_PP_UGCOMP_NUM": float,
                        "DBRR4_PP_UGCOMP_DEN": float,
                        "DBRR4_PP_UGCOMP_RT": float,
                        "DBRR4_PP_UGNOCOMP_N": float,
                        "DBRR4_PP_UGNOCOMP_NUM": float,
                        "DBRR4_PP_UGNOCOMP_DEN": float,
                        "DBRR4_PP_UGNOCOMP_RT": float,
                        "DBRR4_PP_UGUNK_N": float,
                        "DBRR4_PP_UGUNK_NUM": float,
                        "DBRR4_PP_UGUNK_DEN": float,
                        "DBRR4_PP_UGUNK_RT": float,
                        "DBRR5_PP_UG_N": str,
                        "DBRR5_PP_UG_NUM": str,
                        "DBRR5_PP_UG_DEN": str,
                        "DBRR5_PP_UG_RT": str,
                        "DBRR10_PP_UG_N": str,
                        "DBRR10_PP_UG_NUM": str,
                        "DBRR10_PP_UG_DEN": str,
                        "DBRR10_PP_UG_RT": str,
                        "DBRR20_PP_UG_N": str,
                        "DBRR20_PP_UG_NUM": str,
                        "DBRR20_PP_UG_DEN": str,
                        "DBRR20_PP_UG_RT": str,
                        "BBRR1_FED_UG_N": str,
                        "BBRR1_FED_UG_DFLT": str,
                        "BBRR1_FED_UG_DLNQ": str,
                        "BBRR1_FED_UG_FBR": str,
                        "BBRR1_FED_UG_DFR": str,
                        "BBRR1_FED_UG_NOPROG": str,
                        "BBRR1_FED_UG_MAKEPROG": str,
                        "BBRR1_FED_UG_PAIDINFULL": str,
                        "BBRR1_FED_UG_DISCHARGE": str,
                        "BBRR1_FED_UGCOMP_N": str,
                        "BBRR1_FED_UGCOMP_DFLT": str,
                        "BBRR1_FED_UGCOMP_DLNQ": str,
                        "BBRR1_FED_UGCOMP_FBR": str,
                        "BBRR1_FED_UGCOMP_DFR": str,
                        "BBRR1_FED_UGCOMP_NOPROG": str,
                        "BBRR1_FED_UGCOMP_MAKEPROG": str,
                        "BBRR1_FED_UGCOMP_PAIDINFULL": str,
                        "BBRR1_FED_UGCOMP_DISCHARGE": str,
                        "BBRR1_FED_UGNOCOMP_N": str,
                        "BBRR1_FED_UGNOCOMP_DFLT": str,
                        "BBRR1_FED_UGNOCOMP_DLNQ": str,
                        "BBRR1_FED_UGNOCOMP_FBR": str,
                        "BBRR1_FED_UGNOCOMP_DFR": str,
                        "BBRR1_FED_UGNOCOMP_NOPROG": str,
                        "BBRR1_FED_UGNOCOMP_MAKEPROG": str,
                        "BBRR1_FED_UGNOCOMP_PAIDINFULL": str,
                        "BBRR1_FED_UGNOCOMP_DISCHARGE": str,
                        "BBRR1_FED_UGUNK_N": str,
                        "BBRR1_FED_UGUNK_DFLT": str,
                        "BBRR1_FED_UGUNK_DLNQ": str,
                        "BBRR1_FED_UGUNK_FBR": str,
                        "BBRR1_FED_UGUNK_DFR": str,
                        "BBRR1_FED_UGUNK_NOPROG": str,
                        "BBRR1_FED_UGUNK_MAKEPROG": str,
                        "BBRR1_FED_UGUNK_PAIDINFULL": str,
                        "BBRR1_FED_UGUNK_DISCHARGE": str,
                        "BBRR1_FED_GR_N": str,
                        "BBRR1_FED_GR_DFLT": str,
                        "BBRR1_FED_GR_DLNQ": str,
                        "BBRR1_FED_GR_FBR": str,
                        "BBRR1_FED_GR_DFR": str,
                        "BBRR1_FED_GR_NOPROG": str,
                        "BBRR1_FED_GR_MAKEPROG": str,
                        "BBRR1_FED_GR_PAIDINFULL": str,
                        "BBRR1_FED_GR_DISCHARGE": str,
                        "BBRR1_FED_GRCOMP_N": str,
                        "BBRR1_FED_GRCOMP_DFLT": str,
                        "BBRR1_FED_GRCOMP_DLNQ": str,
                        "BBRR1_FED_GRCOMP_FBR": str,
                        "BBRR1_FED_GRCOMP_DFR": str,
                        "BBRR1_FED_GRCOMP_NOPROG": str,
                        "BBRR1_FED_GRCOMP_MAKEPROG": str,
                        "BBRR1_FED_GRCOMP_PAIDINFULL": str,
                        "BBRR1_FED_GRCOMP_DISCHARGE": str,
                        "BBRR1_FED_GRNOCOMP_N": str,
                        "BBRR1_FED_GRNOCOMP_DFLT": str,
                        "BBRR1_FED_GRNOCOMP_DLNQ": str,
                        "BBRR1_FED_GRNOCOMP_FBR": str,
                        "BBRR1_FED_GRNOCOMP_DFR": str,
                        "BBRR1_FED_GRNOCOMP_NOPROG": str,
                        "BBRR1_FED_GRNOCOMP_MAKEPROG": str,
                        "BBRR1_FED_GRNOCOMP_PAIDINFULL": str,
                        "BBRR1_FED_GRNOCOMP_DISCHARGE": str,
                        "BBRR1_PP_UG_N": str,
                        "BBRR1_PP_UG_DFLT": str,
                        "BBRR1_PP_UG_DLNQ": str,
                        "BBRR1_PP_UG_FBR": str,
                        "BBRR1_PP_UG_DFR": str,
                        "BBRR1_PP_UG_NOPROG": str,
                        "BBRR1_PP_UG_MAKEPROG": str,
                        "BBRR1_PP_UG_PAIDINFULL": str,
                        "BBRR1_PP_UG_DISCHARGE": str,
                        "BBRR1_PP_UGCOMP_N": str,
                        "BBRR1_PP_UGCOMP_DFLT": str,
                        "BBRR1_PP_UGCOMP_DLNQ": str,
                        "BBRR1_PP_UGCOMP_FBR": str,
                        "BBRR1_PP_UGCOMP_DFR": str,
                        "BBRR1_PP_UGCOMP_NOPROG": str,
                        "BBRR1_PP_UGCOMP_MAKEPROG": str,
                        "BBRR1_PP_UGCOMP_PAIDINFULL": str,
                        "BBRR1_PP_UGCOMP_DISCHARGE": str,
                        "BBRR1_PP_UGNOCOMP_N": str,
                        "BBRR1_PP_UGNOCOMP_DFLT": str,
                        "BBRR1_PP_UGNOCOMP_DLNQ": str,
                        "BBRR1_PP_UGNOCOMP_FBR": str,
                        "BBRR1_PP_UGNOCOMP_DFR": str,
                        "BBRR1_PP_UGNOCOMP_NOPROG": str,
                        "BBRR1_PP_UGNOCOMP_MAKEPROG": str,
                        "BBRR1_PP_UGNOCOMP_PAIDINFULL": str,
                        "BBRR1_PP_UGNOCOMP_DISCHARGE": str,
                        "BBRR1_PP_UGUNK_N": str,
                        "BBRR1_PP_UGUNK_DFLT": str,
                        "BBRR1_PP_UGUNK_DLNQ": str,
                        "BBRR1_PP_UGUNK_FBR": str,
                        "BBRR1_PP_UGUNK_DFR": str,
                        "BBRR1_PP_UGUNK_NOPROG": str,
                        "BBRR1_PP_UGUNK_MAKEPROG": str,
                        "BBRR1_PP_UGUNK_PAIDINFULL": str,
                        "BBRR1_PP_UGUNK_DISCHARGE": str,
                        "BBRR2_FED_UG_N": str,
                        "BBRR2_FED_UG_DFLT": str,
                        "BBRR2_FED_UG_DLNQ": str,
                        "BBRR2_FED_UG_FBR": str,
                        "BBRR2_FED_UG_DFR": str,
                        "BBRR2_FED_UG_NOPROG": str,
                        "BBRR2_FED_UG_MAKEPROG": str,
                        "BBRR2_FED_UG_PAIDINFULL": str,
                        "BBRR2_FED_UG_DISCHARGE": str,
                        "BBRR2_FED_UGCOMP_N": str,
                        "BBRR2_FED_UGCOMP_DFLT": str,
                        "BBRR2_FED_UGCOMP_DLNQ": str,
                        "BBRR2_FED_UGCOMP_FBR": str,
                        "BBRR2_FED_UGCOMP_DFR": str,
                        "BBRR2_FED_UGCOMP_NOPROG": str,
                        "BBRR2_FED_UGCOMP_MAKEPROG": str,
                        "BBRR2_FED_UGCOMP_PAIDINFULL": str,
                        "BBRR2_FED_UGCOMP_DISCHARGE": str,
                        "BBRR2_FED_UGNOCOMP_N": str,
                        "BBRR2_FED_UGNOCOMP_DFLT": str,
                        "BBRR2_FED_UGNOCOMP_DLNQ": str,
                        "BBRR2_FED_UGNOCOMP_FBR": str,
                        "BBRR2_FED_UGNOCOMP_DFR": str,
                        "BBRR2_FED_UGNOCOMP_NOPROG": str,
                        "BBRR2_FED_UGNOCOMP_MAKEPROG": str,
                        "BBRR2_FED_UGNOCOMP_PAIDINFULL": str,
                        "BBRR2_FED_UGNOCOMP_DISCHARGE": str,
                        "BBRR2_FED_UGUNK_N": str,
                        "BBRR2_FED_UGUNK_DFLT": str,
                        "BBRR2_FED_UGUNK_DLNQ": str,
                        "BBRR2_FED_UGUNK_FBR": str,
                        "BBRR2_FED_UGUNK_DFR": str,
                        "BBRR2_FED_UGUNK_NOPROG": str,
                        "BBRR2_FED_UGUNK_MAKEPROG": str,
                        "BBRR2_FED_UGUNK_PAIDINFULL": str,
                        "BBRR2_FED_UGUNK_DISCHARGE": str,
                        "BBRR2_FED_GR_N": str,
                        "BBRR2_FED_GR_DFLT": str,
                        "BBRR2_FED_GR_DLNQ": str,
                        "BBRR2_FED_GR_FBR": str,
                        "BBRR2_FED_GR_DFR": str,
                        "BBRR2_FED_GR_NOPROG": str,
                        "BBRR2_FED_GR_MAKEPROG": str,
                        "BBRR2_FED_GR_PAIDINFULL": str,
                        "BBRR2_FED_GR_DISCHARGE": str,
                        "BBRR2_FED_GRCOMP_N": str,
                        "BBRR2_FED_GRCOMP_DFLT": str,
                        "BBRR2_FED_GRCOMP_DLNQ": str,
                        "BBRR2_FED_GRCOMP_FBR": str,
                        "BBRR2_FED_GRCOMP_DFR": str,
                        "BBRR2_FED_GRCOMP_NOPROG": str,
                        "BBRR2_FED_GRCOMP_MAKEPROG": str,
                        "BBRR2_FED_GRCOMP_PAIDINFULL": str,
                        "BBRR2_FED_GRCOMP_DISCHARGE": str,
                        "BBRR2_FED_GRNOCOMP_N": str,
                        "BBRR2_FED_GRNOCOMP_DFLT": str,
                        "BBRR2_FED_GRNOCOMP_DLNQ": str,
                        "BBRR2_FED_GRNOCOMP_FBR": str,
                        "BBRR2_FED_GRNOCOMP_DFR": str,
                        "BBRR2_FED_GRNOCOMP_NOPROG": str,
                        "BBRR2_FED_GRNOCOMP_MAKEPROG": str,
                        "BBRR2_FED_GRNOCOMP_PAIDINFULL": str,
                        "BBRR2_FED_GRNOCOMP_DISCHARGE": str,
                        "BBRR2_PP_UG_N": str,
                        "BBRR2_PP_UG_DFLT": str,
                        "BBRR2_PP_UG_DLNQ": str,
                        "BBRR2_PP_UG_FBR": str,
                        "BBRR2_PP_UG_DFR": str,
                        "BBRR2_PP_UG_NOPROG": str,
                        "BBRR2_PP_UG_MAKEPROG": str,
                        "BBRR2_PP_UG_PAIDINFULL": str,
                        "BBRR2_PP_UG_DISCHARGE": str,
                        "BBRR2_PP_UGCOMP_N": str,
                        "BBRR2_PP_UGCOMP_DFLT": str,
                        "BBRR2_PP_UGCOMP_DLNQ": str,
                        "BBRR2_PP_UGCOMP_FBR": str,
                        "BBRR2_PP_UGCOMP_DFR": str,
                        "BBRR2_PP_UGCOMP_NOPROG": str,
                        "BBRR2_PP_UGCOMP_MAKEPROG": str,
                        "BBRR2_PP_UGCOMP_PAIDINFULL": str,
                        "BBRR2_PP_UGCOMP_DISCHARGE": str,
                        "BBRR2_PP_UGNOCOMP_N": str,
                        "BBRR2_PP_UGNOCOMP_DFLT": str,
                        "BBRR2_PP_UGNOCOMP_DLNQ": str,
                        "BBRR2_PP_UGNOCOMP_FBR": str,
                        "BBRR2_PP_UGNOCOMP_DFR": str,
                        "BBRR2_PP_UGNOCOMP_NOPROG": str,
                        "BBRR2_PP_UGNOCOMP_MAKEPROG": str,
                        "BBRR2_PP_UGNOCOMP_PAIDINFULL": str,
                        "BBRR2_PP_UGNOCOMP_DISCHARGE": str,
                        "BBRR2_PP_UGUNK_N": str,
                        "BBRR2_PP_UGUNK_DFLT": str,
                        "BBRR2_PP_UGUNK_DLNQ": str,
                        "BBRR2_PP_UGUNK_FBR": str,
                        "BBRR2_PP_UGUNK_DFR": str,
                        "BBRR2_PP_UGUNK_NOPROG": str,
                        "BBRR2_PP_UGUNK_MAKEPROG": str,
                        "BBRR2_PP_UGUNK_PAIDINFULL": str,
                        "BBRR2_PP_UGUNK_DISCHARGE": str,
                        "BBRR2_FED_UG_N_SUPP": float,
                        "BBRR2_FED_UG_DFLT_SUPP": float,
                        "BBRR2_FED_UG_DLNQ_SUPP": float,
                        "BBRR2_FED_UG_FBR_SUPP": float,
                        "BBRR2_FED_UG_DFR_SUPP": float,
                        "BBRR2_FED_UG_NOPROG_SUPP": float,
                        "BBRR2_FED_UG_MAKEPROG_SUPP": float,
                        "BBRR2_FED_UG_PAIDINFULL_SUPP": float,
                        "BBRR2_FED_UG_DISCHARGE_SUPP": float,
                        "BBRR2_FED_UGCOMP_N_SUPP": float,
                        "BBRR2_FED_UGCOMP_DFLT_SUPP": float,
                        "BBRR2_FED_UGCOMP_DLNQ_SUPP": float,
                        "BBRR2_FED_UGCOMP_FBR_SUPP": float,
                        "BBRR2_FED_UGCOMP_DFR_SUPP": float,
                        "BBRR2_FED_UGCOMP_NOPROG_SUPP": float,
                        "BBRR2_FED_UGCOMP_MAKEPROG_SUPP": float,
                        "BBRR2_FED_UGCOMP_PAIDINFULL_SUPP": float,
                        "BBRR2_FED_UGCOMP_DISCHARGE_SUPP": float,
                        "LPSTAFFORD_CNT": str,
                        "LPSTAFFORD_AMT": str,
                        "LPPPLUS_CNT": str,
                        "LPPPLUS_AMT": str,
                        "LPGPLUS_CNT": str,
                        "LPGPLUS_AMT": str,
                        "FEDSCHCD": float,
                        "BOOKSUPPLY": float,
                        "ROOMBOARD_ON": float,
                        "OTHEREXPENSE_ON": float,
                        "ROOMBOARD_OFF": float,
                        "OTHEREXPENSE_OFF": float,
                        "OTHEREXPENSE_FAM": float,
                        "ENDOWBEGIN": float,
                        "ENDOWEND": float,
                        "DOLPROVIDER": float,
                        "ADMCON7": float,
                        "MDCOMP_PD": float,
                        "MDCOST_PD": float,
                        "MDEARN_PD": float,
                        "MDCOMP_ALL": float,
                        "MDCOST_ALL": float,
                        "MDEARN_ALL": float,
                        "D150_L4_PELL_POOLED": float,
                        "C150_L4_PELL_POOLED": float,
                        "D150_4_PELL_POOLED": float,
                        "C150_4_PELL_POOLED": float,
                        "C150_L4_PELL_POOLED_SUPP": float,
                        "C150_4_PELL_POOLED_SUPP": float,
                        "POOLYRS150_PELL": float,
                        "OMENRYP_PELL_ALL": float,
                        "OMENRAP_PELL_ALL": float,
                        "OMAWDP8_PELL_ALL": float,
                        "OMENRUP_PELL_ALL": float,
                        "OMENRYP_PELL_FIRSTTIME": float,
                        "OMENRAP_PELL_FIRSTTIME": float,
                        "OMAWDP8_PELL_FIRSTTIME": float,
                        "OMENRUP_PELL_FIRSTTIME": float,
                        "OMENRYP_PELL_NOTFIRSTTIME": float,
                        "OMENRAP_PELL_NOTFIRSTTIME": float,
                        "OMAWDP8_PELL_NOTFIRSTTIME": float,
                        "OMENRUP_PELL_NOTFIRSTTIME": float,
                        "OMENRYP_PELL_FULLTIME": float,
                        "OMENRAP_PELL_FULLTIME": float,
                        "OMAWDP8_PELL_FULLTIME": float,
                        "OMENRUP_PELL_FULLTIME": float,
                        "OMENRYP_PELL_PARTTIME": float,
                        "OMENRAP_PELL_PARTTIME": float,
                        "OMAWDP8_PELL_PARTTIME": float,
                        "OMENRUP_PELL_PARTTIME": float,
                        "OMACHT8_PELL_FTFT": float,
                        "OMAWDP8_PELL_FTFT": float,
                        "OMENRYP8_PELL_FTFT": float,
                        "OMENRAP8_PELL_FTFT": float,
                        "OMENRUP8_PELL_FTFT": float,
                        "OMACHT8_PELL_PTFT": float,
                        "OMAWDP8_PELL_PTFT": float,
                        "OMENRYP8_PELL_PTFT": float,
                        "OMENRAP8_PELL_PTFT": float,
                        "OMENRUP8_PELL_PTFT": float,
                        "OMACHT8_PELL_FTNFT": float,
                        "OMAWDP8_PELL_FTNFT": float,
                        "OMENRYP8_PELL_FTNFT": float,
                        "OMENRAP8_PELL_FTNFT": float,
                        "OMENRUP8_PELL_FTNFT": float,
                        "OMACHT8_PELL_PTNFT": float,
                        "OMAWDP8_PELL_PTNFT": float,
                        "OMENRYP8_PELL_PTNFT": float,
                        "OMENRAP8_PELL_PTNFT": float,
                        "OMENRUP8_PELL_PTNFT": float,
                        "OMACHT8_PELL_FTFT_POOLED": float,
                        "OMACHT8_PELL_PTFT_POOLED": float,
                        "OMACHT8_PELL_FTNFT_POOLED": float,
                        "OMACHT8_PELL_PTNFT_POOLED": float,
                        "OMAWDP8_PELL_FTFT_POOLED": float,
                        "OMENRYP8_PELL_FTFT_POOLED": float,
                        "OMENRAP8_PELL_FTFT_POOLED": float,
                        "OMENRUP8_PELL_FTFT_POOLED": float,
                        "OMAWDP8_PELL_PTFT_POOLED": float,
                        "OMENRYP8_PELL_PTFT_POOLED": float,
                        "OMENRAP8_PELL_PTFT_POOLED": float,
                        "OMENRUP8_PELL_PTFT_POOLED": float,
                        "OMAWDP8_PELL_FTNFT_POOLED": float,
                        "OMENRYP8_PELL_FTNFT_POOLED": float,
                        "OMENRAP8_PELL_FTNFT_POOLED": float,
                        "OMENRUP8_PELL_FTNFT_POOLED": float,
                        "OMAWDP8_PELL_PTNFT_POOLED": float,
                        "OMENRYP8_PELL_PTNFT_POOLED": float,
                        "OMENRAP8_PELL_PTNFT_POOLED": float,
                        "OMENRUP8_PELL_PTNFT_POOLED": float,
                        "OMENRYP_PELL_ALL_POOLED": float,
                        "OMENRAP_PELL_ALL_POOLED": float,
                        "OMAWDP8_PELL_ALL_POOLED": float,
                        "OMENRUP_PELL_ALL_POOLED": float,
                        "OMENRYP_PELL_FTT_POOLED": float,
                        "OMENRAP_PELL_FTT_POOLED": float,
                        "OMAWDP8_PELL_FTT_POOLED": float,
                        "OMENRUP_PELL_FTT_POOLED": float,
                        "OMENRYP_PELL_NFT_POOLED": float,
                        "OMENRAP_PELL_NFT_POOLED": float,
                        "OMAWDP8_PELL_NFT_POOLED": float,
                        "OMENRUP_PELL_NFT_POOLED": float,
                        "OMENRYP_PELL_FT_POOLED": float,
                        "OMENRAP_PELL_FT_POOLED": float,
                        "OMAWDP8_PELL_FT_POOLED": float,
                        "OMENRUP_PELL_FT_POOLED": float,
                        "OMENRYP_PELL_PT_POOLED": float,
                        "OMENRAP_PELL_PT_POOLED": float,
                        "OMAWDP8_PELL_PT_POOLED": float,
                        "OMENRUP_PELL_PT_POOLED": float,
                        "POOLYRSOM_PELL_FTFT": float,
                        "POOLYRSOM_PELL_PTFT": float,
                        "POOLYRSOM_PELL_FTNFT": float,
                        "POOLYRSOM_PELL_PTNFT": float,
                        "POOLYRSOM_PELL_ALL": float,
                        "POOLYRSOM_PELL_FIRSTTIME": float,
                        "POOLYRSOM_PELL_NOTFIRSTTIME": float,
                        "POOLYRSOM_PELL_FULLTIME": float,
                        "POOLYRSOM_PELL_PARTTIME": float,
                        "OMAWDP8_PELL_FTFT_POOLED_SUPP": float,
                        "OMENRYP8_PELL_FTFT_POOLED_SUPP": float,
                        "OMENRAP8_PELL_FTFT_POOLED_SUPP": float,
                        "OMENRUP8_PELL_FTFT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_PTFT_POOLED_SUPP": float,
                        "OMENRYP8_PELL_PTFT_POOLED_SUPP": float,
                        "OMENRAP8_PELL_PTFT_POOLED_SUPP": float,
                        "OMENRUP8_PELL_PTFT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_FTNFT_POOLED_SUPP": float,
                        "OMENRYP8_PELL_FTNFT_POOLED_SUPP": float,
                        "OMENRAP8_PELL_FTNFT_POOLED_SUPP": float,
                        "OMENRUP8_PELL_FTNFT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_PTNFT_POOLED_SUPP": float,
                        "OMENRYP8_PELL_PTNFT_POOLED_SUPP": float,
                        "OMENRAP8_PELL_PTNFT_POOLED_SUPP": float,
                        "OMENRUP8_PELL_PTNFT_POOLED_SUPP": float,
                        "OMENRYP_PELL_ALL_POOLED_SUPP": float,
                        "OMENRAP_PELL_ALL_POOLED_SUPP": float,
                        "OMAWDP8_PELL_ALL_POOLED_SUPP": float,
                        "OMENRUP_PELL_ALL_POOLED_SUPP": float,
                        "OMENRYP_PELL_FTT_POOLED_SUPP": float,
                        "OMENRAP_PELL_FTT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_FTT_POOLED_SUPP": float,
                        "OMENRUP_PELL_FTT_POOLED_SUPP": float,
                        "OMENRYP_PELL_NFT_POOLED_SUPP": float,
                        "OMENRAP_PELL_NFT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_NFT_POOLED_SUPP": float,
                        "OMENRUP_PELL_NFT_POOLED_SUPP": float,
                        "OMENRYP_PELL_FT_POOLED_SUPP": float,
                        "OMENRAP_PELL_FT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_FT_POOLED_SUPP": float,
                        "OMENRUP_PELL_FT_POOLED_SUPP": float,
                        "OMENRYP_PELL_PT_POOLED_SUPP": float,
                        "OMENRAP_PELL_PT_POOLED_SUPP": float,
                        "OMAWDP8_PELL_PT_POOLED_SUPP": float,
                        "OMENRUP_PELL_PT_POOLED_SUPP": float,
                        "BBRR1_FED_IND_N": str,
                        "BBRR1_FED_IND_DFLT": str,
                        "BBRR1_FED_IND_DLNQ": str,
                        "BBRR1_FED_IND_FBR": str,
                        "BBRR1_FED_IND_DFR": str,
                        "BBRR1_FED_IND_NOPROG": str,
                        "BBRR1_FED_IND_MAKEPROG": str,
                        "BBRR1_FED_IND_PAIDINFULL": str,
                        "BBRR1_FED_IND_DISCHARGE": str,
                        "BBRR1_FED_DEP_N": str,
                        "BBRR1_FED_DEP_DFLT": str,
                        "BBRR1_FED_DEP_DLNQ": str,
                        "BBRR1_FED_DEP_FBR": str,
                        "BBRR1_FED_DEP_DFR": str,
                        "BBRR1_FED_DEP_NOPROG": str,
                        "BBRR1_FED_DEP_MAKEPROG": str,
                        "BBRR1_FED_DEP_PAIDINFULL": str,
                        "BBRR1_FED_DEP_DISCHARGE": str,
                        "BBRR1_FED_PELL_N": str,
                        "BBRR1_FED_PELL_DFLT": str,
                        "BBRR1_FED_PELL_DLNQ": str,
                        "BBRR1_FED_PELL_FBR": str,
                        "BBRR1_FED_PELL_DFR": str,
                        "BBRR1_FED_PELL_NOPROG": str,
                        "BBRR1_FED_PELL_MAKEPROG": str,
                        "BBRR1_FED_PELL_PAIDINFULL": str,
                        "BBRR1_FED_PELL_DISCHARGE": str,
                        "BBRR1_FED_NOPELL_N": str,
                        "BBRR1_FED_NOPELL_DFLT": str,
                        "BBRR1_FED_NOPELL_DLNQ": str,
                        "BBRR1_FED_NOPELL_FBR": str,
                        "BBRR1_FED_NOPELL_DFR": str,
                        "BBRR1_FED_NOPELL_NOPROG": str,
                        "BBRR1_FED_NOPELL_MAKEPROG": str,
                        "BBRR1_FED_NOPELL_PAIDINFULL": str,
                        "BBRR1_FED_NOPELL_DISCHARGE": str,
                        "BBRR1_FED_MALE_N": str,
                        "BBRR1_FED_MALE_DFLT": str,
                        "BBRR1_FED_MALE_DLNQ": str,
                        "BBRR1_FED_MALE_FBR": str,
                        "BBRR1_FED_MALE_DFR": str,
                        "BBRR1_FED_MALE_NOPROG": str,
                        "BBRR1_FED_MALE_MAKEPROG": str,
                        "BBRR1_FED_MALE_PAIDINFULL": str,
                        "BBRR1_FED_MALE_DISCHARGE": str,
                        "BBRR1_FED_NOMALE_N": str,
                        "BBRR1_FED_NOMALE_DFLT": str,
                        "BBRR1_FED_NOMALE_DLNQ": str,
                        "BBRR1_FED_NOMALE_FBR": str,
                        "BBRR1_FED_NOMALE_DFR": str,
                        "BBRR1_FED_NOMALE_NOPROG": str,
                        "BBRR1_FED_NOMALE_MAKEPROG": str,
                        "BBRR1_FED_NOMALE_PAIDINFULL": str,
                        "BBRR1_FED_NOMALE_DISCHARGE": str,
                        "BBRR1_PP_IND_N": str,
                        "BBRR1_PP_IND_DFLT": str,
                        "BBRR1_PP_IND_DLNQ": str,
                        "BBRR1_PP_IND_FBR": str,
                        "BBRR1_PP_IND_DFR": str,
                        "BBRR1_PP_IND_NOPROG": str,
                        "BBRR1_PP_IND_MAKEPROG": str,
                        "BBRR1_PP_IND_PAIDINFULL": str,
                        "BBRR1_PP_IND_DISCHARGE": str,
                        "BBRR1_PP_DEP_N": str,
                        "BBRR1_PP_DEP_DFLT": str,
                        "BBRR1_PP_DEP_DLNQ": str,
                        "BBRR1_PP_DEP_FBR": str,
                        "BBRR1_PP_DEP_DFR": str,
                        "BBRR1_PP_DEP_NOPROG": str,
                        "BBRR1_PP_DEP_MAKEPROG": str,
                        "BBRR1_PP_DEP_PAIDINFULL": str,
                        "BBRR1_PP_DEP_DISCHARGE": str,
                        "BBRR1_PP_PELL_N": str,
                        "BBRR1_PP_PELL_DFLT": str,
                        "BBRR1_PP_PELL_DLNQ": str,
                        "BBRR1_PP_PELL_FBR": str,
                        "BBRR1_PP_PELL_DFR": str,
                        "BBRR1_PP_PELL_NOPROG": str,
                        "BBRR1_PP_PELL_MAKEPROG": str,
                        "BBRR1_PP_PELL_PAIDINFULL": str,
                        "BBRR1_PP_PELL_DISCHARGE": str,
                        "BBRR1_PP_NOPELL_N": str,
                        "BBRR1_PP_NOPELL_DFLT": str,
                        "BBRR1_PP_NOPELL_DLNQ": str,
                        "BBRR1_PP_NOPELL_FBR": str,
                        "BBRR1_PP_NOPELL_DFR": str,
                        "BBRR1_PP_NOPELL_NOPROG": str,
                        "BBRR1_PP_NOPELL_MAKEPROG": str,
                        "BBRR1_PP_NOPELL_PAIDINFULL": str,
                        "BBRR1_PP_NOPELL_DISCHARGE": str,
                        "BBRR1_PP_MALE_N": str,
                        "BBRR1_PP_MALE_DFLT": str,
                        "BBRR1_PP_MALE_DLNQ": str,
                        "BBRR1_PP_MALE_FBR": str,
                        "BBRR1_PP_MALE_DFR": str,
                        "BBRR1_PP_MALE_NOPROG": str,
                        "BBRR1_PP_MALE_MAKEPROG": str,
                        "BBRR1_PP_MALE_PAIDINFULL": str,
                        "BBRR1_PP_MALE_DISCHARGE": str,
                        "BBRR1_PP_NOMALE_N": str,
                        "BBRR1_PP_NOMALE_DFLT": str,
                        "BBRR1_PP_NOMALE_DLNQ": str,
                        "BBRR1_PP_NOMALE_FBR": str,
                        "BBRR1_PP_NOMALE_DFR": str,
                        "BBRR1_PP_NOMALE_NOPROG": str,
                        "BBRR1_PP_NOMALE_MAKEPROG": str,
                        "BBRR1_PP_NOMALE_PAIDINFULL": str,
                        "BBRR1_PP_NOMALE_DISCHARGE": str,
                        "BBRR2_FED_IND_N": str,
                        "BBRR2_FED_IND_DFLT": str,
                        "BBRR2_FED_IND_DLNQ": str,
                        "BBRR2_FED_IND_FBR": str,
                        "BBRR2_FED_IND_DFR": str,
                        "BBRR2_FED_IND_NOPROG": str,
                        "BBRR2_FED_IND_MAKEPROG": str,
                        "BBRR2_FED_IND_PAIDINFULL": str,
                        "BBRR2_FED_IND_DISCHARGE": str,
                        "BBRR2_FED_DEP_N": str,
                        "BBRR2_FED_DEP_DFLT": str,
                        "BBRR2_FED_DEP_DLNQ": str,
                        "BBRR2_FED_DEP_FBR": str,
                        "BBRR2_FED_DEP_DFR": str,
                        "BBRR2_FED_DEP_NOPROG": str,
                        "BBRR2_FED_DEP_MAKEPROG": str,
                        "BBRR2_FED_DEP_PAIDINFULL": str,
                        "BBRR2_FED_DEP_DISCHARGE": str,
                        "BBRR2_FED_PELL_N": str,
                        "BBRR2_FED_PELL_DFLT": str,
                        "BBRR2_FED_PELL_DLNQ": str,
                        "BBRR2_FED_PELL_FBR": str,
                        "BBRR2_FED_PELL_DFR": str,
                        "BBRR2_FED_PELL_NOPROG": str,
                        "BBRR2_FED_PELL_MAKEPROG": str,
                        "BBRR2_FED_PELL_PAIDINFULL": str,
                        "BBRR2_FED_PELL_DISCHARGE": str,
                        "BBRR2_FED_NOPELL_N": str,
                        "BBRR2_FED_NOPELL_DFLT": str,
                        "BBRR2_FED_NOPELL_DLNQ": str,
                        "BBRR2_FED_NOPELL_FBR": str,
                        "BBRR2_FED_NOPELL_DFR": str,
                        "BBRR2_FED_NOPELL_NOPROG": str,
                        "BBRR2_FED_NOPELL_MAKEPROG": str,
                        "BBRR2_FED_NOPELL_PAIDINFULL": str,
                        "BBRR2_FED_NOPELL_DISCHARGE": str,
                        "BBRR2_FED_MALE_N": str,
                        "BBRR2_FED_MALE_DFLT": str,
                        "BBRR2_FED_MALE_DLNQ": str,
                        "BBRR2_FED_MALE_FBR": str,
                        "BBRR2_FED_MALE_DFR": str,
                        "BBRR2_FED_MALE_NOPROG": str,
                        "BBRR2_FED_MALE_MAKEPROG": str,
                        "BBRR2_FED_MALE_PAIDINFULL": str,
                        "BBRR2_FED_MALE_DISCHARGE": str,
                        "BBRR2_FED_NOMALE_N": str,
                        "BBRR2_FED_NOMALE_DFLT": str,
                        "BBRR2_FED_NOMALE_DLNQ": str,
                        "BBRR2_FED_NOMALE_FBR": str,
                        "BBRR2_FED_NOMALE_DFR": str,
                        "BBRR2_FED_NOMALE_NOPROG": str,
                        "BBRR2_FED_NOMALE_MAKEPROG": str,
                        "BBRR2_FED_NOMALE_PAIDINFULL": str,
                        "BBRR2_FED_NOMALE_DISCHARGE": str,
                        "BBRR2_PP_IND_N": str,
                        "BBRR2_PP_IND_DFLT": str,
                        "BBRR2_PP_IND_DLNQ": str,
                        "BBRR2_PP_IND_FBR": str,
                        "BBRR2_PP_IND_DFR": str,
                        "BBRR2_PP_IND_NOPROG": str,
                        "BBRR2_PP_IND_MAKEPROG": str,
                        "BBRR2_PP_IND_PAIDINFULL": str,
                        "BBRR2_PP_IND_DISCHARGE": str,
                        "BBRR2_PP_DEP_N": str,
                        "BBRR2_PP_DEP_DFLT": str,
                        "BBRR2_PP_DEP_DLNQ": str,
                        "BBRR2_PP_DEP_FBR": str,
                        "BBRR2_PP_DEP_DFR": str,
                        "BBRR2_PP_DEP_NOPROG": str,
                        "BBRR2_PP_DEP_MAKEPROG": str,
                        "BBRR2_PP_DEP_PAIDINFULL": str,
                        "BBRR2_PP_DEP_DISCHARGE": str,
                        "BBRR2_PP_PELL_N": str,
                        "BBRR2_PP_PELL_DFLT": str,
                        "BBRR2_PP_PELL_DLNQ": str,
                        "BBRR2_PP_PELL_FBR": str,
                        "BBRR2_PP_PELL_DFR": str,
                        "BBRR2_PP_PELL_NOPROG": str,
                        "BBRR2_PP_PELL_MAKEPROG": str,
                        "BBRR2_PP_PELL_PAIDINFULL": str,
                        "BBRR2_PP_PELL_DISCHARGE": str,
                        "BBRR2_PP_NOPELL_N": str,
                        "BBRR2_PP_NOPELL_DFLT": str,
                        "BBRR2_PP_NOPELL_DLNQ": str,
                        "BBRR2_PP_NOPELL_FBR": str,
                        "BBRR2_PP_NOPELL_DFR": str,
                        "BBRR2_PP_NOPELL_NOPROG": str,
                        "BBRR2_PP_NOPELL_MAKEPROG": str,
                        "BBRR2_PP_NOPELL_PAIDINFULL": str,
                        "BBRR2_PP_NOPELL_DISCHARGE": str,
                        "BBRR2_PP_MALE_N": str,
                        "BBRR2_PP_MALE_DFLT": str,
                        "BBRR2_PP_MALE_DLNQ": str,
                        "BBRR2_PP_MALE_FBR": str,
                        "BBRR2_PP_MALE_DFR": str,
                        "BBRR2_PP_MALE_NOPROG": str,
                        "BBRR2_PP_MALE_MAKEPROG": str,
                        "BBRR2_PP_MALE_PAIDINFULL": str,
                        "BBRR2_PP_MALE_DISCHARGE": str,
                        "BBRR2_PP_NOMALE_N": str,
                        "BBRR2_PP_NOMALE_DFLT": str,
                        "BBRR2_PP_NOMALE_DLNQ": str,
                        "BBRR2_PP_NOMALE_FBR": str,
                        "BBRR2_PP_NOMALE_DFR": str,
                        "BBRR2_PP_NOMALE_NOPROG": str,
                        "BBRR2_PP_NOMALE_MAKEPROG": str,
                        "BBRR2_PP_NOMALE_PAIDINFULL": str,
                        "BBRR2_PP_NOMALE_DISCHARGE": str,
                        "BBRR3_FED_UG_N": str,
                        "BBRR3_FED_UG_DFLT": str,
                        "BBRR3_FED_UG_DLNQ": str,
                        "BBRR3_FED_UG_FBR": str,
                        "BBRR3_FED_UG_DFR": str,
                        "BBRR3_FED_UG_NOPROG": str,
                        "BBRR3_FED_UG_MAKEPROG": str,
                        "BBRR3_FED_UG_PAIDINFULL": str,
                        "BBRR3_FED_UG_DISCHARGE": str,
                        "BBRR3_FED_UGCOMP_N": str,
                        "BBRR3_FED_UGCOMP_DFLT": str,
                        "BBRR3_FED_UGCOMP_DLNQ": str,
                        "BBRR3_FED_UGCOMP_FBR": str,
                        "BBRR3_FED_UGCOMP_DFR": str,
                        "BBRR3_FED_UGCOMP_NOPROG": str,
                        "BBRR3_FED_UGCOMP_MAKEPROG": str,
                        "BBRR3_FED_UGCOMP_PAIDINFULL": str,
                        "BBRR3_FED_UGCOMP_DISCHARGE": str,
                        "BBRR3_FED_UGNOCOMP_N": str,
                        "BBRR3_FED_UGNOCOMP_DFLT": str,
                        "BBRR3_FED_UGNOCOMP_DLNQ": str,
                        "BBRR3_FED_UGNOCOMP_FBR": str,
                        "BBRR3_FED_UGNOCOMP_DFR": str,
                        "BBRR3_FED_UGNOCOMP_NOPROG": str,
                        "BBRR3_FED_UGNOCOMP_MAKEPROG": str,
                        "BBRR3_FED_UGNOCOMP_PAIDINFULL": str,
                        "BBRR3_FED_UGNOCOMP_DISCHARGE": str,
                        "BBRR3_FED_UGUNK_N": str,
                        "BBRR3_FED_UGUNK_DFLT": str,
                        "BBRR3_FED_UGUNK_DLNQ": str,
                        "BBRR3_FED_UGUNK_FBR": str,
                        "BBRR3_FED_UGUNK_DFR": str,
                        "BBRR3_FED_UGUNK_NOPROG": str,
                        "BBRR3_FED_UGUNK_MAKEPROG": str,
                        "BBRR3_FED_UGUNK_PAIDINFULL": str,
                        "BBRR3_FED_UGUNK_DISCHARGE": str,
                        "BBRR3_FED_GR_N": str,
                        "BBRR3_FED_GR_DFLT": str,
                        "BBRR3_FED_GR_DLNQ": str,
                        "BBRR3_FED_GR_FBR": str,
                        "BBRR3_FED_GR_DFR": str,
                        "BBRR3_FED_GR_NOPROG": str,
                        "BBRR3_FED_GR_MAKEPROG": str,
                        "BBRR3_FED_GR_PAIDINFULL": str,
                        "BBRR3_FED_GR_DISCHARGE": str,
                        "BBRR3_FED_GRCOMP_N": str,
                        "BBRR3_FED_GRCOMP_DFLT": str,
                        "BBRR3_FED_GRCOMP_DLNQ": str,
                        "BBRR3_FED_GRCOMP_FBR": str,
                        "BBRR3_FED_GRCOMP_DFR": str,
                        "BBRR3_FED_GRCOMP_NOPROG": str,
                        "BBRR3_FED_GRCOMP_MAKEPROG": str,
                        "BBRR3_FED_GRCOMP_PAIDINFULL": str,
                        "BBRR3_FED_GRCOMP_DISCHARGE": str,
                        "BBRR3_FED_GRNOCOMP_N": str,
                        "BBRR3_FED_GRNOCOMP_DFLT": str,
                        "BBRR3_FED_GRNOCOMP_DLNQ": str,
                        "BBRR3_FED_GRNOCOMP_FBR": str,
                        "BBRR3_FED_GRNOCOMP_DFR": str,
                        "BBRR3_FED_GRNOCOMP_NOPROG": str,
                        "BBRR3_FED_GRNOCOMP_MAKEPROG": str,
                        "BBRR3_FED_GRNOCOMP_PAIDINFULL": str,
                        "BBRR3_FED_GRNOCOMP_DISCHARGE": str,
                        "BBRR3_PP_UG_N": str,
                        "BBRR3_PP_UG_DFLT": str,
                        "BBRR3_PP_UG_DLNQ": str,
                        "BBRR3_PP_UG_FBR": str,
                        "BBRR3_PP_UG_DFR": str,
                        "BBRR3_PP_UG_NOPROG": str,
                        "BBRR3_PP_UG_MAKEPROG": str,
                        "BBRR3_PP_UG_PAIDINFULL": str,
                        "BBRR3_PP_UG_DISCHARGE": str,
                        "BBRR3_PP_UGCOMP_N": str,
                        "BBRR3_PP_UGCOMP_DFLT": str,
                        "BBRR3_PP_UGCOMP_DLNQ": str,
                        "BBRR3_PP_UGCOMP_FBR": str,
                        "BBRR3_PP_UGCOMP_DFR": str,
                        "BBRR3_PP_UGCOMP_NOPROG": str,
                        "BBRR3_PP_UGCOMP_MAKEPROG": str,
                        "BBRR3_PP_UGCOMP_PAIDINFULL": str,
                        "BBRR3_PP_UGCOMP_DISCHARGE": str,
                        "BBRR3_PP_UGNOCOMP_N": str,
                        "BBRR3_PP_UGNOCOMP_DFLT": str,
                        "BBRR3_PP_UGNOCOMP_DLNQ": str,
                        "BBRR3_PP_UGNOCOMP_FBR": str,
                        "BBRR3_PP_UGNOCOMP_DFR": str,
                        "BBRR3_PP_UGNOCOMP_NOPROG": str,
                        "BBRR3_PP_UGNOCOMP_MAKEPROG": str,
                        "BBRR3_PP_UGNOCOMP_PAIDINFULL": str,
                        "BBRR3_PP_UGNOCOMP_DISCHARGE": str,
                        "BBRR3_PP_UGUNK_N": str,
                        "BBRR3_PP_UGUNK_DFLT": str,
                        "BBRR3_PP_UGUNK_DLNQ": str,
                        "BBRR3_PP_UGUNK_FBR": str,
                        "BBRR3_PP_UGUNK_DFR": str,
                        "BBRR3_PP_UGUNK_NOPROG": str,
                        "BBRR3_PP_UGUNK_MAKEPROG": str,
                        "BBRR3_PP_UGUNK_PAIDINFULL": str,
                        "BBRR3_PP_UGUNK_DISCHARGE": str,
                        "BBRR3_FED_IND_N": str,
                        "BBRR3_FED_IND_DFLT": str,
                        "BBRR3_FED_IND_DLNQ": str,
                        "BBRR3_FED_IND_FBR": str,
                        "BBRR3_FED_IND_DFR": str,
                        "BBRR3_FED_IND_NOPROG": str,
                        "BBRR3_FED_IND_MAKEPROG": str,
                        "BBRR3_FED_IND_PAIDINFULL": str,
                        "BBRR3_FED_IND_DISCHARGE": str,
                        "BBRR3_FED_DEP_N": str,
                        "BBRR3_FED_DEP_DFLT": str,
                        "BBRR3_FED_DEP_DLNQ": str,
                        "BBRR3_FED_DEP_FBR": str,
                        "BBRR3_FED_DEP_DFR": str,
                        "BBRR3_FED_DEP_NOPROG": str,
                        "BBRR3_FED_DEP_MAKEPROG": str,
                        "BBRR3_FED_DEP_PAIDINFULL": str,
                        "BBRR3_FED_DEP_DISCHARGE": str,
                        "BBRR3_FED_PELL_N": str,
                        "BBRR3_FED_PELL_DFLT": str,
                        "BBRR3_FED_PELL_DLNQ": str,
                        "BBRR3_FED_PELL_FBR": str,
                        "BBRR3_FED_PELL_DFR": str,
                        "BBRR3_FED_PELL_NOPROG": str,
                        "BBRR3_FED_PELL_MAKEPROG": str,
                        "BBRR3_FED_PELL_PAIDINFULL": str,
                        "BBRR3_FED_PELL_DISCHARGE": str,
                        "BBRR3_FED_NOPELL_N": str,
                        "BBRR3_FED_NOPELL_DFLT": str,
                        "BBRR3_FED_NOPELL_DLNQ": str,
                        "BBRR3_FED_NOPELL_FBR": str,
                        "BBRR3_FED_NOPELL_DFR": str,
                        "BBRR3_FED_NOPELL_NOPROG": str,
                        "BBRR3_FED_NOPELL_MAKEPROG": str,
                        "BBRR3_FED_NOPELL_PAIDINFULL": str,
                        "BBRR3_FED_NOPELL_DISCHARGE": str,
                        "BBRR3_FED_MALE_N": str,
                        "BBRR3_FED_MALE_DFLT": str,
                        "BBRR3_FED_MALE_DLNQ": str,
                        "BBRR3_FED_MALE_FBR": str,
                        "BBRR3_FED_MALE_DFR": str,
                        "BBRR3_FED_MALE_NOPROG": str,
                        "BBRR3_FED_MALE_MAKEPROG": str,
                        "BBRR3_FED_MALE_PAIDINFULL": str,
                        "BBRR3_FED_MALE_DISCHARGE": str,
                        "BBRR3_FED_NOMALE_N": str,
                        "BBRR3_FED_NOMALE_DFLT": str,
                        "BBRR3_FED_NOMALE_DLNQ": str,
                        "BBRR3_FED_NOMALE_FBR": str,
                        "BBRR3_FED_NOMALE_DFR": str,
                        "BBRR3_FED_NOMALE_NOPROG": str,
                        "BBRR3_FED_NOMALE_MAKEPROG": str,
                        "BBRR3_FED_NOMALE_PAIDINFULL": str,
                        "BBRR3_FED_NOMALE_DISCHARGE": str,
                        "BBRR3_PP_IND_N": str,
                        "BBRR3_PP_IND_DFLT": str,
                        "BBRR3_PP_IND_DLNQ": str,
                        "BBRR3_PP_IND_FBR": str,
                        "BBRR3_PP_IND_DFR": str,
                        "BBRR3_PP_IND_NOPROG": str,
                        "BBRR3_PP_IND_MAKEPROG": str,
                        "BBRR3_PP_IND_PAIDINFULL": str,
                        "BBRR3_PP_IND_DISCHARGE": str,
                        "BBRR3_PP_DEP_N": str,
                        "BBRR3_PP_DEP_DFLT": str,
                        "BBRR3_PP_DEP_DLNQ": str,
                        "BBRR3_PP_DEP_FBR": str,
                        "BBRR3_PP_DEP_DFR": str,
                        "BBRR3_PP_DEP_NOPROG": str,
                        "BBRR3_PP_DEP_MAKEPROG": str,
                        "BBRR3_PP_DEP_PAIDINFULL": str,
                        "BBRR3_PP_DEP_DISCHARGE": str,
                        "BBRR3_PP_PELL_N": str,
                        "BBRR3_PP_PELL_DFLT": str,
                        "BBRR3_PP_PELL_DLNQ": str,
                        "BBRR3_PP_PELL_FBR": str,
                        "BBRR3_PP_PELL_DFR": str,
                        "BBRR3_PP_PELL_NOPROG": str,
                        "BBRR3_PP_PELL_MAKEPROG": str,
                        "BBRR3_PP_PELL_PAIDINFULL": str,
                        "BBRR3_PP_PELL_DISCHARGE": str,
                        "BBRR3_PP_NOPELL_N": str,
                        "BBRR3_PP_NOPELL_DFLT": str,
                        "BBRR3_PP_NOPELL_DLNQ": str,
                        "BBRR3_PP_NOPELL_FBR": str,
                        "BBRR3_PP_NOPELL_DFR": str,
                        "BBRR3_PP_NOPELL_NOPROG": str,
                        "BBRR3_PP_NOPELL_MAKEPROG": str,
                        "BBRR3_PP_NOPELL_PAIDINFULL": str,
                        "BBRR3_PP_NOPELL_DISCHARGE": str,
                        "BBRR3_PP_MALE_N": str,
                        "BBRR3_PP_MALE_DFLT": str,
                        "BBRR3_PP_MALE_DLNQ": str,
                        "BBRR3_PP_MALE_FBR": str,
                        "BBRR3_PP_MALE_DFR": str,
                        "BBRR3_PP_MALE_NOPROG": str,
                        "BBRR3_PP_MALE_MAKEPROG": str,
                        "BBRR3_PP_MALE_PAIDINFULL": str,
                        "BBRR3_PP_MALE_DISCHARGE": str,
                        "BBRR3_PP_NOMALE_N": str,
                        "BBRR3_PP_NOMALE_DFLT": str,
                        "BBRR3_PP_NOMALE_DLNQ": str,
                        "BBRR3_PP_NOMALE_FBR": str,
                        "BBRR3_PP_NOMALE_DFR": str,
                        "BBRR3_PP_NOMALE_NOPROG": str,
                        "BBRR3_PP_NOMALE_MAKEPROG": str,
                        "BBRR3_PP_NOMALE_PAIDINFULL": str,
                        "BBRR3_PP_NOMALE_DISCHARGE": str,
                        "COUNT_NWNE_1YR": float,
                        "COUNT_WNE_1YR": float,
                        "CNTOVER150_1YR": float,
                        "GT_THRESHOLD_P6": float,
                        "GT_THRESHOLD_P6_SUPP": str,
                        "MD_EARN_WNE_INC1_P6": float,
                        "MD_EARN_WNE_INC2_P6": float,
                        "MD_EARN_WNE_INC3_P6": float,
                        "MD_EARN_WNE_INDEP1_P6": float,
                        "MD_EARN_WNE_INDEP0_P6": float,
                        "MD_EARN_WNE_MALE0_P6": float,
                        "MD_EARN_WNE_MALE1_P6": float,
                        "GT_THRESHOLD_P8": float,
                        "COUNT_WNE_INC1_P8": float,
                        "MD_EARN_WNE_INC1_P8": float,
                        "COUNT_WNE_INC2_P8": float,
                        "MD_EARN_WNE_INC2_P8": float,
                        "COUNT_WNE_INC3_P8": float,
                        "MD_EARN_WNE_INC3_P8": float,
                        "COUNT_WNE_INDEP1_P8": float,
                        "MD_EARN_WNE_INDEP1_P8": float,
                        "COUNT_WNE_INDEP0_P8": float,
                        "MD_EARN_WNE_INDEP0_P8": float,
                        "COUNT_WNE_MALE0_P8": float,
                        "MD_EARN_WNE_MALE0_P8": float,
                        "COUNT_WNE_MALE1_P8": float,
                        "MD_EARN_WNE_MALE1_P8": float,
                        "GT_THRESHOLD_P10": float,
                        "MD_EARN_WNE_INC1_P10": float,
                        "MD_EARN_WNE_INC2_P10": float,
                        "MD_EARN_WNE_INC3_P10": float,
                        "MD_EARN_WNE_INDEP1_P10": float,
                        "MD_EARN_WNE_INDEP0_P10": float,
                        "MD_EARN_WNE_MALE0_P10": float,
                        "MD_EARN_WNE_MALE1_P10": float,
                        "STUFACR": float,
                        "IRPS_2MOR": float,
                        "IRPS_AIAN": float,
                        "IRPS_ASIAN": float,
                        "IRPS_BLACK": float,
                        "IRPS_HISP": float,
                        "IRPS_NHPI": float,
                        "IRPS_NRA": float,
                        "IRPS_UNKN": float,
                        "IRPS_WHITE": float,
                        "IRPS_WOMEN": float,
                        "IRPS_MEN": float,
                        "MD_EARN_WNE_1YR": float,
                        "GT_THRESHOLD_1YR": float,
                        "COUNT_NWNE_4YR": float,
                        "COUNT_WNE_4YR": float,
                        "MD_EARN_WNE_4YR": float,
                        "GT_THRESHOLD_4YR": float,
                        "BBRR4_FED_UG_N": float,
                        "BBRR4_FED_UG_DFLT": float,
                        "BBRR4_FED_UG_DLNQ": float,
                        "BBRR4_FED_UG_FBR": float,
                        "BBRR4_FED_UG_DFR": float,
                        "BBRR4_FED_UG_NOPROG": float,
                        "BBRR4_FED_UG_MAKEPROG": float,
                        "BBRR4_FED_UG_PAIDINFULL": float,
                        "BBRR4_FED_UG_DISCHARGE": float,
                        "BBRR4_FED_UGCOMP_N": float,
                        "BBRR4_FED_UGCOMP_DFLT": float,
                        "BBRR4_FED_UGCOMP_DLNQ": float,
                        "BBRR4_FED_UGCOMP_FBR": float,
                        "BBRR4_FED_UGCOMP_DFR": float,
                        "BBRR4_FED_UGCOMP_NOPROG": float,
                        "BBRR4_FED_UGCOMP_MAKEPROG": float,
                        "BBRR4_FED_UGCOMP_PAIDINFULL": float,
                        "BBRR4_FED_UGCOMP_DISCHARGE": float,
                        "BBRR4_FED_UGNOCOMP_N": float,
                        "BBRR4_FED_UGNOCOMP_DFLT": float,
                        "BBRR4_FED_UGNOCOMP_DLNQ": float,
                        "BBRR4_FED_UGNOCOMP_FBR": float,
                        "BBRR4_FED_UGNOCOMP_DFR": float,
                        "BBRR4_FED_UGNOCOMP_NOPROG": float,
                        "BBRR4_FED_UGNOCOMP_MAKEPROG": float,
                        "BBRR4_FED_UGNOCOMP_PAIDINFULL": float,
                        "BBRR4_FED_UGNOCOMP_DISCHARGE": float,
                        "BBRR4_FED_UGUNK_N": float,
                        "BBRR4_FED_UGUNK_DFLT": float,
                        "BBRR4_FED_UGUNK_DLNQ": float,
                        "BBRR4_FED_UGUNK_FBR": float,
                        "BBRR4_FED_UGUNK_DFR": float,
                        "BBRR4_FED_UGUNK_NOPROG": float,
                        "BBRR4_FED_UGUNK_MAKEPROG": float,
                        "BBRR4_FED_UGUNK_PAIDINFULL": float,
                        "BBRR4_FED_UGUNK_DISCHARGE": float,
                        "BBRR4_FED_GR_N": float,
                        "BBRR4_FED_GR_DFLT": float,
                        "BBRR4_FED_GR_DLNQ": float,
                        "BBRR4_FED_GR_FBR": float,
                        "BBRR4_FED_GR_DFR": float,
                        "BBRR4_FED_GR_NOPROG": float,
                        "BBRR4_FED_GR_MAKEPROG": float,
                        "BBRR4_FED_GR_PAIDINFULL": float,
                        "BBRR4_FED_GR_DISCHARGE": float,
                        "BBRR4_FED_GRCOMP_N": float,
                        "BBRR4_FED_GRCOMP_DFLT": float,
                        "BBRR4_FED_GRCOMP_DLNQ": float,
                        "BBRR4_FED_GRCOMP_FBR": float,
                        "BBRR4_FED_GRCOMP_DFR": float,
                        "BBRR4_FED_GRCOMP_NOPROG": float,
                        "BBRR4_FED_GRCOMP_MAKEPROG": float,
                        "BBRR4_FED_GRCOMP_PAIDINFULL": float,
                        "BBRR4_FED_GRCOMP_DISCHARGE": float,
                        "BBRR4_FED_GRNOCOMP_N": float,
                        "BBRR4_FED_GRNOCOMP_DFLT": float,
                        "BBRR4_FED_GRNOCOMP_DLNQ": float,
                        "BBRR4_FED_GRNOCOMP_FBR": float,
                        "BBRR4_FED_GRNOCOMP_DFR": float,
                        "BBRR4_FED_GRNOCOMP_NOPROG": float,
                        "BBRR4_FED_GRNOCOMP_MAKEPROG": float,
                        "BBRR4_FED_GRNOCOMP_PAIDINFULL": float,
                        "BBRR4_FED_GRNOCOMP_DISCHARGE": float,
                        "BBRR4_PP_UG_N": float,
                        "BBRR4_PP_UG_DFLT": float,
                        "BBRR4_PP_UG_DLNQ": float,
                        "BBRR4_PP_UG_FBR": float,
                        "BBRR4_PP_UG_DFR": float,
                        "BBRR4_PP_UG_NOPROG": float,
                        "BBRR4_PP_UG_MAKEPROG": float,
                        "BBRR4_PP_UG_PAIDINFULL": float,
                        "BBRR4_PP_UG_DISCHARGE": float,
                        "BBRR4_PP_UGCOMP_N": float,
                        "BBRR4_PP_UGCOMP_DFLT": float,
                        "BBRR4_PP_UGCOMP_DLNQ": float,
                        "BBRR4_PP_UGCOMP_FBR": float,
                        "BBRR4_PP_UGCOMP_DFR": float,
                        "BBRR4_PP_UGCOMP_NOPROG": float,
                        "BBRR4_PP_UGCOMP_MAKEPROG": float,
                        "BBRR4_PP_UGCOMP_PAIDINFULL": float,
                        "BBRR4_PP_UGCOMP_DISCHARGE": float,
                        "BBRR4_PP_UGNOCOMP_N": float,
                        "BBRR4_PP_UGNOCOMP_DFLT": float,
                        "BBRR4_PP_UGNOCOMP_DLNQ": float,
                        "BBRR4_PP_UGNOCOMP_FBR": float,
                        "BBRR4_PP_UGNOCOMP_DFR": float,
                        "BBRR4_PP_UGNOCOMP_NOPROG": float,
                        "BBRR4_PP_UGNOCOMP_MAKEPROG": float,
                        "BBRR4_PP_UGNOCOMP_PAIDINFULL": float,
                        "BBRR4_PP_UGNOCOMP_DISCHARGE": float,
                        "BBRR4_PP_UGUNK_N": float,
                        "BBRR4_PP_UGUNK_DFLT": float,
                        "BBRR4_PP_UGUNK_DLNQ": float,
                        "BBRR4_PP_UGUNK_FBR": float,
                        "BBRR4_PP_UGUNK_DFR": float,
                        "BBRR4_PP_UGUNK_NOPROG": float,
                        "BBRR4_PP_UGUNK_MAKEPROG": float,
                        "BBRR4_PP_UGUNK_PAIDINFULL": float,
                        "BBRR4_PP_UGUNK_DISCHARGE": float,
                        "BBRR4_FED_IND_N": float,
                        "BBRR4_FED_IND_DFLT": float,
                        "BBRR4_FED_IND_DLNQ": float,
                        "BBRR4_FED_IND_FBR": float,
                        "BBRR4_FED_IND_DFR": float,
                        "BBRR4_FED_IND_NOPROG": float,
                        "BBRR4_FED_IND_MAKEPROG": float,
                        "BBRR4_FED_IND_PAIDINFULL": float,
                        "BBRR4_FED_IND_DISCHARGE": float,
                        "BBRR4_FED_DEP_N": float,
                        "BBRR4_FED_DEP_DFLT": float,
                        "BBRR4_FED_DEP_DLNQ": float,
                        "BBRR4_FED_DEP_FBR": float,
                        "BBRR4_FED_DEP_DFR": float,
                        "BBRR4_FED_DEP_NOPROG": float,
                        "BBRR4_FED_DEP_MAKEPROG": float,
                        "BBRR4_FED_DEP_PAIDINFULL": float,
                        "BBRR4_FED_DEP_DISCHARGE": float,
                        "BBRR4_FED_PELL_N": float,
                        "BBRR4_FED_PELL_DFLT": float,
                        "BBRR4_FED_PELL_DLNQ": float,
                        "BBRR4_FED_PELL_FBR": float,
                        "BBRR4_FED_PELL_DFR": float,
                        "BBRR4_FED_PELL_NOPROG": float,
                        "BBRR4_FED_PELL_MAKEPROG": float,
                        "BBRR4_FED_PELL_PAIDINFULL": float,
                        "BBRR4_FED_PELL_DISCHARGE": float,
                        "BBRR4_FED_NOPELL_N": float,
                        "BBRR4_FED_NOPELL_DFLT": float,
                        "BBRR4_FED_NOPELL_DLNQ": float,
                        "BBRR4_FED_NOPELL_FBR": float,
                        "BBRR4_FED_NOPELL_DFR": float,
                        "BBRR4_FED_NOPELL_NOPROG": float,
                        "BBRR4_FED_NOPELL_MAKEPROG": float,
                        "BBRR4_FED_NOPELL_PAIDINFULL": float,
                        "BBRR4_FED_NOPELL_DISCHARGE": float,
                        "BBRR4_FED_MALE_N": float,
                        "BBRR4_FED_MALE_DFLT": float,
                        "BBRR4_FED_MALE_DLNQ": float,
                        "BBRR4_FED_MALE_FBR": float,
                        "BBRR4_FED_MALE_DFR": float,
                        "BBRR4_FED_MALE_NOPROG": float,
                        "BBRR4_FED_MALE_MAKEPROG": float,
                        "BBRR4_FED_MALE_PAIDINFULL": float,
                        "BBRR4_FED_MALE_DISCHARGE": float,
                        "BBRR4_FED_NOMALE_N": float,
                        "BBRR4_FED_NOMALE_DFLT": float,
                        "BBRR4_FED_NOMALE_DLNQ": float,
                        "BBRR4_FED_NOMALE_FBR": float,
                        "BBRR4_FED_NOMALE_DFR": float,
                        "BBRR4_FED_NOMALE_NOPROG": float,
                        "BBRR4_FED_NOMALE_MAKEPROG": float,
                        "BBRR4_FED_NOMALE_PAIDINFULL": float,
                        "BBRR4_FED_NOMALE_DISCHARGE": float,
                        "BBRR4_PP_IND_N": float,
                        "BBRR4_PP_IND_DFLT": float,
                        "BBRR4_PP_IND_DLNQ": float,
                        "BBRR4_PP_IND_FBR": float,
                        "BBRR4_PP_IND_DFR": float,
                        "BBRR4_PP_IND_NOPROG": float,
                        "BBRR4_PP_IND_MAKEPROG": float,
                        "BBRR4_PP_IND_PAIDINFULL": float,
                        "BBRR4_PP_IND_DISCHARGE": float,
                        "BBRR4_PP_DEP_N": float,
                        "BBRR4_PP_DEP_DFLT": float,
                        "BBRR4_PP_DEP_DLNQ": float,
                        "BBRR4_PP_DEP_FBR": float,
                        "BBRR4_PP_DEP_DFR": float,
                        "BBRR4_PP_DEP_NOPROG": float,
                        "BBRR4_PP_DEP_MAKEPROG": float,
                        "BBRR4_PP_DEP_PAIDINFULL": float,
                        "BBRR4_PP_DEP_DISCHARGE": float,
                        "BBRR4_PP_PELL_N": float,
                        "BBRR4_PP_PELL_DFLT": float,
                        "BBRR4_PP_PELL_DLNQ": float,
                        "BBRR4_PP_PELL_FBR": float,
                        "BBRR4_PP_PELL_DFR": float,
                        "BBRR4_PP_PELL_NOPROG": float,
                        "BBRR4_PP_PELL_MAKEPROG": float,
                        "BBRR4_PP_PELL_PAIDINFULL": float,
                        "BBRR4_PP_PELL_DISCHARGE": float,
                        "BBRR4_PP_NOPELL_N": float,
                        "BBRR4_PP_NOPELL_DFLT": float,
                        "BBRR4_PP_NOPELL_DLNQ": float,
                        "BBRR4_PP_NOPELL_FBR": float,
                        "BBRR4_PP_NOPELL_DFR": float,
                        "BBRR4_PP_NOPELL_NOPROG": float,
                        "BBRR4_PP_NOPELL_MAKEPROG": float,
                        "BBRR4_PP_NOPELL_PAIDINFULL": float,
                        "BBRR4_PP_NOPELL_DISCHARGE": float,
                        "BBRR4_PP_MALE_N": float,
                        "BBRR4_PP_MALE_DFLT": float,
                        "BBRR4_PP_MALE_DLNQ": float,
                        "BBRR4_PP_MALE_FBR": float,
                        "BBRR4_PP_MALE_DFR": float,
                        "BBRR4_PP_MALE_NOPROG": float,
                        "BBRR4_PP_MALE_MAKEPROG": float,
                        "BBRR4_PP_MALE_PAIDINFULL": float,
                        "BBRR4_PP_MALE_DISCHARGE": float,
                        "BBRR4_PP_NOMALE_N": float,
                        "BBRR4_PP_NOMALE_DFLT": float,
                        "BBRR4_PP_NOMALE_DLNQ": float,
                        "BBRR4_PP_NOMALE_FBR": float,
                        "BBRR4_PP_NOMALE_DFR": float,
                        "BBRR4_PP_NOMALE_NOPROG": float,
                        "BBRR4_PP_NOMALE_MAKEPROG": float,
                        "BBRR4_PP_NOMALE_PAIDINFULL": float,
                        "BBRR4_PP_NOMALE_DISCHARGE": float,
                        "CONTROL_PEPS": float,
                        "ADM_RATE_SUPP": float,
                        "OMENRYP_NOPELL_ALL": float,
                        "OMENRAP_NOPELL_ALL": float,
                        "OMAWDP8_NOPELL_ALL": float,
                        "OMENRUP_NOPELL_ALL": float,
                        "OMENRYP_NOPELL_FIRSTTIME": float,
                        "OMENRAP_NOPELL_FIRSTTIME": float,
                        "OMAWDP8_NOPELL_FIRSTTIME": float,
                        "OMENRUP_NOPELL_FIRSTTIME": float,
                        "OMENRYP_NOPELL_NOTFIRSTTIME": float,
                        "OMENRAP_NOPELL_NOTFIRSTTIME": float,
                        "OMAWDP8_NOPELL_NOTFIRSTTIME": float,
                        "OMENRUP_NOPELL_NOTFIRSTTIME": float,
                        "OMACHT8_NOPELL_ALL": float,
                        "OMACHT8_NOPELL_FIRSTTIME": float,
                        "OMACHT8_NOPELL_NOTFIRSTTIME": float,
                        "ADDR": float
}

# %%
with zipfile.ZipFile(zip_file_bytes) as zip_file:
    with zip_file.open(desired_file) as file:
        df_merged = pd.read_csv(file, dtype=merged_dtypes)
                 # Remove the 'data/' prefix from the filename
        simplified_name = desired_file.split('/', 1)[1] if '/' in desired_file else desired_file
        full_path = os.path.join(dataset_directory, simplified_name.replace('.csv', '.parquet'))
                 # Save to Parquet file
        df_merged.to_parquet(full_path)
        print(f"Converted {simplified_name} to {full_path}")
# Out:
# Converted MERGED2019_20_PP.csv to ../mage/de-bootcamp-final-project/dataset/MERGED2019_20_PP.parquet
